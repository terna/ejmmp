# %%
# %matplotlib inline
import random as r
import matplotlib.pyplot as plt

# %%
a=[]
b=[]
for i in range(10):
    a.append(r.random())
    b.append(r.random())

# %%
plt.plot(a)
plt.show()
plt.plot(b)
plt.show()
