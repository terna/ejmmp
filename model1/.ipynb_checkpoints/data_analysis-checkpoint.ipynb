# %%
# %%javascript
# // to avoid scroll in windows
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import pandas as pd
import csv

with open("plotInfo.csv","r") as data:
    reader = csv.reader(data, delimiter = ',')
    for row in reader:
        fileNameRoot=row[0]
        rankNum=int(row[1])

# %%
names=["_total_production_","_total_cost_of_production_","_total_cost_of_unused_factors_",
       "_total_inventories_","_total_in_progress_inventories_",
       "_total_lost_production_","_total_cost_of_lost_production_"]

# %%
#production
for k in range(rankNum):
    for name in names:

        data=pd.read_csv(fileNameRoot+name+str(k)+".csv", header=None)

        display(name+", rank "+str(k))
        display(data)
        display("____________________________________________________________")
        g=str(list(range(len(data.columns))))
        data.plot(title="rank "+str(k)+" groups "+g,xlabel="time",ylabel=name)
# Out:
# '_total_production_, rank 0'
#             0          1          2
# 0   17.423036  26.069528  11.900372
# 1   23.099910  44.233591  18.062460
# 2   31.300522  52.433807  27.189450
# 3   43.179897  69.909451  13.230773
# 4   43.853053  69.099911  18.670345
# ..        ...        ...        ...
# 95  54.590880  48.390504  21.790254
# 96  39.872325  63.549900  17.460852
# 97  30.966136  58.794382  16.520367
# 98  33.948000  49.345961  24.433071
# 99  34.783498  54.970685  14.801423
#
# [100 rows x 3 columns]
# '____________________________________________________________'
# '_total_cost_of_production_, rank 0'
#         0      1      2
# 0    33.0   58.8  29.40
# 1    45.0   79.2  34.65
# 2    61.5   92.4  51.45
# 3    84.0  122.4  25.20
# 4    85.5  120.0  34.65
# ..    ...    ...    ...
# 95  108.0  120.0  42.00
# 96  108.0  111.6  33.60
# 97   91.5  122.4  30.45
# 98   84.0   87.6  57.75
# 99   91.5   97.2  28.35
#
# [100 rows x 3 columns]
# '____________________________________________________________'
# '_total_cost_of_unused_factors_, rank 0'
#             0          1          2
# 0   83.168386  107.56835  63.840667
# 1   71.168386   87.16835  58.590667
# 2   54.668386   73.96835  41.790667
# 3   32.168386   43.96835  68.040667
# 4   30.668386   46.36835  58.590667
# ..        ...        ...        ...
# 95   8.168386   46.36835  51.240667
# 96   8.168386   54.76835  59.640667
# 97  24.668386   43.96835  62.790667
# 98  32.168386   78.76835  35.490667
# 99  24.668386   69.16835  64.890667
#
# [100 rows x 3 columns]
# '____________________________________________________________'
# '_total_inventories_, rank 0'
#          0        1        2
# 0      0.0      0.0    23.10
# 1      0.0     93.6    57.75
# 2      0.0    117.6   109.20
# 3      0.0    282.0   134.40
# 4    165.0    391.2   169.05
# ..     ...      ...      ...
# 95  5880.0  10281.6  3228.75
# 96  5902.5  10298.4  3262.35
# 97  5925.0  10503.6  3292.80
# 98  5970.0  10536.0  3337.95
# 99  6127.5  10646.4  3366.30
#
# [100 rows x 3 columns]
# '____________________________________________________________'
# '_total_in_progress_inventories_, rank 0'
#         0      1    2
# 0    33.0   46.8  0.0
# 1    78.0   32.4  0.0
# 2   139.5  100.8  0.0
# 3   223.5   58.8  0.0
# 4   144.0   69.6  0.0
# ..    ...    ...  ...
# 95  285.0   28.8  0.0
# 96  228.0  123.6  0.0
# 97  147.0   21.6  0.0
# 98  153.0   76.8  0.0
# 99   42.0   63.6  0.0
#
# [100 rows x 3 columns]
# '____________________________________________________________'
# '_total_lost_production_, rank 0'
#             0          1         2
# 0    0.000000   6.678746  3.317398
# 1    0.000000   0.000000  0.000000
# 2    0.000000   0.000000  0.000000
# 3    0.000000   0.000000  0.000000
# 4    0.000000   0.000000  0.000000
# ..        ...        ...       ...
# 95   0.000000  20.286278  0.000000
# 96  73.592775   0.000000  0.000000
# 97  76.121492  11.066129  0.000000
# 98  16.736318   0.000000  6.664517
# 99  23.159321   0.000000  0.000000
#
# [100 rows x 3 columns]
# '____________________________________________________________'
# '_total_cost_of_lost_production_, rank 0'
#         0     1     2
# 0     0.0  12.0   6.3
# 1     0.0   0.0   0.0
# 2     0.0   0.0   0.0
# 3     0.0   0.0   0.0
# 4     0.0   0.0   0.0
# ..    ...   ...   ...
# 95    0.0  34.8   0.0
# 96  142.5   0.0   0.0
# 97  150.0  19.2   0.0
# 98   33.0   0.0  12.6
# 99   45.0   0.0   0.0
#
# [100 rows x 3 columns]
# '____________________________________________________________'
