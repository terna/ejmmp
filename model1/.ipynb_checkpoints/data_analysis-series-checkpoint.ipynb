# %%
# %%javascript
# // to avoid scroll in windows
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import matplotlib.pyplot as plt #used to avoid a warning message

# %%
import pandas as pd
import csv
import os

folder=input("Which is your input folder? ")
os.chdir("./"+folder)

with open("plotInfo.csv","r") as data:
    reader = csv.reader(data, delimiter = ',')
    for row in reader:
        fileNameRoot=row[0]
        rankNum=int(row[1])
# Out:
# Which is your input folder?  prova3ranks

# %%
names=["_total_production_","_total_cost_of_production_","_total_cost_of_unused_factors_",
       "_total_inventories_","_total_in_progress_inventories_",
       "_total_lost_production_","_total_cost_of_lost_production_","_updatedLabor_","_updatedCapital_"]

# %%
# database
data={}
for name in names:
    data[name]=[]
    for k in range(rankNum):
        data[name].append(pd.read_csv(fileNameRoot+name+str(k)+".csv", header=None))

    data[name].append(data[name][0].copy()) #copy of first rank
    for k in range(1,rankNum):   #add others
        data[name][-1]=data[name][-1].add(data[name][k])

# %% [raw]
# # output by ranks
# with plt.rc_context(rc={'figure.max_open_warning': 0}): #to avoid a warning about open plots
#     for name in names:
#         for k in range(rankNum):
#             display(name+", rank "+str(k))
#             display(data[name][k])
#             display("____________________________________________________________")
#             g=str(list(range(len(data[name][k].columns))))
#             data[name][k].plot(title="rank "+str(k)+" groups "+g,xlabel="time",ylabel=name)

# %%
# totals
with plt.rc_context(rc={'figure.max_open_warning': 0}): #to avoid a warning about open plots
    for name in names:
        display(name+", all ranks")
        display(data[name][-1])
        display("____________________________________________________________")
        data[name][-1].plot(title="total",xlabel="time",ylabel=name)
# Out:
# '_total_production_, all ranks'
#              0           1           2
# 0    69.702615  276.578495  146.845983
# 1   112.213113  394.687415  118.942748
# 2   174.343442  470.920574  143.530527
# 3   215.088854  518.665193  143.592378
# 4   283.871625  485.287834  144.858078
# ..         ...         ...         ...
# 95  358.721623  502.121391   23.205576
# 96  349.397534  469.620420   10.111578
# 97  341.159707  523.490686   24.114628
# 98  332.721902  502.974727   21.269947
# 99  370.216111  432.854822   24.913441
#
# [100 rows x 3 columns]
# '____________________________________________________________'
# '_total_cost_of_production_, all ranks'
#         0      1       2
# 0   150.0  494.4  286.65
# 1   249.0  738.0  270.90
# 2   360.0  885.6  279.30
# 3   466.5  933.6  288.75
# 4   558.0  956.4  316.05
# ..    ...    ...     ...
# 95  742.5  980.4   47.25
# 96  696.0  924.0   30.45
# 97  729.0  963.6   53.55
# 98  733.5  933.6   44.10
# 99  778.5  914.4   55.65
#
# [100 rows x 3 columns]
# '____________________________________________________________'
# '_total_cost_of_unused_factors_, all ranks'
#              0            1           2
# 0   963.232917  1314.433223  490.428325
# 1   864.232917  1070.833223  506.178325
# 2   753.232917   923.233223  497.778325
# 3   646.732917   875.233223  488.328325
# 4   555.232917   852.433223  461.028325
# ..         ...          ...         ...
# 95  370.732917   828.433223  729.828325
# 96  417.232917   884.833223  746.628325
# 97  384.232917   845.233223  723.528325
# 98  379.732917   875.233223  732.978325
# 99  334.732917   894.433223  721.428325
#
# [100 rows x 3 columns]
# '____________________________________________________________'
# '_total_inventories_, all ranks'
#           0        1        2
# 0       0.0      0.0   275.10
# 1       0.0    420.0   501.90
# 2       0.0    926.4   770.70
# 3       0.0   1917.6  1046.85
# 4     202.5   2752.8  1317.75
# ..      ...      ...      ...
# 95  51012.0  79701.6  6830.25
# 96  51535.5  80359.2  6851.25
# 97  51822.0  81248.4  6904.80
# 98  52351.5  82152.0  6948.90
# 99  53011.5  82962.0  7001.40
#
# [100 rows x 3 columns]
# '____________________________________________________________'
# '_total_in_progress_inventories_, all ranks'
#          0       1    2
# 0    138.0   494.4  0.0
# 1    333.0   750.0  0.0
# 2    648.0  1029.6  0.0
# 3   1072.5   964.8  0.0
# 4   1428.0   987.6  0.0
# ..     ...     ...  ...
# 95  1930.5   914.4  0.0
# 96  2097.0   984.0  0.0
# 97  2190.0  1010.4  0.0
# 98  2155.5   973.2  0.0
# 99  2029.5   858.0  0.0
#
# [100 rows x 3 columns]
# '____________________________________________________________'
# '_total_lost_production_, all ranks'
#              0           1          2
# 0     5.850904    0.000000   5.818152
# 1    28.155557   33.342449  23.868813
# 2    22.681443   54.556081   5.846552
# 3    22.132458    2.239486   6.711375
# 4     0.000000   54.209422  24.806246
# ..         ...         ...        ...
# 95   19.024167   67.599119   0.000000
# 96    2.527872  110.469375   4.786353
# 97  177.530289   26.274315   0.000000
# 98  122.014143   36.715906   0.000000
# 99  129.323811  119.744406   1.667597
#
# [100 rows x 3 columns]
# '____________________________________________________________'
# '_total_cost_of_lost_production_, all ranks'
#         0      1      2
# 0    12.0    0.0  11.55
# 1    54.0   62.4  44.10
# 2    45.0   99.6  10.50
# 3    42.0    7.2  12.60
# 4     0.0   98.4  45.15
# ..    ...    ...    ...
# 95   39.0  118.8   0.00
# 96    6.0  196.8   9.45
# 97  349.5   48.0   0.00
# 98  238.5   67.2   0.00
# 99  244.5  219.6   3.15
#
# [100 rows x 3 columns]
# '____________________________________________________________'
# '_updatedLabor_, all ranks'
#       0     1    2
# 0   577  1049  639
# 1   577  1049  639
# 2   577  1049  639
# 3   577  1049  639
# 4   577  1049  639
# ..  ...   ...  ...
# 95  453   781  292
# 96  453   780  300
# 97  453   780  300
# 98  453   785  301
# 99  453   785  301
#
# [100 rows x 3 columns]
# '____________________________________________________________'
# '_updatedCapital_, all ranks'
#               0            1            2
# 0   5353.735691  7586.155412  1378.570457
# 1   5345.155986  7573.998112  1376.361210
# 2   5336.590031  7561.860295  1374.155503
# 3   5328.037804  7549.741929  1371.953330
# 4   5319.499281  7537.642983  1369.754687
# ..          ...          ...          ...
# 95  4597.114697  6514.035910  1183.742881
# 96  4589.747526  6503.596749  1181.845857
# 97  4582.392161  6493.174319  1179.951873
# 98  4575.048584  6482.768591  1178.060925
# 99  4567.716776  6472.379538  1176.173006
#
# [100 rows x 3 columns]
# '____________________________________________________________'
