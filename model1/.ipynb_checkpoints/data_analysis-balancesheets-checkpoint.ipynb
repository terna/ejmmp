# %% [raw]
# %%javascript
# // to avoid scroll in windows
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import pandas as pd
import numpy as np
import csv
import os
import matplotlib.pyplot as plt #used to generate the legends
from typing import List

myListDir=os.listdir()
folder=input("The name of your input folder without extension: ")
while not folder+".0" in myListDir: #extension 0 certainly exists, as we have at least one rank
    print(folder+": wrong name")
    folder=input("The name of your input folder, without extension: ")

os.chdir("./"+folder+".0") #extension 0 certainly exists, as we have at least one rank

with open("plotInfo.csv","r") as data:
    reader = csv.reader(data, delimiter = ',')
    for row in reader:
        fileNameRoot=row[0] #the names of the files contating the data start with...
        rankNum=int(row[1]) #we have file from different ranks, reported in different folders with name, for a specific
                            #rank: fileNameRoot+"."+str(rank)
        ag0num=int(row[2])  #how many agents in each rank, with type==0

#current folders
print("Current folders are:")
for k in range(rankNum):
    print(folder+"."+str(k))
# Out:
# The name of your input folder without extension:  prova3ranks
# Current folders are:
# prova3ranks.0
# prova3ranks.1
# prova3ranks.2

# %% [markdown]
# ### uncomment to show all the rows in tables

# %%
#display all the rows of the dataframe  
#pd.set_option('display.max_rows', None)

# %% [markdown]
# # creation of firm dataframes

# %%
#each firm will have its dataframe
#containing the values of the names of the columns for all the time units (rows)
colNames=["firm class type", "initial inventories","total costs", "final inventories","profits", "added value",\
          "total production", "cost of production", "cost of unused factors",\
          "total lost production", "total cost of lost production", "cost of labor", "cost of capital"]

#fileNameArray is the array that will contain the names of the file of the balance sheets (one file for each firm), 
#subdivided by ranks in the columns of the array; 'itemsize=len(fileNameRoot)+30' is supposed to be sufficient to 
#report the names of the file;
fileNameArray=np.chararray((ag0num, rankNum), itemsize=len(fileNameRoot)+30, unicode=True)

# %%
#operating by folders to load the names of the files reported in the balancesheetList files
for k in range(rankNum):
    #which folder
    os.chdir("../"+folder+"."+str(k))
    with open(fileNameRoot+"_balancesheetList_"+str(k)+".csv","r") as fileList:
        reader = csv.reader(fileList, delimiter = ',')
        #read the name of the files, containing _balancesheetList_, present in the current set of folders
        for row in reader:
            for i in range(len(row)):
                fileNameArray[i,k]=row[i]

# %%
#creating a dictionary of firm dataframes
firmData={}
for k in range(rankNum):
    #in the folder with name extension == k
    os.chdir("../"+folder+"."+str(k))
    #repeating for the number of agent type 0 in each folder
    for i in range(ag0num):
        #extracting the agent uid from the name of the file
        p1=fileNameArray[i,k].find('(')
        p2=fileNameArray[i,k].find(')')+1
        uid=fileNameArray[i,k][p1:p2]
        #filling the dictionary with uids as keys and the balancesheetLists of the related firm as values
        firmData[uid]=pd.read_csv(fileNameArray[i,k], header=None)

#naming the firm dataframe columns, firm by firm, by scrolling the keys of the dictionary
for aFirm in firmData.keys():
    firmData[aFirm].columns=colNames

# %% [markdown]
# # Retrieve a firm

# %%
#retrieve a firm with id and rank
def retrieveFirmBalancesheet(id,r):
    return firmData['('+str(id)+', 0, '+str(r)+')']

# %%
#example
retrieveFirmBalancesheet(29,2)
# Out:
#     firm class type  initial inventories  total costs  final inventories  \
# 0               2.0                0.000    18.479305              5.775
# 1               2.0                5.775    18.479305             11.550
# 2               2.0               11.550    18.479305             15.015
# 3               2.0               15.015    18.479305             23.100
# 4               2.0               23.100    18.479305             27.720
# ..              ...                  ...          ...                ...
# 95              2.0              278.355    18.479305            278.355
# 96              2.0              278.355    18.479305            278.355
# 97              2.0              278.355    18.479305            278.355
# 98              2.0              278.355    18.479305            278.355
# 99              2.0              278.355    18.479305            280.665
#
#       profits   added value  total production  cost of production  \
# 0  -12.704305  5.775000e+00          3.103878                5.25
# 1  -12.704305  5.775000e+00          3.282330                5.25
# 2  -15.014305  3.465000e+00          1.845713                3.15
# 3  -10.394305  8.085000e+00          4.217502                7.35
# 4  -13.859305  4.620000e+00          2.670316                4.20
# ..        ...           ...               ...                 ...
# 95 -18.479305  2.842171e-14          0.000000                0.00
# 96 -18.479305  2.842171e-14          0.000000                0.00
# 97 -18.479305  2.842171e-14          0.000000                0.00
# 98 -18.479305  2.842171e-14          0.000000                0.00
# 99 -16.169305  2.310000e+00          1.205687                2.10
#
#     cost of unused factors  total lost production  \
# 0                13.229305                    0.0
# 1                13.229305                    0.0
# 2                15.329305                    0.0
# 3                11.129305                    0.0
# 4                14.279305                    0.0
# ..                     ...                    ...
# 95               18.479305                    0.0
# 96               18.479305                    0.0
# 97               18.479305                    0.0
# 98               18.479305                    0.0
# 99               16.379305                    0.0
#
#     total cost of lost production  cost of labor  cost of capital
# 0                             0.0           16.0         2.479305
# 1                             0.0           16.0         2.462088
# 2                             0.0           16.0         2.444990
# 3                             0.0           16.0         2.428011
# 4                             0.0           16.0         2.411150
# ..                            ...            ...              ...
# 95                            0.0            4.0         1.278842
# 96                            0.0            4.0         1.269961
# 97                            0.0            4.0         1.261142
# 98                            0.0            4.0         1.252384
# 99                            0.0            8.0         1.243687
#
# [100 rows x 13 columns]

# %% [raw]
# #also working, by paying attention to spaces
# firmData['(29, 0, 2)']

# %% [markdown]
# # The allFirmData dataframe

# %%
#create a dataframe summing up all the firm dataframes
allFirmData=firmData[list(firmData.keys())[0]].copy() #copy the dataframe of first firm; use .copy to create an
                                                      #independent copy with a new name

for aFirmUid in list(firmData.keys())[1:]: #from the second to the last
    allFirmData=allFirmData.add(firmData[aFirmUid])

allFirmData.__description__="all firms"

# %%
allFirmData
# Out:
#     firm class type  initial inventories  total costs  final inventories  \
# 0             150.0                0.000  3771.811456           1022.670
# 1             150.0             1022.670  3771.811456           2327.040
# 2             150.0             2327.040  3771.811456           3704.580
# 3             150.0             3704.580  3771.811456           5281.425
# 4             150.0             5281.425  3771.811456           6989.880
# ..              ...                  ...          ...                ...
# 95            150.0           177285.960  3771.811456         179265.870
# 96            150.0           179265.870  3771.811456         180982.515
# 97            150.0           180982.515  3771.811456         183025.875
# 98            150.0           183025.875  3771.811456         185077.860
# 99            150.0           185077.860  3771.811456         187247.055
#
#         profits  added value  total production  cost of production  \
# 0  -2749.141456     1022.670        517.806825              869.55
# 1  -2467.441456     1304.370        681.176694             1191.45
# 2  -2394.271456     1377.540        757.045388             1332.30
# 3  -2194.966456     1576.845        851.057540             1485.45
# 4  -2063.356456     1708.455        963.188873             1742.55
# ..          ...          ...               ...                 ...
# 95 -1791.901456     1979.910       1020.844305             1817.70
# 96 -2055.166456     1716.645        949.853151             1694.40
# 97 -1728.451456     2043.360       1041.373771             1779.75
# 98 -1719.826456     2051.985       1033.060387             1799.55
# 99 -1602.616456     2169.195       1103.888499             1891.35
#
#     cost of unused factors  total lost production  \
# 0              2902.261456               3.304338
# 1              2580.361456              58.093026
# 2              2439.511456             107.117746
# 3              2286.361456             104.117435
# 4              2029.261456             182.944853
# ..                     ...                    ...
# 95             1954.111456             119.289424
# 96             2077.411456             168.531280
# 97             1992.061456              71.390847
# 98             1972.261456              88.384462
# 99             1880.461456              74.716010
#
#     total cost of lost production  cost of labor  cost of capital
# 0                            5.25         2336.0      1435.811456
# 1                           98.55         2336.0      1425.840543
# 2                          180.30         2336.0      1415.938873
# 3                          174.90         2336.0      1406.105964
# 4                          315.90         2336.0      1396.341339
# ..                            ...            ...              ...
# 95                         204.00         7580.0      2728.814526
# 96                         291.45         7521.0      2709.898082
# 97                         114.75         7502.0      2709.474744
# 98                         136.80         7502.0      2690.658947
# 99                         129.30         7559.0      2680.323357
#
# [100 rows x 13 columns]

# %%
allFirmData.__description__
# Out:
# 'all firms'

# %%
allFirmData.drop(['firm class type'], axis=1).plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
allFirmData[['cost of capital','cost of labor']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Considering groups of firms

# %%
#summarize a subset of balancesheets of firm with 'dimensional class' in a given list
def sumBalancesheetsWithAGivenDimensionalClass(dimClassList: List):
    tmpDict={}
    for aFirmUid in list(firmData.keys())[:]:
        if firmData[aFirmUid]['firm class type'].loc[0] in dimClassList:
            tmpDict[aFirmUid]=firmData[aFirmUid]
    print("found",len(tmpDict), "firms")
    
    if tmpDict=={}: return 0 #firms with the required dimensional class: not found
        
    allLocalFirmData=tmpDict[list(tmpDict.keys())[0]].copy() #copy the dataframe of first firm; use .copy to create an
                                                              #independent copy with a new name

    for aFirmUid in list(tmpDict.keys())[1:]: #from the second to the last
        allLocalFirmData=allLocalFirmData.add(tmpDict[aFirmUid])

    memo="firms of groups"
    for g in dimClassList: memo = memo +" "+str(g)
    allLocalFirmData.__description__= memo
    
    return allLocalFirmData

# %%
#example with dimensional class 0
sumOfBalanceSheetSubset = sumBalancesheetsWithAGivenDimensionalClass([0])
# Out:
# found 9 firms

# %%
sumOfBalanceSheetSubset.__description__
# Out:
# 'firms of groups 0'

# %%
sumOfBalanceSheetSubset
# Out:
#     firm class type  initial inventories  total costs  final inventories  \
# 0               0.0                 0.00  1161.330698             150.15
# 1               0.0               150.15  1161.330698             374.40
# 2               0.0               374.40  1161.330698             668.85
# 3               0.0               668.85  1161.330698            1082.25
# 4               0.0              1082.25  1161.330698            1384.50
# ..              ...                  ...          ...                ...
# 95              0.0             58654.05  1161.330698           59363.85
# 96              0.0             59363.85  1161.330698           59929.35
# 97              0.0             59929.35  1161.330698           60652.80
# 98              0.0             60652.80  1161.330698           61503.00
# 99              0.0             61503.00  1161.330698           62327.85
#
#         profits  added value  total production  cost of production  \
# 0  -1011.180698       150.15         64.233110               115.5
# 1   -937.080698       224.25         97.256683               184.5
# 2   -866.880698       294.45        147.165619               282.0
# 3   -747.930698       413.40        189.680794               351.0
# 4   -859.080698       302.25        220.885620               436.5
# ..          ...          ...               ...                 ...
# 95  -451.530698       709.80        334.491250               622.5
# 96  -595.830698       565.50        311.164293               600.0
# 97  -437.880698       723.45        346.004817               618.0
# 98  -311.130698       850.20        383.174020               684.0
# 99  -336.480698       824.85        394.117965               717.0
#
#     cost of unused factors  total lost production  \
# 0              1045.830698               0.000000
# 1               976.830698               6.521350
# 2               879.330698              32.053637
# 3               810.330698              18.978370
# 4               724.830698             112.989823
# ..                     ...                    ...
# 95              538.830698              43.249281
# 96              561.330698              91.799275
# 97              543.330698              39.707266
# 98              477.330698              23.312510
# 99              444.330698              46.641342
#
#     total cost of lost production  cost of labor  cost of capital
# 0                             0.0          603.0       558.330698
# 1                            12.0          603.0       554.453402
# 2                            55.5          603.0       550.603031
# 3                            33.0          603.0       546.779399
# 4                           204.0          603.0       542.982320
# ..                            ...            ...              ...
# 95                           76.5         3986.0      2001.188347
# 96                          165.0         3926.0      1987.291206
# 97                           61.5         3848.0      1973.490573
# 98                           30.0         3848.0      1959.785777
# 99                           82.5         3848.0      1946.176153
#
# [100 rows x 13 columns]

# %%
sumOfBalanceSheetSubset.drop(['firm class type'], axis=1).plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
sumOfBalanceSheetSubset[['total production']].plot()
# Out:
# <Axes: >

# %%
sumOfBalanceSheetSubset[['cost of capital', 'cost of labor']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # The National Economic Balance Table

# %%
allFirmData[['initial inventories', 'added value', 'final inventories']]
# Out:
#     initial inventories  added value  final inventories
# 0                 0.000     1022.670           1022.670
# 1              1022.670     1304.370           2327.040
# 2              2327.040     1377.540           3704.580
# 3              3704.580     1576.845           5281.425
# 4              5281.425     1708.455           6989.880
# ..                  ...          ...                ...
# 95           177285.960     1979.910         179265.870
# 96           179265.870     1716.645         180982.515
# 97           180982.515     2043.360         183025.875
# 98           183025.875     2051.985         185077.860
# 99           185077.860     2169.195         187247.055
#
# [100 rows x 3 columns]
