# %%
# %%javascript
# // to avoid scroll in windows
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import matplotlib.pyplot as plt #used to avoid a warning message

# %%
import pandas as pd
import numpy as np
import csv
#from repast4py import parameters
#params = parameters.init_params("model1.yaml", "")

with open("plotInfo.csv","r") as data:
    reader = csv.reader(data, delimiter = ',')
    for row in reader:
        fileNameRoot=row[0]
        rankNum=int(row[1])
        ag0num=int(row[2])

# %%
colNames=["initial inventories","total costs","final inventories","profits","added value"]
fileNameArray=np.chararray((ag0num, rankNum), itemsize=len(fileNameRoot)+30, unicode=True)

# %%
for k in range(rankNum):
    with open("balancesheetList_"+str(k)+".csv","r") as fileList:
        reader = csv.reader(fileList, delimiter = ',')
  
        for row in reader:
            for i in range(len(row)):
                fileNameArray[i,k]=row[i]

# %%
# database
data={}
for k in range(rankNum):
    for i in range(ag0num):
        p1=fileNameArray[i,k].find('(')
        p2=fileNameArray[i,k].find(')')+1
        data[fileNameArray[i,k][p1:p2]]=pd.read_csv(fileNameArray[i,k], header=None)

for aFirm in data.keys():
    data[aFirm].columns=colNames

# %%
data
# Out:
# {'(0, 0, 0)':    initial inventories  total costs  final inventories       profits
#  0                  0.0         38.4               38.4  0.000000e+00  \
#  1                 38.4         45.6               84.0  0.000000e+00
#  2                 84.0         49.2              133.2 -1.421085e-14
#  3                133.2         42.0              175.2  0.000000e+00
#  4                175.2         26.4              201.6  0.000000e+00
#  5                201.6         27.6              229.2  0.000000e+00
#  6                229.2         10.8              240.0  0.000000e+00
#  7                240.0         50.4              290.4 -2.842171e-14
#  8                290.4         40.8              331.2  0.000000e+00
#  9                331.2         33.6              364.8  0.000000e+00
#
#     added value
#  0         38.4
#  1         45.6
#  2         49.2
#  3         42.0
#  4         26.4
#  5         27.6
#  6         10.8
#  7         50.4
#  8         40.8
#  9         33.6  ,
#  '(1, 0, 0)':    initial inventories  total costs  final inventories       profits
#  0                 0.00         5.25               5.25  0.000000e+00  \
#  1                 5.25         0.00               5.25  0.000000e+00
#  2                 5.25         5.25              10.50  0.000000e+00
#  3                10.50         6.30              10.50 -6.300000e+00
#  4                10.50         0.00              10.50  0.000000e+00
#  5                10.50         8.40              18.90 -1.776357e-15
#  6                18.90        11.55              30.45  0.000000e+00
#  7                30.45         9.45              39.90  0.000000e+00
#  8                39.90         4.20              44.10  0.000000e+00
#  9                44.10        11.55              55.65  7.105427e-15
#
#     added value
#  0         5.25
#  1         0.00
#  2         5.25
#  3         0.00
#  4         0.00
#  5         8.40
#  6        11.55
#  7         9.45
#  8         4.20
#  9        11.55  ,
#  '(2, 0, 0)':    initial inventories  total costs  final inventories       profits
#  0                 0.00         7.35               7.35  0.000000e+00  \
#  1                 7.35         5.25              12.60  0.000000e+00
#  2                12.60         0.00              12.60  0.000000e+00
#  3                12.60         3.15              15.75  0.000000e+00
#  4                15.75         8.40              24.15 -1.776357e-15
#  5                24.15         6.30              30.45  0.000000e+00
#  6                30.45         6.30              36.75  0.000000e+00
#  7                36.75        10.50              47.25  0.000000e+00
#  8                47.25         2.10              49.35  0.000000e+00
#  9                49.35         3.15              52.50  0.000000e+00
#
#     added value
#  0         7.35
#  1         5.25
#  2         0.00
#  3         3.15
#  4         8.40
#  5         6.30
#  6         6.30
#  7        10.50
#  8         2.10
#  9         3.15  ,
#  '(3, 0, 0)':    initial inventories  total costs  final inventories       profits
#  0                 0.00         4.20               4.20  0.000000e+00  \
#  1                 4.20         1.05               5.25  0.000000e+00
#  2                 5.25         9.45              14.70  0.000000e+00
#  3                14.70         5.25              19.95  0.000000e+00
#  4                19.95         5.25              25.20  0.000000e+00
#  5                25.20         7.35              32.55 -3.552714e-15
#  6                32.55         3.15              35.70  0.000000e+00
#  7                35.70         0.00              35.70  0.000000e+00
#  8                35.70         0.00              35.70  0.000000e+00
#  9                35.70         0.00              35.70  0.000000e+00
#
#     added value
#  0         4.20
#  1         1.05
#  2         9.45
#  3         5.25
#  4         5.25
#  5         7.35
#  6         3.15
#  7         0.00
#  8         0.00
#  9         0.00  ,
#  '(0, 0, 1)':    initial inventories  total costs  final inventories       profits
#  0                  0.0         20.4               20.4  0.000000e+00  \
#  1                 20.4         20.4               40.8  0.000000e+00
#  2                 40.8         20.4               61.2  0.000000e+00
#  3                 61.2         28.8               90.0  7.105427e-15
#  4                 90.0         28.8              118.8  0.000000e+00
#  5                118.8         28.8              147.6  2.842171e-14
#  6                147.6         32.4              180.0  0.000000e+00
#  7                180.0         32.4              212.4  0.000000e+00
#  8                212.4         32.4              237.6 -7.200000e+00
#  9                237.6         24.0              261.6  0.000000e+00
#
#     added value
#  0         20.4
#  1         20.4
#  2         20.4
#  3         28.8
#  4         28.8
#  5         28.8
#  6         32.4
#  7         32.4
#  8         25.2
#  9         24.0  ,
#  '(1, 0, 1)':    initial inventories  total costs  final inventories  profits  added value
#  0                 0.00         3.15               3.15      0.0         3.15
#  1                 3.15         2.10               5.25      0.0         2.10
#  2                 5.25         7.35              12.60      0.0         7.35
#  3                12.60         2.10              14.70      0.0         2.10
#  4                14.70        15.75              30.45      0.0        15.75
#  5                30.45         9.45              39.90      0.0         9.45
#  6                39.90        15.75              55.65      0.0        15.75
#  7                55.65         8.40              64.05      0.0         8.40
#  8                64.05         3.15              67.20      0.0         3.15
#  9                67.20         7.35              74.55      0.0         7.35,
#  '(2, 0, 1)':    initial inventories  total costs  final inventories  profits  added value
#  0                 0.00        14.70               0.00    -14.7         0.00
#  1                 0.00         8.40               8.40      0.0         8.40
#  2                 8.40         8.40              16.80      0.0         8.40
#  3                16.80        14.70              31.50      0.0        14.70
#  4                31.50        10.50              42.00      0.0        10.50
#  5                42.00         9.45              51.45      0.0         9.45
#  6                51.45         8.40              59.85      0.0         8.40
#  7                59.85        12.60              72.45      0.0        12.60
#  8                72.45        12.60              85.05      0.0        12.60
#  9                85.05         5.25              90.30      0.0         5.25,
#  '(3, 0, 1)':    initial inventories  total costs  final inventories       profits
#  0                 0.00         0.00               0.00  0.000000e+00  \
#  1                 0.00         1.05               1.05  0.000000e+00
#  2                 1.05         2.10               1.05 -2.100000e+00
#  3                 1.05         0.00               1.05  0.000000e+00
#  4                 1.05        12.60              13.65  6.661338e-16
#  5                13.65        14.70              28.35  1.776357e-15
#  6                28.35         9.45              37.80 -3.552714e-15
#  7                37.80         0.00              37.80  0.000000e+00
#  8                37.80        14.70              52.50  0.000000e+00
#  9                52.50        11.55              64.05  0.000000e+00
#
#     added value
#  0         0.00
#  1         1.05
#  2         0.00
#  3         0.00
#  4        12.60
#  5        14.70
#  6         9.45
#  7         0.00
#  8        14.70
#  9        11.55  }

# %% [raw]
# DA FARE
# # output by ranks
# with plt.rc_context(rc={'figure.max_open_warning': 0}): #to avoid a worning about open plots
#     for name in names:
#         for k in range(rankNum):
#             display(name+", rank "+str(k))
#             display(data[name][k])
#             display("____________________________________________________________")
#             g=str(list(range(len(data[name][k].columns))))
#             data[name][k].plot(title="rank "+str(k)+" groups "+g,xlabel="time",ylabel=name)

# %% [raw]
# DA FARE
# # totals
# with plt.rc_context(rc={'figure.max_open_warning': 0}): #to avoid a warning about open plots
#     for name in names:
#         display(name+", all ranks")
#         display(data[name][-1])
#         display("____________________________________________________________")
#         data[name][-1].plot(title="total",xlabel="time",ylabel=name)
