# %% [markdown]
# ![Distribution](barre_inviluppo.jpeg)
#
# $\qquad \qquad
# b_i = b_1 - (i-1)\,\Delta b, \qquad \Delta b > 0
# \qquad \qquad \qquad \qquad \qquad \qquad \qquad \qquad
# b_i = b_1\,q^{\,i-1}, \qquad 0<q<1$

# %% [markdown]
# **Linear case**
#
# With $m$ mean value:
# $\Delta b = \frac{2\,(b_1 - m)}{n-1}, \qquad b_1 > m$
