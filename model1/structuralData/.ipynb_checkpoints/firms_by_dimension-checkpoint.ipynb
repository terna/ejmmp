# %% [markdown]
# Source of the data https://ec.europa.eu/eurostat/databrowser/view/SBS_SC_OVW/default/table?lang=en

# %% [markdown]
# ![Distribution](inviluppo_lineare_c.jpeg)
#
# $\qquad
# b_i = b_1 - (i-1)\,\Delta b, \qquad \Delta b > 0$

# %% [markdown]
# **Linear case**
#
# With $m$ mean value:
# $\Delta b = \frac{2\,(b_1 - m)}{n-1}, \qquad b_1 > m$

# %%
# prova
b_1 = 6500000
S   =  30393757
n   = 9
m   = S/n
D_b = 2 * (b_1 - m)/(n-1)
#b_n = 2*S/n - b_1

b_n = b_1 - (n-1) * D_b
b_n

b_vector = []

for i in range(0,n):
    b_vector.append(b_1 - D_b*i)
    print(i+1, b_1 - D_b*i)

total = sum(b_vector)
total
# Out:
# 1 6800000.0
# 2 5944271.027777778
# 3 5088542.055555556
# 4 4232813.083333333
# 5 3377084.111111111
# 6 2521355.138888889
# 7 1665626.166666666
# 8 809897.194444444
# 9 -45831.777777777985
# 30393757.0

# %%
num=0
den=0
for i in range(1,n+1):
    num+=i*(i*b_vector[i-1])
    den+=i*b_vector[i-1]
num/den
# Out:
# 4.292254934986971

# %%
m
# Out:
# 3377084.111111111

# %%
Db = 2 * (b_1 - m) / (n-1)
Db
# Out:
# 780728.9722222222

# %%
Db = (b_1 - b_n)/(n-1)
Db
# Out:
# 780728.9722222222

# %%
bb_1 = b_n 
Ss = 1037430
nn = 10
mm = Ss/nn
bb_n = 2*Ss/nn - bb_1
bb_n
# Out:
# -46682.222222222015

# %%
mm
# Out:
# 103743.0
