# %%
# https://ec.europa.eu/eurostat/databrowser/view/tec00010__custom_21446314/default/table
# https://ec.europa.eu/eurostat/databrowser/view/tec00009/default/table?lang=en&category=t_na10.t_nama10.t_nama_10_ma

# https://ec.europa.eu/eurostat/databrowser/view/tec00001__custom_21446525/default/table --> GDP about 16,1 *10^12 (same value of our epigraph GDP)

# %%
import csv
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

# %%
tec01gdp = pd.read_excel('tec00001__custom_21446525_page_spreadsheet.xlsx', sheet_name = 'Sheet 1')
tec01gdp = tec01gdp.iloc[9:37, 0:2]
tec01gdp = tec01gdp.reset_index(drop=True)

tec01gov_consumption =  pd.read_excel('tec00010__custom_21446921_page_spreadsheet.xlsx', sheet_name = 'Sheet 1')
tec01gov_consumption = tec01gov_consumption.iloc[9:37, 0:2]
tec01gov_consumption = tec01gov_consumption.reset_index(drop=True)

tec01private_consumption =  pd.read_excel('tec00009__custom_21447046_page_spreadsheet.xlsx', sheet_name = 'Sheet 1')
tec01private_consumption =  tec01private_consumption.iloc[9:37, 0:2]
tec01private_consumption =  tec01private_consumption.reset_index(drop=True)

tec01 = tec01gdp 
tec01['private consumption'] = tec01private_consumption['Unnamed: 1']
tec01['gov consumption'] = tec01gov_consumption['Unnamed: 1']
tec01 = tec01.rename(columns={"Data extracted on 13/05/2026 16:54:17 from [ESTAT]": "country", "Unnamed: 1": "gdp"})

tec01.iloc[0,0] = 'EU27'

tec01

tec01['private_cons / gdp'] = tec01['private consumption']/tec01['gdp']
tec01['gov_cons /gdp'] = tec01['gov consumption']/tec01['gdp']

tec01
# Out:
#         country        gdp private consumption gov consumption  \
# 0          EU27   16170154           8511272.8       3440030.8
# 1       Belgium   561678.2            289653.3        131454.5
# 2      Bulgaria    86078.2             49855.4         15734.7
# 3       Czechia   286976.8            139367.5           56234
# 4       Denmark   380567.4            166125.5         83938.5
# 5       Germany    3989390             2094029          868210
# 6       Estonia    36300.9             19164.8          6953.8
# 7       Ireland   520718.4            126634.4         57140.9
# 8        Greece   207008.7            146877.7           41188
# 9         Spain    1375863              775799          275811
# 10       France  2653997.2           1435352.6        653543.8
# 11      Croatia    67609.4             39916.7         14308.3
# 12        Italy  1998072.6           1166513.3          376408
# 13       Cyprus    29645.4             17144.7          5334.3
# 14       Latvia    36088.7               21475          7475.3
# 15    Lithuania    67081.1             38396.9         11468.9
# 16   Luxembourg    76731.2             24909.3         13860.7
# 17      Hungary   168546.2             84928.3         34900.8
# 18        Malta    17984.8                7917          3167.2
# 19  Netherlands     993820              437447          241898
# 20      Austria   449382.2            228963.2         92283.8
# 21       Poland   661712.3            384704.3        119896.5
# 22     Portugal   243957.1            155215.3         42456.4
# 23      Romania   280777.4            177466.4         46768.9
# 24     Slovenia    56881.6             30690.5         11085.1
# 25     Slovakia   109959.8             67473.9         23367.1
# 26      Finland     266135              134505           64318
# 27       Sweden   547190.4            250746.9        140854.4
#
#    private_cons / gdp gov_cons /gdp
# 0            0.526357       0.21274
# 1            0.515693      0.234039
# 2            0.579187      0.182795
# 3             0.48564      0.195953
# 4            0.436521      0.220561
# 5              0.5249       0.21763
# 6            0.527943       0.19156
# 7            0.243192      0.109735
# 8            0.709524      0.198967
# 9            0.563864      0.200464
# 10           0.540827      0.246249
# 11           0.590402      0.211632
# 12           0.583819      0.188386
# 13           0.578326      0.179937
# 14           0.595062      0.207137
# 15           0.572395      0.170971
# 16           0.324631       0.18064
# 17           0.503887       0.20707
# 18           0.440205      0.176104
# 19           0.440167      0.243402
# 20           0.509507      0.205357
# 21           0.581377      0.181191
# 22            0.63624      0.174032
# 23           0.632054      0.166569
# 24           0.539551       0.19488
# 25           0.613623      0.212506
# 26           0.505401      0.241674
# 27           0.458244      0.257414

# %%
tec01.to_pickle("./shareConsumptionDemand.xp")
