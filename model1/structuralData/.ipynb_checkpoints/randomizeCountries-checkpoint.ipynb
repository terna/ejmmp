# %%
import pickle
import numpy as np

# %%
with open('addedvalue_countryshares.xp', 'rb') as f:
            addedvalue_countryshares = pickle.load(f)

# %%
addedvalue_countryshares
# Out:
#             Share in 2020
# Country
# Austria          0.028132
# Belgium          0.034407
# Bulgaria         0.008169
# Croatia          0.003473
# Cyprus           0.001643
# Czechia          0.016539
# Denmark          0.022321
# Estonia           0.00201
# Finland           0.01697
# France           0.169282
# Germany          0.254051
# Greece            0.01212
# Hungary          0.009667
# Ireland          0.029261
# Italy            0.123168
# Latvia           0.002163
# Lithuania        0.003696
# Luxembourg       0.004823
# Malta            0.001082
# Netherlands      0.058412
# Poland           0.038147
# Portugal         0.014413
# Romania          0.016499
# Slovakia         0.006968
# Slovenia         0.003422
# Spain            0.084049
# Sweden           0.035112

# %%
p = addedvalue_countryshares["Share in 2020"].tolist()

# %%
countryNumbers=[i for i in range(27)]

# %%
rng = np.random.default_rng(12345) # seed

# %%
rng.choice(countryNumbers,p=p)
# Out:
# np.int64(9)

# %%
for i in range(1000000):
    rng.choice(countryNumbers,p=p)
