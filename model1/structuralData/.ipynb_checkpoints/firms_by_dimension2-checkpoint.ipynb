# %% [markdown]
# Source of the data https://ec.europa.eu/eurostat/databrowser/view/SBS_SC_OVW/default/table?lang=en

# %% [markdown]
# ![Distribution](inviluppo_lineare_c.jpeg)
#
# $\qquad
# b_i = b_1 - (i-1)\,\Delta b, \qquad \Delta b > 0$

# %% [markdown]
# **Linear case**
#
# With $m$ mean value:
# $\Delta b = \frac{2\,(b_1 - m)}{n-1}, \qquad b_1 > m$

# %%
# prova
b_0 = 5800000
S   =  30393757
n   = 10
m   = S/n
D_b = 2 * (b_0 - m)/(n-1)
#b_n = 2*S/n - b_1

b_n = b_0 - (n-1) * D_b
b_n

b_vector = []

for i in range(0,n):
    b_vector.append(b_0 - D_b*i)
    print(i, b_0 - D_b*i)

total = sum(b_vector)
total
# Out:
# 0 5800000.0
# 1 5186527.933333334
# 2 4573055.866666667
# 3 3959583.8
# 4 3346111.7333333334
# 5 2732639.666666667
# 6 2119167.6
# 7 1505695.5333333332
# 8 892223.4666666668
# 9 278751.4000000004
# 30393757.0

# %%
num=0
den=0
for i in range(0,n):
    num+=i*(i*b_vector[i])
    den+=i*b_vector[i]
num/den
# Out:
# 4.766908860898504

# %%
m
# Out:
# 3039375.7

# %%
Db = 2 * (b_1 - m) / (n-1)
Db

# %%
Db = (b_1 - b_n)/(n-1)
Db

# %%
bb_1 = b_n 
Ss = 1037430
nn = 10
mm = Ss/nn
bb_n = 2*Ss/nn - bb_1
bb_n

# %%
mm
