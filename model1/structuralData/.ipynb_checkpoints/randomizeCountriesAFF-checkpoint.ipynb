# %%
import pickle
import numpy as np

# %%
# agri_eu27.xp from ./special_sectors_eu27.ipynb (cell 7)

with open('agri_eu27base.xp', 'rb') as f:
            agri_eu27 = pickle.load(f)

# %% [markdown]
# ?? attenzione riga 1 e 2 uguali, in special_sectors_eu27.ipynb si vede che è una scelta per mancanza di dati

# %%
agri_eu27
# Out:
#         Country Agricultural share Forestry share Fishing share
# 0       Austria           0.012213       0.012213             0
# 1       Belgium           0.003969       0.003969      0.000842
# 2      Bulgaria           0.014633       0.014633       0.02441
# 3       Croatia           0.015867       0.015867      0.100834
# 4        Cyprus           0.003754       0.003754      0.010775
# 5       Czechia           0.003187       0.003187             0
# 6       Denmark           0.004089       0.004089      0.027123
# 7       Estonia           0.001253       0.001253      0.024437
# 8       Finland            0.00503        0.00503      0.041935
# 9        France           0.043328       0.043328      0.082841
# 10      Germany           0.028969       0.028969      0.017271
# 11       Greece           0.058511       0.058511      0.195426
# 12      Hungary           0.025583       0.025583             0
# 13      Ireland           0.014356       0.014356       0.02719
# 14        Italy           0.124906       0.124906      0.162447
# 15       Latvia           0.007604       0.007604       0.00893
# 16    Lithuania           0.014561       0.014561      0.001872
# 17   Luxembourg           0.000207       0.000207             0
# 18        Malta           0.000843       0.000843      0.011804
# 19  Netherlands           0.005803       0.005803      0.011149
# 20       Poland           0.143571       0.143571      0.010988
# 21     Portugal           0.031995       0.031995      0.103093
# 22      Romania           0.318275       0.318275      0.002339
# 23     Slovakia           0.002164       0.002164             0
# 24     Slovenia           0.007989       0.007989      0.001818
# 25        Spain           0.100857       0.100857      0.118146
# 26       Sweden           0.006481       0.006481       0.01433

# %%
p1 = agri_eu27["Agricultural share"].tolist()
p2 = agri_eu27["Forestry share"].tolist()
p3 = agri_eu27["Fishing share"].tolist()

# %%
countryNumbers=[i for i in range(27)] # NB from 0

# %%
rng = np.random.default_rng(12345) # seed

# %%
rng.choice(countryNumbers,p=p1)
# Out:
# np.int64(13)

# %%
rng.choice(countryNumbers,p=p2)
# Out:
# np.int64(14)

# %%
rng.choice(countryNumbers,p=p3)
# Out:
# np.int64(21)

# %%
for i in range(1000000):
    rng.choice(countryNumbers,p=p1)
