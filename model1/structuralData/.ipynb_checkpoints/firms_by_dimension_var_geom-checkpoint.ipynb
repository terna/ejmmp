# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### Our data
#
# Fonte: clic [qui](https://ec.europa.eu/eurostat/databrowser/view/SBS_SC_OVW/default/table?lang=en)
#
#                      Firms        Workers      av. num. of w.
#
#          0-9         30393757     48632916        1.6
#         10-19         1037430     13958529       13.45
#         20-49          525408     15876234       30.2
#         50-249         242846     24000000       98.8
#         250-more(*)     52433     60000000     1144.3
#
# (*) in *test_ff_multi.ipynb* usa gli intervalli di *ff_with_class_limits.csv* prodotto da *firm-features-generation.ipynb*; come max dell'intervallo abbiamo 1850

# %% [markdown]
# ## media geometrica

# %%
import math

def geometric_ratio_from_sum(a1: float, n: int, S: float, tol: float = 1e-12, max_iter: int = 200) -> float:
    """
    Solve for q in (0,1) such that:
        S = a1 * (1 - q**n) / (1 - q)     (q != 1)
    assuming a decreasing geometric series (0<q<1) and a1>0.

    Uses bisection (guaranteed convergence if inputs are consistent).
    """
    if n <= 0:
        raise ValueError("n must be a positive integer.")
    if a1 <= 0:
        raise ValueError("a1 must be > 0 for the decreasing-series assumption.")
    if S <= 0:
        raise ValueError("S must be > 0.")

    # Consistency checks for 0<q<1:
    # As q -> 0+, sum -> a1
    # As q -> 1-, sum -> n*a1
    if S < a1 - 1e-15:
        raise ValueError("Inconsistent data: for 0<q<1, S must be >= a1.")
    if S > n * a1 + 1e-15:
        raise ValueError("Inconsistent data: for 0<q<1, S must be <= n*a1.")

    # Handle edge cases near q=0 or q=1
    if abs(S - a1) <= tol:
        return 0.0
    if abs(S - n * a1) <= tol:
        return 1.0  # limit case (not strictly decreasing, but the limiting value)

    def sum_q(q: float) -> float:
        # Stable evaluation near q ~ 1 via fallback to limit
        if abs(1.0 - q) < 1e-15:
            return n * a1
        return a1 * (1.0 - q**n) / (1.0 - q)

    def f(q: float) -> float:
        return sum_q(q) - S

    lo, hi = 0.0, 1.0
    flo, fhi = f(lo), f(hi - 1e-15)  # avoid exact 1 in computation
    # flo should be <= 0 and fhi >= 0 for consistent inputs
    if flo > 0 or fhi < 0:
        raise ValueError("Could not bracket the root in (0,1). Check inputs.")

    for _ in range(max_iter):
        mid = (lo + hi) / 2.0
        fmid = f(mid)
        if abs(fmid) <= tol or (hi - lo) <= tol:
            return mid
        if fmid > 0:
            hi = mid
        else:
            lo = mid

    raise RuntimeError("Bisection did not converge within max_iter.")

# %% [markdown]
# ## 0-9 geometric ratio, prova

# %%
a1 = 24000000 #22000000 #13000000
n = 9
S = 30393757
q0_9 = geometric_ratio_from_sum(a1, n, S, tol=1e-12)
print("q0_9 =", q0_9)
# Out:
# q0_9 = 0.21036479178337686

# %%
a0_9 = []
a = a1

for i in range(n):
    a0_9.append(a)
    a *= q0_9

print(a0_9)
# Out:
# [24000000, 5048755.002801045, 1062080.294929524, 223424.3001000768, 47000.60636989936, 9887.272772696335, 2079.9340781337155, 437.54489926974895, 92.04404163075934]

# %%
plt.figure()
plt.bar(range(1,len(a0_9)+1), a0_9)
# Out:
# <BarContainer object of 9 artists>

# %%
def weighted_average(series,start):
    num=0
    den=0
    for i in range(start,len(series)+start):
        num+=i*series[i-start]
        den+=series[i-start]
    return num/den

# %%
weighted_average(a0_9,1)
# Out:
# 1.266400302318736

# %%
S
# Out:
# 30393757

# %%
S*weighted_average(a0_9,1)
# Out:
# 38490663.0534022

# %%
sum(a0_9)
# Out:
# 30393756.999992277

# %% [markdown]
# ## modificazione serie geometrica

# %% [markdown]
# Vorrei operare su una serie decrescente di cui conosco primo termine, numero dei termini e totale dei termini. Usiamo lo schema delle progressioni geometriche, ma aggiungendo un correzione che renda variabile la ragione, sempre < 1, ma via via crescente in modo tale che la serie scenda rapidamente ma poi si stabilizzi; mi serve poter indicare il punto in cui inizia la stabilizzazione.
# Come risultato mi serve la serie.
#
# Prepara il codice Python necessario.
#
# ----------------
#
# [Risultato di ChatGTP 5.2](https://chatgpt.com/share/69530a08-6024-8013-b605-c14243ba55ac)
#
# Di seguito trovi uno schema “alla progressione geometrica” con **ragione variabile** $r_i$, sempre $<1$, **crescente** (quindi la serie decresce rapidamente all’inizio e poi si stabilizza). Tu indichi:
#
# * `a1` = primo termine $a_1$
# * `n` = numero termini
# * `S` = somma totale $\sum_{i=1}^n a_i$
# * `i0` = **punto di stabilizzazione** (indice del termine da cui la ragione si avvicina a $r_{\max}$ e la discesa rallenta)
#
# La ragione è costruita come transizione logistica:
#
# $$
# r_i = r_{\min} + (r_{\max}-r_{\min})\cdot \sigma\left(\frac{i - i_0}{\tau}\right),
# \quad \sigma(x)=\frac{1}{1+e^{-x}},
# \quad i=1,\dots,n-1
# $$
#
# con $0<r_{\min}<r_{\max}<1$ e $\tau>0$ che controlla “quanto graduale” è la stabilizzazione.
#
# $\textcolor{red}{\text{Qui sotto}}$ il **codice Python completo** (solo `numpy`) che **calibra automaticamente (r_{\min})** via bisezione per far tornare esattamente la somma $S$, dati `a1, n, S, i0` (e scelte ragionevoli per `r_max, tau`).
#
#
# ### Come “pilotare” la stabilizzazione (in pratica)
#
# * `i0` (intero o anche float) sposta **il punto** in cui la ragione “sale” verso `r_max`.
#
#   * Più **piccolo** → stabilizzazione prima.
#   * Più **grande** → discesa rapida più lunga.
# * `tau` controlla **la gradualità**:
#
#   * piccolo (es. 1–2) → “ginocchio” netto,
#   * grande (es. 6–10) → transizione molto morbida.
# * `r_max` quanto “piatta” diventa la coda (sempre < 1).
#
# Se mi dai un tuo terzetto reale (`a1`, `n`, `S`) e un’idea di dove vuoi il “ginocchio” (`i0`), posso suggerirti valori iniziali sensati di `tau` e `r_max` per ottenere una forma più vicina a quella che hai in mente.

# %%
import numpy as np

def _sigmoid(x):
    return 1.0 / (1.0 + np.exp(-x))

def _build_ratios(n, i0, tau, r_min, r_max):
    """
    Costruisce r_i per i=1..n-1 (array di lunghezza n-1), crescente e < 1.
    i0: indice (1-based) del punto attorno a cui la transizione accelera verso r_max.
    """
    i = np.arange(1, n)  # i = 1..n-1
    # Transizione centrata su i0: quando i ~ i0 la logistica è ~0.5
    x = (i - i0) / tau
    return r_min + (r_max - r_min) * _sigmoid(x)

def _series_from_ratios(a1, ratios):
    """
    Dato a1 e ratios r_1..r_{n-1}, produce a_1..a_n con a_{k+1}=a_k*r_k.
    """
    n = len(ratios) + 1
    a = np.empty(n, dtype=float)
    a[0] = float(a1)
    for k in range(n - 1):
        a[k + 1] = a[k] * ratios[k]
    return a

def generate_stabilizing_geometric_series(
    a1, n, S,
    i0,
    tau=5.0,
    r_max=0.999,
    tol=1e-12,
    max_iter=200
):
    """
    Genera una serie decrescente a_1..a_n con ragione variabile r_i crescente (<1),
    calibrando r_min affinché sum(a)=S, dati a1,n,S,i0.

    Parametri:
      a1    : primo termine (positivo)
      n     : numero termini (>=2)
      S     : somma totale desiderata (>= a1, tipicamente)
      i0    : indice (1-based) del "punto di stabilizzazione" (tra 1 e n-1 consigliato)
      tau   : larghezza transizione (più grande = più graduale)
      r_max : limite superiore della ragione (deve essere < 1)
      tol   : tolleranza su somma
      max_iter: iterazioni bisezione

    Ritorna:
      a      : array (n,) dei termini
      ratios : array (n-1,) delle ragioni r_1..r_{n-1}
      r_min  : valore calibrato di r_min
    """
    a1 = float(a1)
    S = float(S)
    n = int(n)
    i0 = float(i0)
    tau = float(tau)
    r_max = float(r_max)

    if n < 2:
        raise ValueError("n deve essere >= 2.")
    if a1 <= 0:
        raise ValueError("a1 deve essere > 0 (serie decrescente positiva).")
    if not (0.0 < r_max < 1.0):
        raise ValueError("r_max deve essere in (0,1).")
    if tau <= 0:
        raise ValueError("tau deve essere > 0.")
    if S < a1:
        raise ValueError("S deve essere >= a1, perché la somma include almeno il primo termine.")

    # Funzione obiettivo: f(r_min) = sum(a(r_min)) - S
    def f(r_min):
        ratios = _build_ratios(n=n, i0=i0, tau=tau, r_min=r_min, r_max=r_max)
        a = _series_from_ratios(a1, ratios)
        return a.sum() - S

    # Intervallo per r_min: (eps, r_max-eps)
    eps = 1e-12
    lo = eps
    hi = r_max - eps
    if hi <= lo:
        raise ValueError("Intervallo non valido: r_max troppo vicino a 0 o 1.")

    flo = f(lo)
    fhi = f(hi)

    # Monotonia: all'aumentare di r_min, la serie decresce meno rapidamente => somma cresce => f cresce.
    # Serve quindi che S sia tra le somme ottenute ai due estremi.
    if flo > 0:
        # Anche con r_min quasi 0 la somma supera S => S troppo piccolo rispetto a a1 e alla forma.
        raise ValueError(
            "Somma S troppo piccola per i vincoli dati (a1, n, i0, tau, r_max). "
            "Prova a ridurre r_max o aumentare n."
        )
    if fhi < 0:
        # Anche con r_min vicino a r_max la somma resta sotto S => S troppo grande.
        raise ValueError(
            "Somma S troppo grande per i vincoli dati (a1, n, i0, tau, r_max). "
            "Prova ad aumentare r_max (restando <1) o aumentare tau / spostare i0."
        )

    # Bisezione
    for _ in range(max_iter):
        mid = 0.5 * (lo + hi)
        fmid = f(mid)
        if abs(fmid) <= tol:
            r_min_star = mid
            break
        if fmid > 0:
            hi = mid
        else:
            lo = mid
    else:
        r_min_star = 0.5 * (lo + hi)

    ratios = _build_ratios(n=n, i0=i0, tau=tau, r_min=r_min_star, r_max=r_max)
    a = _series_from_ratios(a1, ratios)

    # Piccola correzione numerica: garantiamo somma entro tolleranza (senza alterare a1).
    # Non forzo alcuna riscalatura perché a1 è vincolato.
    if abs(a.sum() - S) > 1e-8:
        # Se vuoi essere più permissivo, puoi alzare max_iter o ridurre tol.
        pass

    return a, ratios, r_min_star

"""
# --- ESEMPIO D'USO ---
if __name__ == "__main__":
    a1 = 100.0
    n = 40
    S = 550.0

    i0 = 10      # da ~qui inizia la stabilizzazione
    tau = 3.0    # quanto "dolce" la transizione
    r_max = 0.995

    a, r, r_min = generate_stabilizing_geometric_series(a1, n, S, i0, tau=tau, r_max=r_max)

    print("r_min calibrato =", r_min)
    print("Somma =", a.sum())
    print("Primi 12 termini:", np.round(a[:12], 6))
    print("Ultimi 5 termini:", np.round(a[-5:], 6))
"""
print("ready")
# Out:
# ready

# %% [markdown]
# ## 0 - 9

# %%
i0=4
tau=0.6
r_max=0.99 #0.95

a0_9, r, r_min = generate_stabilizing_geometric_series(a1, n, S, i0, tau=tau, r_max=r_max)
print("Ratios",r,"\nSeries",a0_9,"\nSum",a0_9.sum())
# Out:
# Ratios [0.1856841  0.20815616 0.30890659 0.58513233 0.86135807 0.96210851
#  0.98458056 0.98897081]
# Series [24000000.          4456418.50005627   927630.9547478    286551.31867276
#    167670.44166111   144424.28841818   138951.83664791   136809.27743488
#    135300.38236109]
# Sum 30393757.0

# %%
plt.figure()
plt.bar(range(1,len(a0_9)+1), a0_9)
# Out:
# <BarContainer object of 9 artists>

# %%
weighted_average(a0_9,1)
# Out:
# np.float64(1.3763245391191965)

# %%
S
# Out:
# 30393757

# %%
S*weighted_average(a0_9,1)
# Out:
# np.float64(41831673.595125854)

# %%
from shift_firms_preserve_ratios_monotone import shift_firms_preserve_ratios_monotone

# %%
f, achieved, info= shift_firms_preserve_ratios_monotone(a0_9,-41831673+48632916,1)
f
# Out:
# [np.float64(22092201.0),
#  np.float64(4989672.500056266),
#  np.float64(1288201.9547477965),
#  np.float64(477405.3186727624),
#  np.float64(323445.44166111085),
#  np.float64(305927.28841818456),
#  np.float64(305926.8366479119),
#  np.float64(305925.2774348757),
#  np.float64(305051.38236109226)]

# %%
a0_9=f

# %%
sum(a0_9)
# Out:
# np.float64(30393757.0)

# %%
weighted_average(a0_9,1)
# Out:
# np.float64(1.6000955918390034)

# %% [markdown]
# $\textcolor{red}{**********}$

# %%
plt.figure()
plt.bar(range(1,len(a0_9)+1), a0_9)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# ## 10 - 19

# %%
a0_9[-1]*(a0_9[-1]/a0_9[-2])
# Out:
# np.float64(304179.9836243437)

# %%
a10 = a0_9[-1]*(a0_9[-1]/a0_9[-2])
nn = 10
SS = 1037430
q10_19 = geometric_ratio_from_sum(a10, nn, SS, tol=1e-12)
print("q10_19 =", q10_19)
# Out:
# q10_19 = 0.7173788832474202

# %%
a10_19 = []
a = a10

for i in range(nn):
    a10_19.append(a)
    a *= q10_19

print(a10_19)
# Out:
# [np.float64(304179.9836243437), np.float64(218212.29695865023), np.float64(156540.89390305092), np.float64(112299.13165072356), np.float64(80561.02565325108), np.float64(57792.778616396026), np.float64(41459.31898359556), np.float64(29742.039952650353), np.float64(21336.311406732464), np.float64(15306.219249580927)]

# %%
sum(a10_19)
# Out:
# np.float64(1037429.9999989746)

# %%
plt.figure()
plt.bar(range(10,len(a10_19)+10), a10_19)
# Out:
# <BarContainer object of 10 artists>

# %%
weighted_average(a10_19,10)
# Out:
# np.float64(12.163804915497279)

# %%
SS
# Out:
# 1037430

# %%
SS*weighted_average(a10_19,10)
# Out:
# np.float64(12619096.133484341)

# %%
i0=5
tau=3. #0.6
r_max=0.99 #0.95

a10_19, r, r_min = generate_stabilizing_geometric_series(a10, nn, SS, i0, tau=tau, r_max=r_max)
print("Ratios",r,"\nSeries",a10_19,"\nSum",a10_19.sum())
# Out:
# Ratios [0.66446776 0.68928519 0.71820341 0.75036463 0.78432919 0.81829376
#  0.85045498 0.8793732  0.90419063]
# Series [304179.98362434 202117.79097175 139316.7990181  100057.80009039
#   75079.83432697  58887.30592164  48187.1147191   40980.97157248
#   36037.5681946   32584.83156062]
# Sum 1037430.0000000002

# %%
plt.figure()
plt.bar(range(10,len(a10_19)+10), a10_19)
# Out:
# <BarContainer object of 10 artists>

# %%
weighted_average(a10_19,10)
# Out:
# np.float64(12.441836244488407)

# %%
SS*weighted_average(a10_19,10)
# Out:
# np.float64(12907534.175119609)

# %%
f, achieved, info= shift_firms_preserve_ratios_monotone(a10_19,-12907534+13958529,10)
f
# Out:
# [np.float64(206911.9836243437),
#  np.float64(152992.79097174903),
#  np.float64(120683.79901809635),
#  np.float64(101007.8000903933),
#  np.float64(89281.83432696611),
#  np.float64(81461.30592164339),
#  np.float64(76204.11471909951),
#  np.float64(72507.97157248495),
#  np.float64(69774.5681946022),
#  np.float64(66603.83156062172)]

# %%
a10_19=f

# %%
plt.figure()
plt.bar(range(10,len(a10_19)+10), a10_19)
# Out:
# <BarContainer object of 10 artists>

# %%
weighted_average(a10_19,10)
# Out:
# np.float64(13.454911825491461)

# %% [markdown]
# $\textcolor{red}{**********}$

# %%
SS*weighted_average(a10_19,10)
# Out:
# np.float64(13958529.175119607)

# %% [markdown]
# ## 20 - 49

# %%
a10_19[-1]*(a10_19[-1]/a10_19[-2])
# Out:
# np.float64(63577.18139055208)

# %%
a20 = a10_19[-1]*(a10_19[-1]/a10_19[-2])
nnn = 30
SSS = 525408
q20_49 = geometric_ratio_from_sum(a20, nnn, SSS, tol=1e-12)
print("q20_49 =", q20_49)
# Out:
# q20_49 = 0.8817710281505242

# %%
a20_49 = []
a = a20

for i in range(nnn):
    a20_49.append(a)
    a *= q20_49

print(a20_49)
# Out:
# [np.float64(63577.18139055208), np.float64(56060.51660165949), np.float64(49432.53936249482), np.float64(43588.18105775832), np.float64(38434.79522651075), np.float64(33890.688903635244), np.float64(29883.82759928801), np.float64(26350.6933872972), np.float64(23235.27800059627), np.float64(20488.19497194903), np.float64(18065.896745363898), np.float64(15929.984347620733), np.float64(14046.598676623293), np.float64(12385.883757103913), np.float64(10921.513455054395), np.float64(9630.274148223098), np.float64(8491.696737050095), np.float64(7487.732162571114), np.float64(6602.465287506079), np.float64(5821.862604892382), np.float64(5133.549774867044), np.float64(4526.615463046405), np.float64(3991.43837089249), np.float64(3519.5347161013246), np.float64(3103.4237452281286), np.float64(2736.5091466165577), np.float64(2412.974483755396), np.float64(2127.6909914419757), np.float64(1876.136273110399), np.float64(1654.3226104910493)]

# %%
sum(a20_49)
# Out:
# np.float64(525407.999999301)

# %%
weighted_average(a20_49,20)
# Out:
# np.float64(26.753670701904124)

# %%
SSS*weighted_average(a20_49,20)
# Out:
# np.float64(14056592.616146041)

# %%
plt.figure()
plt.bar(range(20,len(a20_49)+20), a20_49)
# Out:
# <BarContainer object of 30 artists>

# %%
a20_49 = []
a = a20

for i in range(nnn):
    a20_49.append(a)
    a *= q20_49

print(a20_49)
# Out:
# [np.float64(63577.18139055208), np.float64(56060.51660165949), np.float64(49432.53936249482), np.float64(43588.18105775832), np.float64(38434.79522651075), np.float64(33890.688903635244), np.float64(29883.82759928801), np.float64(26350.6933872972), np.float64(23235.27800059627), np.float64(20488.19497194903), np.float64(18065.896745363898), np.float64(15929.984347620733), np.float64(14046.598676623293), np.float64(12385.883757103913), np.float64(10921.513455054395), np.float64(9630.274148223098), np.float64(8491.696737050095), np.float64(7487.732162571114), np.float64(6602.465287506079), np.float64(5821.862604892382), np.float64(5133.549774867044), np.float64(4526.615463046405), np.float64(3991.43837089249), np.float64(3519.5347161013246), np.float64(3103.4237452281286), np.float64(2736.5091466165577), np.float64(2412.974483755396), np.float64(2127.6909914419757), np.float64(1876.136273110399), np.float64(1654.3226104910493)]

# %%
sum(a20_49)
# Out:
# np.float64(525407.999999301)

# %%
weighted_average(a20_49,20)
# Out:
# np.float64(26.753670701904124)

# %%
SSS*weighted_average(a20_49,20)
# Out:
# np.float64(14056592.616146041)

# %%
plt.figure()
plt.bar(range(20,len(a20_49)+20), a20_49)
# Out:
# <BarContainer object of 30 artists>

# %%
a20_49 = []
a = a20

for i in range(nnn):
    a20_49.append(a)
    a *= q20_49

print(a20_49)
# Out:
# [np.float64(63577.18139055208), np.float64(56060.51660165949), np.float64(49432.53936249482), np.float64(43588.18105775832), np.float64(38434.79522651075), np.float64(33890.688903635244), np.float64(29883.82759928801), np.float64(26350.6933872972), np.float64(23235.27800059627), np.float64(20488.19497194903), np.float64(18065.896745363898), np.float64(15929.984347620733), np.float64(14046.598676623293), np.float64(12385.883757103913), np.float64(10921.513455054395), np.float64(9630.274148223098), np.float64(8491.696737050095), np.float64(7487.732162571114), np.float64(6602.465287506079), np.float64(5821.862604892382), np.float64(5133.549774867044), np.float64(4526.615463046405), np.float64(3991.43837089249), np.float64(3519.5347161013246), np.float64(3103.4237452281286), np.float64(2736.5091466165577), np.float64(2412.974483755396), np.float64(2127.6909914419757), np.float64(1876.136273110399), np.float64(1654.3226104910493)]

# %%
sum(a20_49)
# Out:
# np.float64(525407.999999301)

# %%
weighted_average(a20_49,20)
# Out:
# np.float64(26.753670701904124)

# %%
SSS*weighted_average(a20_49,20)
# Out:
# np.float64(14056592.616146041)

# %%
plt.figure()
plt.bar(range(20,len(a20_49)+20), a20_49)
# Out:
# <BarContainer object of 30 artists>

# %%
i0=5
tau=5. #3. #0.6
r_max=0.99 #0.95

a20_49, r, r_min = generate_stabilizing_geometric_series(a20, nnn, SSS, i0, tau=tau, r_max=r_max)
print("Ratios",r,"\nSeries",a20_49,"\nSum",a20_49.sum())
# Out:
# Ratios [0.80753658 0.8192565  0.83167734 0.84459666 0.85777524 0.87095382
#  0.88387315 0.89629398 0.9080139  0.91887857 0.92878649 0.93768762
#  0.94557734 0.95248755 0.95847684 0.96362103 0.96800502 0.97171638
#  0.97484065 0.97745825 0.97964264 0.98145948 0.98296644 0.98421351
#  0.98524356 0.98609301 0.98679264 0.98736825 0.98784141]
# Series [63577.18139055 51340.89972415 42061.36589187 34981.48478778
#  29545.24538274 25343.17998945 22072.73936956 19509.50157515
#  17486.24883871 15877.7570253  14589.73068524 13550.74476395
#  12706.36567228 12014.85149208 11443.99651374 10968.80567056
#  10569.77183245 10231.59220002  9942.20571496  9692.0662752
#   9473.59014734  9280.7328955   9108.66328118  8953.51029942
#   8812.16578486  8682.12954916  8561.38729898  8448.3139853
#   8341.59700188  8240.17496066]
# Sum 525407.9999999998

# %%
plt.figure()
plt.bar(range(20,len(a20_49)+20), a20_49)
# Out:
# <BarContainer object of 30 artists>

# %%
weighted_average(a20_49,20)
# Out:
# np.float64(29.16258825141087)

# %%
SSS*weighted_average(a20_49,20)
# Out:
# np.float64(15322257.167997282)

# %%
f, achieved, info= shift_firms_preserve_ratios_monotone(a20_49,-15322257+15876234,20)
f
# Out:
# [np.float64(55431.18139055208),
#  np.float64(45062.89972414806),
#  np.float64(37351.36589186623),
#  np.float64(31530.484787778107),
#  np.float64(27081.24538274212),
#  np.float64(23645.17998945469),
#  np.float64(20973.739369555293),
#  np.float64(18882.5015751466),
#  np.float64(17238.248838713862),
#  np.float64(15939.757025300081),
#  np.float64(14910.730685240998),
#  np.float64(14092.74476395279),
#  np.float64(13437.3656722831),
#  np.float64(12911.851492084452),
#  np.float64(12487.996513737922),
#  np.float64(12145.805670558668),
#  np.float64(11864.77183245255),
#  np.float64(11631.592200015391),
#  np.float64(11435.205714956714),
#  np.float64(11268.06627519907),
#  np.float64(11122.590147338151),
#  np.float64(10992.732895497911),
#  np.float64(10873.663281176456),
#  np.float64(10761.51029941849),
#  np.float64(10654.165784857549),
#  np.float64(10549.12954915937),
#  np.float64(10444.387298981776),
#  np.float64(10339.313985297307),
#  np.float64(10230.597001875454),
#  np.float64(10117.174960658538)]

# %%
a20_49=f

# %%
plt.figure()
plt.bar(range(20,len(a20_49)+20), a20_49)
# Out:
# <BarContainer object of 30 artists>

# %%
weighted_average(a20_49,20)
# Out:
# np.float64(30.216963137213902)

# %% [markdown]
# $\textcolor{red}{**********}$

# %%
SSS*weighted_average(a20_49,20)
# Out:
# np.float64(15876234.167997282)

# %% [markdown]
# ## 50 - 249

# %%
a20_49[-1]*(a20_49[-1]/a20_49[-2])
# Out:
# np.float64(10005.010378750345)

# %%
a50 = a20_49[-1]*(a20_49[-1]/a20_49[-2])
nnnn = 200
SSSS = 242846
q50_249 = geometric_ratio_from_sum(a50, nnnn, SSSS, tol=1e-12)
922945), np.float64(97.9053562148666), np.float64(93.87265005552389), np.float64(90.0060504259599), np.float64(86.29871542444786), np.float64(82.74408496611254), np.float64(79.3358691749386), np.float64(76.06803725391035), np.float64(72.9348068135887), np.float64(69.93063364024225), np.float64(67.05020188542758), np.float64(64.28841465965905), np.float64(61.64038501352395), np.float64(59.10142729028399), np.float64(56.66704883466195), np.float64(54.33294204314184), np.float64(52.0949767417162), np.float64(49.9491928775926), np.float64(47.8917935119276 ...

# %%
plt.figure()
plt.bar(range(50,len(a50_249)+50), a50_249)
# Out:
# <BarContainer object of 200 artists>

# %%
weighted_average(a50_249,50)
# Out:
# np.float64(73.23340291953009)

# %%
SSSS*weighted_average(a50_249,50)
# Out:
# np.float64(17784438.965396203)

# %%
i0=5
tau=20 #5. #3. #0.6
r_max=0.99 #0.95

a50_249, r, r_min = generate_stabilizing_geometric_series(a50, nnnn, SSSS, i0, tau=tau, r_max=r_max)
print("Ratios",r,"\nSeries",a50_249,"\nSum",a50_249.sum())
# Out:
# Ratios [0.92760145 0.92900915 0.93042212 0.93183863 0.93325691 0.9346752
#  0.93609171 0.93750468 0.93891238 0.94031309 0.94170511 0.94308681
#  0.9444566  0.94581294 0.94715436 0.94847945 0.94978689 0.95107543
#  0.9523439  0.95359122 0.95481639 0.95601851 0.95719677 0.95835043
#  0.95947887 0.96058154 0.96165798 0.96270782 0.96373076 0.96472661
#  0.96569523 0.96663656 0.96755061 0.96843745 0.96929723 0.97013013
#  0.97093641 0.97171636 0.97247033 0.97319869 0.97390187 0.97458031
#  0.97523449 0.97586492 0.97647212 0.97705663 0.97761902 0.97815985
#  0.9786797  0.97917915 0.9796588  0.98011924 0.98056105 0.98098482
#  0.98139115 0.9817806  0.98215375 0.98251116 0.9828534  0.983181
#  0.9834945  0.98379443 0.98408129 0.98435559 0.98461782 0.98486844
#  0.98510792 0.98533671 0.98555523 0.98576391 0.98596316 0.98615337
#  0.98633491 0.98650816 0.98667347 0.98683117 0.98698161 0.98712509
#  0.98726192 0.98739239 0.98751678 0.98763536 0.9877484  0.98785614
#  0.98795881 0.98805666 0.98814989 0.98823872 0.98832335 0.98840397
#  0.98848077 0.98855392 0.98862359 0.98868994 0.98875313 0.98881331
#  0.98887061 0.98892517 0.98897712 0.98902657 0.98907366 0.98911849
#  0.98916116 0.98920179 0.98924045 0.98927726 0.9893123  0.98934564
#  0.98937738 0.98940759 0.98943634 0.9894637  0.98948974 0.98951451
#  0.9895381  0.98956054 0.98958189 0.98960221 0.98962155 0.98963994
#  0.98965745 0.98967411 0.98968996 0.98970504 0.98971939 0.98973304
#  0.98974604 0.98975839 0.98977015 0.98978134 0.98979199 0.98980211
#  0.98981175 0.98982092 0.98982964 0.98983793 0.98984583 0.98985334
#  0.98986048 0.98986728 0.98987374 0.98987989 0.98988575 0.98989131
#  0.98989661 0.98990165 0.98990644 0.989911   0.98991534 0.98991946
#  0.98992339 0.98992712 0.98993067 0.98993405 0.98993727 0.98994033
#  0.98994323 0.989946   0.98994863 0.98995114 0.98995352 0.98995579
#  np.float64(258.8671190079089),
#  np.float64(256.27276298154356),
#  np.float64(253.70468191224467),
#  np.float64(251.16259372857425),
#  np.float64(248.64622030668372),
#  np.float64(246.15528736508313),
#  np.float64(243.68952436430328),
#  np.float64(241.24866441117695),
#  np.float64(238.83244416748164),
#  np.float64(236.44060376270102),
#  np.float64(234.0728867106764),
#  np.float64(231.72903982993338),
#  np.float64(229.40881316748008),
#  np.float64(227.1119599258866),
#  np.float64(224.83823639346525),
#  np.float64(222.58740187738218),
#  np.float64(220.35921863954056),
#  np.float64(218.1534518350846),
#  np.float64(215.96986945338307),
#  np.float64(213.80824226135786),
#  np.float64(211.6683437490325),
#  np.float64(209.54995007718117),
#  np.float64(207.45284002696698),
#  np.float64(205.37679495146338),
#  np.float64(203.32159872896003)]

# %%
a50_249=f

# %%
plt.figure()
plt.bar(range(50,len(a50_249)+50), a50_249)
# Out:
# <BarContainer object of 200 artists>

# %%
weighted_average(a50_249,50)
# Out:
# np.float64(98.828066436719)

# %% [markdown]
# $\textcolor{red}{**********}$

# %%
SSSS*weighted_average(a50_249,50)
# Out:
# np.float64(24000000.62189146)

# %% [markdown]
# ## 250 - more (i.e. 1850)

# %%
a50_249[-1]*(a50_249[-1]/a50_249[-2])
# Out:
# np.float64(201.28696876134438)

# %%
a250 = a50_249[-1]*(a50_249[-1]/a50_249[-2])
nnnnn = 1600
SSSSS = 52433
q250_1850 = geometric_ratio_from_sum(a250, nnnnn, SSSSS, tol=1e-12)
print("q250_1850 =", q250_1850)
# Out:
# q250_1850 = 0.9961693289301365

# %%
a250_1850 = []
a = a250

for i in range(nnnnn):
    a250_1850.append(a)
    a *= q250_1850

print(a250_1850[0],a250_1850[-1])
# Out:
# 201.28696876134438 0.4350591029548551

# %%
plt.figure()
plt.bar(range(250,len(a250_1850)+250), a250_1850)
# Out:
# <BarContainer object of 1600 artists>

# %%
weighted_average(a250_1850,250)
# Out:
# np.float64(506.5984601416803)

# %%
SSSSS*weighted_average(a250_1850,250)
# Out:
# np.float64(26562477.060608722)

# %%
i0=50
tau=100 #5. #3. #0.6
r_max=0.999 #0.95

a250_1850, r, r_min = generate_stabilizing_geometric_series(a250, nnnnn, SSSSS, i0, tau=tau, r_max=r_max)
print("Ratios",r[-1],"\nSeries",a250_1850[-1],"\nSum",a250_1850.sum())
# Out:
# Ratios 0.9989999973245258
# Series 10.112331988867806
# Sum 52433.00000000025

# %%
plt.figure()
plt.bar(range(250,len(a250_1850)+250), a250_1850)
# Out:
# <BarContainer object of 1600 artists>

# %%
weighted_average(a250_1850,250)
# Out:
# np.float64(723.4855703429569)

# %%
SSSSS*weighted_average(a250_1850,250)
# Out:
# np.float64(37934518.90979226)

# %%
f, achieved, info= shift_firms_preserve_ratios_monotone(a250_1850,-37934518+60000000,250)
f[-1]
# Out:
# np.float64(10.112331988867806)

# %%
a250_1850=f

# %%
plt.figure()
plt.bar(range(250,len(a250_1850)+250), a250_1850)
# Out:
# <BarContainer object of 1600 artists>

# %%
weighted_average(a250_1850,250)
# Out:
# np.float64(723.4855703429569)
