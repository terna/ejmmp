# %%
def f(b):
    print (b)

class Model:
    
    def __init__(self):
        self.a = [[0] * 2 for _ in range(3)]
        self.a[1][0]=131

    def exec(self):
        f(self.a[1])
        f(self.a[1][0])

m = Model()
m.exec()
# Out:
# [131, 0]
# 131
