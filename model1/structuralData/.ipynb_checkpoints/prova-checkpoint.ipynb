# %%
import numpy as np

def f(b):
    print (b)

class Model:
    
    def __init__(self):
        self.a = [[0] * 2 for _ in range(3)]
        self.a[1][0]=131

        self.A=np.array([[1,2,3],[4,5,6]])

    def exec(self):
        f(self.a[1])
        f(self.a[1][0])

        f(self.A[0,0])

m = Model()
m.exec()
# Out:
# [131, 0]
# 131
# 1
