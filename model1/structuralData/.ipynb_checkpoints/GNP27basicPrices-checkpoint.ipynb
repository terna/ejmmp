# %%
# !pip3 install matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
countryNames=['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia', 
              'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 
              'Hungary', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 
              'Malta', 'Netherlands', 'Poland', 'Portugal', 'Romania', 'Slovakia', 
              'Slovenia', 'Spain', 'Sweden', 'totEU27']

# %%
#year 2022 GNP current prices (with VAT)
#from https://ec.europa.eu/eurostat/databrowser/view/tec00001__custom_19176318/default/table
GDPcurrentPrices=[449382.2, 561309.1, 86079.5, 67609.4, 29645.4, 286976.8, 
                  380567.4, 36300.9, 266135.0, 2653997.2, 3989390.0, 207008.7,
                  168546.2, 520718.4, 1998072.6, 36088.7, 67081.1, 76731.2,
                  17985.1, 993820.0, 661712.3, 243957.1, 280777.4, 109959.8,
                  56881.6, 1375863.0, 547190.4, 16169786.6]

# %%
tot=0
for i in range(27):
    tot+=GDPcurrentPrices[i]
tot
# Out:
# 16169786.499999998

# %%
#in test_ff_multi 
GDP27currentPrices = 16144780 #difference due to update values; contains VAT
GDP27basicPrices   = 14303899 #from naio, so at basic prices, as intermediate products, as well
ratio= GDP27basicPrices/GDP27currentPrices

# %%
ratio
# Out:
# 0.8859767057835412

# %%
GDPbasicPrices=[]
for i in range(28):
    GDPbasicPrices.append(GDPcurrentPrices[i]*ratio)

print(GDPbasicPrices)
# Out:
# [398142.16119376046, 497306.7873443243, 76264.43184549433, 59900.35349200174, 26265.13383363539, 254254.75990030213, 337173.85138060723, 32161.75179897775, 235789.41059370272, 2351379.696414742, 3534506.6102858013, 183404.88609453334, 149328.0070483339, 461344.37267287634, 1770245.780064355, 31973.74754201048, 59432.29199833631, 67982.05580681805, 15934.379651187564, 880501.3697417988, 586261.6837304503, 216140.30781050594, 248762.23591046766, 97421.82137261704, 50395.77258769707, 1218982.5683494604, 484797.9480283782, 14326054.265090846]

# %%
sharesGDPbasicPrices=[0]*len(GDPbasicPrices)
for i in range(len(GDPbasicPrices)):
    sharesGDPbasicPrices[i]=GDPbasicPrices[i]/14257807
sharesGDPbasicPrices
# Out:
# [0.02792450207761688,
#  0.034879612786477214,
#  0.005348959475008627,
#  0.004201231892955329,
#  0.0018421580425121052,
#  0.0178326694911989,
#  0.023648366917900294,
#  0.00225572921550823,
#  0.01653756504024095,
#  0.1649187491747323,
#  0.24789973733588913,
#  0.012863470945744556,
#  0.010473420424917654,
#  0.032357316428317226,
#  0.12415975192148099,
#  0.0022425431584261507,
#  0.004168403457722237,
#  0.004768058356156599,
#  0.001117589798430261,
#  0.06175573633040473,
#  0.04111864354247819,
#  0.01515943565588354,
#  0.01744744026276044,
#  0.0068328755868709,
#  0.0035346089751177776,
#  0.08549579667823112,
#  0.0340022801562946,
#  1.0047866593432528]

# %%
GDPbasicPricesBySimulation =\
[334923, 380998, 178981, 99642, 44856, 506194, 298892, 65519, 
 250589, 1700545, 2991205, 306787, 314588, 221886, 1556951, 
 90205, 157354, 40499, 58191, 758925, 1022063, 449591, 549328, 
 201911, 57885, 1501142, 387433, 14527096]
# here above values 24.03 after computing the model in test_ff_multi with no adjustingCoefficient

"""
[423185, 554431, 64244, 51810, 35988, 361074, 463032, 45808, 308794,
 1957527, 3417495, 170418, 141315, 628326, 1616361, 47093, 98022, 
 81536, 48669, 977743, 523205, 276289, 260184, 118887, 39919, 1337555, 509749, 14558672]
# above computed with productivity indeces for agri and non-agri sectors (computing_productivity-ipynb) 24.03

-----------------------------------------------------------
    [
    313193,
    512928,
    69437,
    52381,
    27206,
    258283,
    376836,
    31030,
    280445,
    2425960,
    3641167,
    188773,
    143742,
    417219,
    1874019,
    33070,
    70078,
    57675,
    27330,
    871473,
    574781,
    214419,
    285523,
    117262,
    36703,
    1257047,
    441579,
    14599571

    ]

now 21.3 after eliminating while cycles

    [
    425766, 369395, 196580, 113945, 43305, 498299, 267434, 67907, 210688,
    1648266, 2903584, 298063, 326813, 245353, 1470735, 87213, 133449, 47736,
    33927, 766788, 1042478, 453200, 478602, 167748, 79480, 1455686, 425353,
    14257807
]
# old version

# current results 21.01 (after new method of computing labor)


    [
    477847, 366183, 233902, 131827, 49152, 436814, 302768,
    55335, 194907, 1625024, 3004102, 311654, 306574,
    231891, 1539759, 68659, 135637, 33915, 21372,
    816799, 1073939, 457265, 574046, 178924, 61477,
    1392974, 376987, 14459746
    ]


['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia', 
              'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 
              'Hungary', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 
              'Malta', 'Netherlands', 'Poland', 'Portugal', 'Romania', 'Slovakia', 
              'Slovenia', 'Spain', 'Sweden', 'totEU27']
"""
# Out:
# "\n[423185, 554431, 64244, 51810, 35988, 361074, 463032, 45808, 308794,\n 1957527, 3417495, 170418, 141315, 628326, 1616361, 47093, 98022, \n 81536, 48669, 977743, 523205, 276289, 260184, 118887, 39919, 1337555, 509749, 14558672]\n\n# above computed with productivity indeces for agri and non-agri sectors (computing_productivity-ipynb) 24.03\n    [\n    313193,\n    512928,\n    69437,\n    52381,\n    27206,\n    258283,\n    376836,\n    31030,\n    280445,\n    2425960,\n    3641167,\n    188773,\n    143742,\n    417219,\n    1874019,\n    33070,\n    70078,\n    57675,\n    27330,\n    871473,\n    574781,\n    214419,\n    285523,\n    117262,\n    36703,\n    1257047,\n    441579,\n    14599571\n\n    ]\n\nnow 21.3 after eliminating while cycles\n\n    [\n    425766, 369395, 196580, 113945, 43305, 498299, 267434, 67907, 210688,\n    1648266, 2903584, 298063, 326813, 245353, 1470735, 87213, 133449, 47736,\n    33927, 766788, 1042478, 453200, 478602, 167748, 79480, 1455686, 425353,\n    14257807\n]\n# old version\n\n# current results 21.01 (after new method of computing labor)\n\n\n    [\n    477847, 366183, 233902, 131827, 49152, 436814, 302768,\n    55335, 194907, 1625024, 3004102, 311654, 306574,\n    231891, 1539759, 68659, 135637, 33915, 21372,\n    816799, 1073939, 457265, 574046, 178924, 61477,\n    1392974, 376987, 14459746\n    ]\n\n\n['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia', \n              'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', \n              'Hungary', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', \n              'Malta', 'Netherlands', 'Poland', 'Portugal', 'Romania', 'Slovakia', \n              'Slovenia', 'Spain', 'Sweden', 'totEU27']\n"

# %%
sharesGDPbasicPricesBySimulation=[0]*len(GDPbasicPricesBySimulation)
for i in range(len(GDPbasicPricesBySimulation)):
    sharesGDPbasicPricesBySimulation[i]=GDPbasicPricesBySimulation[i]/14527096
sharesGDPbasicPricesBySimulation
# Out:
# [0.023055055187905415,
#  0.026226714547766462,
#  0.012320494061579822,
#  0.00685904464319641,
#  0.0030877472001286425,
#  0.0348448168856322,
#  0.02057479347558521,
#  0.004510123702631276,
#  0.017249765541578303,
#  0.11706021630200558,
#  0.20590522703229883,
#  0.021118260662695423,
#  0.021655257182853337,
#  0.015273940504007133,
#  0.1071756530004345,
#  0.0062094309833155914,
#  0.010831758804374942,
#  0.002787824903201576,
#  0.004005687027882242,
#  0.052242031029463835,
#  0.07035563060917337,
#  0.03094844282711424,
#  0.03781402697414542,
#  0.013898923776644692,
#  0.003984622941846051,
#  0.10333393542659867,
#  0.026669679886468706,
#  1.0]

# %% [raw]
# plt.bar(countryNames[0:27], GDPbasicPrices[0:27])
# plt.bar(countryNames[0:27], GDPbasicPricesBySimulation[0:27])
# plt.xticks(rotation=90);

# %%
x = np.arange(len(countryNames[0:28]))
width = 0.35
fig, ax = plt.subplots()
ax.bar(x - width/2, GDPbasicPrices[0:28], width, label='GDPbasicPrices')
ax.bar(x + width/2, GDPbasicPricesBySimulation[0:28], width, label='GDPbasicPricesBySimulation')
ax.set_ylabel("GDP")
ax.set_xticks(x)
ax.set_xticklabels(countryNames[0:28],rotation=75)
plt.legend()
plt.tight_layout()

# %%
x = np.arange(len(countryNames[0:27]))
width = 0.35
fig, ax = plt.subplots()
ax.bar(x - width/2, GDPbasicPrices[0:27], width, label='GDPbasicPrices')
ax.bar(x + width/2, GDPbasicPricesBySimulation[0:27], width, label='GDPbasicPricesBySimulation')
ax.set_ylabel("GDP")
ax.set_xticks(x)
ax.set_xticklabels(countryNames[0:27],rotation=75)
plt.legend()
plt.tight_layout()

# %%
df = pd.DataFrame({
    "country": countryNames,
    "GDP basic prices": GDPbasicPrices,
    "sim GDP basic prices": GDPbasicPricesBySimulation
})
df['adj. coeff'] = np.array(GDPbasicPrices) / np.array(GDPbasicPricesBySimulation)
adjustmentCoefficient = np.array(GDPbasicPrices) / np.array(GDPbasicPricesBySimulation)
adjustmentCoefficient
# Out:
# array([1.1887573 , 1.30527401, 0.42610351, 0.60115567, 0.58554338,
#        0.50228719, 1.12807921, 0.49087672, 0.94094079, 1.38272124,
#        1.18163302, 0.59782483, 0.47467801, 2.0791955 , 1.13699518,
#        0.35445649, 0.37769801, 1.67861073, 0.27382894, 1.1601955 ,
#        0.57360621, 0.48074874, 0.45284827, 0.48249883, 0.87061886,
#        0.81203681, 1.25130783, 0.98616091])

# %%
share_df = pd.DataFrame({
    "country": countryNames,
    "GDP basic prices": sharesGDPbasicPrices,
    "sim GDP basic prices": sharesGDPbasicPricesBySimulation
})
df['adj. coeff'] = np.array(sharesGDPbasicPrices) / np.array(sharesGDPbasicPricesBySimulation)
share_adjustmentCoefficient = np.array(sharesGDPbasicPrices) / np.array(sharesGDPbasicPricesBySimulation)
share_adjustmentCoefficient
# Out:
# array([1.21120951, 1.32992689, 0.43415138, 0.61250978, 0.59660261,
#        0.51177395, 1.14938538, 0.50014797, 0.95871245, 1.40883687,
#        1.20395068, 0.60911602, 0.48364332, 2.11846553, 1.15846975,
#        0.36115115, 0.38483164, 1.71031486, 0.27900078, 1.18210826,
#        0.58443998, 0.4898287 , 0.46140128, 0.49161185, 0.88706235,
#        0.82737386, 1.27494144, 1.00478666])

# %%
# in newGDPsim the adjustingCoefficient is applied upon labor and capital
# these values come from applying the adjustments in test ff and for this reason we copied the vector of the results for quickness 

newGDPsim = [
    446844, 492983, 90744, 69301, 29811, 222882, 381722, 26207,
    218129, 2318224, 3656867, 191767, 140080, 436032, 1853327,
    25171, 60406, 48300, 10038, 937929, 603954, 218079, 298371,
    103912, 38980, 1166468, 429673, 14516213
]

df['new GDP sim'] =  newGDPsim


# in newGDPsim2 the adjustingCoefficient is applied upon capital R and wage

newGDPsim2 = [
    446844, 492983, 90744, 69301, 29811, 222882, 381722, 26207,
    218129, 2318224, 3656867, 191767, 140080, 436032, 1853327,
    25171, 60406, 48300, 10038, 937929, 603954, 218079, 298371,
    103912, 38980, 1166468, 429673, 14516213
]

df['new GDP sim 2'] = newGDPsim2

newGDPsim3 = [398142, 497307, 76264, 59900, 26265, 254255, 337174, 32161, 235790, 2351380, 3534507, 183404, 149328, 461345, 1770246, 31973, 59432, 67982, 15934, 880502, 586262, 216140, 248762, 97421, 50395, 1218982, 484798, 14326066]

df['new GDP sim 3'] = newGDPsim3

df
# Out:
#         country  GDP basic prices  sim GDP basic prices  adj. coeff  \
# 0       Austria      3.981422e+05                334923    1.211210
# 1       Belgium      4.973068e+05                380998    1.329927
# 2      Bulgaria      7.626443e+04                178981    0.434151
# 3       Croatia      5.990035e+04                 99642    0.612510
# 4        Cyprus      2.626513e+04                 44856    0.596603
# 5       Czechia      2.542548e+05                506194    0.511774
# 6       Denmark      3.371739e+05                298892    1.149385
# 7       Estonia      3.216175e+04                 65519    0.500148
# 8       Finland      2.357894e+05                250589    0.958712
# 9        France      2.351380e+06               1700545    1.408837
# 10      Germany      3.534507e+06               2991205    1.203951
# 11       Greece      1.834049e+05                306787    0.609116
# 12      Hungary      1.493280e+05                314588    0.483643
# 13      Ireland      4.613444e+05                221886    2.118466
# 14        Italy      1.770246e+06               1556951    1.158470
# 15       Latvia      3.197375e+04                 90205    0.361151
# 16    Lithuania      5.943229e+04                157354    0.384832
# 17   Luxembourg      6.798206e+04                 40499    1.710315
# 18        Malta      1.593438e+04                 58191    0.279001
# 19  Netherlands      8.805014e+05                758925    1.182108
# 20       Poland      5.862617e+05               1022063    0.584440
# 21     Portugal      2.161403e+05                449591    0.489829
# 22      Romania      2.487622e+05                549328    0.461401
# 23     Slovakia      9.742182e+04                201911    0.491612
# 24     Slovenia      5.039577e+04                 57885    0.887062
# 25        Spain      1.218983e+06               1501142    0.827374
# 26       Sweden      4.847979e+05                387433    1.274941
# 27      totEU27      1.432605e+07              14527096    1.004787
#
#     new GDP sim  new GDP sim 2  new GDP sim 3
# 0        446844         446844         398142
# 1        492983         492983         497307
# 2         90744          90744          76264
# 3         69301          69301          59900
# 4         29811          29811          26265
# 5        222882         222882         254255
# 6        381722         381722         337174
# 7         26207          26207          32161
# 8        218129         218129         235790
# 9       2318224        2318224        2351380
# 10      3656867        3656867        3534507
# 11       191767         191767         183404
# 12       140080         140080         149328
# 13       436032         436032         461345
# 14      1853327        1853327        1770246
# 15        25171          25171          31973
# 16        60406          60406          59432
# 17        48300          48300          67982
# 18        10038          10038          15934
# 19       937929         937929         880502
# 20       603954         603954         586262
# 21       218079         218079         216140
# 22       298371         298371         248762
# 23       103912         103912          97421
# 24        38980          38980          50395
# 25      1166468        1166468        1218982
# 26       429673         429673         484798
# 27     14516213       14516213       14326066

# %%
x = np.arange(len(countryNames[0:27]))
width = 0.35
fig, ax = plt.subplots()
ax.bar(x - width/2, GDPbasicPrices[0:27], width, label='GDPbasicPrices')
ax.bar(x + width/2, newGDPsim3[0:27], width, label='GDPbasicPricesBySimulation')
ax.set_ylabel("GDP")
ax.set_xticks(x)
ax.set_xticklabels(countryNames[0:27],rotation=75)
plt.legend()
plt.tight_layout()

# %%
x = np.arange(len(countryNames[0:27]))
width = 0.35
fig, ax = plt.subplots()
ax.bar(x - width/2, GDPbasicPrices[0:27], width, label='GDPbasicPrices')
ax.bar(x + width/2, newGDPsim2[0:27], width, label='GDPbasicPricesBySimulation')
ax.set_ylabel("GDP")
ax.set_xticks(x)
ax.set_xticklabels(countryNames[0:27],rotation=75)
plt.legend()
plt.tight_layout()
