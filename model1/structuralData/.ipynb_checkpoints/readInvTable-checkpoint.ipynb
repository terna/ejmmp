# %%
import pandas as pd

# %%
invTable = pd.read_pickle('./invTableNoNama.xp')

# %%
invTable
# Out:
#                                               sectors  \
# 1   Crop and animal production, hunting and relate...
# 2                                Forestry and logging
# 3                             Fishing and aquaculture
# 4                                Mining and quarrying
# 5   Manufacture of food products; beverages and to...
# ..                                                ...
# 61             Activities of membership organisations
# 62  Repair of computers and personal and household...
# 63                  Other personal service activities
# 64  Activities of households as employers; undiffe...
# 65  Activities of extraterritorial organisations a...
#
#     Products of agriculture, hunting and related services  \
# 1                                            0.002242
# 2                                            0.002242
# 3                                            0.002242
# 4                                            0.002242
# ...

# %%
#print(invTable.iloc[[44]])
