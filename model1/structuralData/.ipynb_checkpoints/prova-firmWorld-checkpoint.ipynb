# %% [raw]
# import pickle
#
# data = [f.__dict__ for f in firms]
#
# with open("firms.pkl", "wb") as f:
#     pickle.dump(data, f)

# %% [raw]
# import pickle
#
# with open("firms.pkl", "rb") as f:
#     data = pickle.load(f)
#
# firms = [Firm(**d) for d in data]

# %%
import pickle

with open("firmWorld.xp", "rb") as f:
    data = pickle.load(f)

firms = [Firm(**d) for d in data]
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pickle
#       3 with open("firmWorld.xp", "rb") as fileF:
# ----> 4     data = pickle.load(fileF)
#       6 firms = [Firm(**d) for d in data]
#
# EOFError: Ran out of input
