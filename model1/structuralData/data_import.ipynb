# %% [markdown]
# Here we import and prepare two datasets containing the relevant info about data on sector size (naio.xlsx) and about employment per sector (sbs.xlsx). Datasets are in excel format (as provided by EUROSTAT), and required some manipulation to be clean.
# We had to:
# - exclude some initial rows containing info not relevant for the model and negatively affecting the format of our data,
# - reset the index to have dataset with indexes starting from 0 (to be done twice because of the header)
# - drop NaN and invalid characters
# - reattribute correctly column names (i.e. headers)
# - exclude the inital rows with empty values and headers (once setted at their correct place)

# %% [raw]
# !pip install openpyxl

# %%
# %%javascript
# // to avoid scroll in windows
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import csv
import pandas as pd
import numpy as np
#pd.set_option('future.no_silent_downcasting', True)

# %%
naio = pd.read_excel('naio.xlsx', sheet_name = 'Sheet1')
#pd.set_option('display.max_rows', 1000)
naio = naio.iloc[9:93]
naio = naio.reset_index(drop=True)
naio = naio.dropna(axis=1, how='all')
naio = naio.loc[:, (naio != ":").any()]
naio.columns=naio.iloc[0,:]
naio=naio.drop(index=[0,1]) #empty values for all the row
naio = naio.reset_index(drop=True)

naio
# Out:
# 0                                    IND_USE (Labels)        Total
# 0                                               Total  16939701.18  \
# 1   Products of agriculture, hunting and related s...    381871.38
# 2   Products of forestry, logging and related serv...     42864.37
# 3   Fish and other fishing products; aquaculture p...     10980.08
# 4                                Mining and quarrying    337295.56
# ..                                                ...          ...
# 77                           Intermediate consumption  17369689.89
# 78          Total intermediate consumption /final use  17369689.89
# 79                     Cif/fob adjustments on exports            0
# 80                       Consumption of fixed capital            0
# 81                           Use of imported products   2153475.82
#
# 0  Manufacture of food products; beverages and tobacco products
# 0                                           983256.48            \
# 1                                           267542.11
# 2                                              312.45
# 3                                             6627.63
# 4                                             2658.86
# ..                                                ...
# 77                                          990067.83
# 78                                          990067.83
# 79                                                  0
# 80                                                  0
# 81                                          103873.44
#
# 0  Manufacture of textiles, wearing apparel, leather and related products
# 0                                           149771.07                      \
# 1                                             3881.34
# 2                                               10.71
# 3                                                7.25
# 4                                              193.46
# ..                                                ...
# 77                                          151365.61
# 78                                          151365.61
# 79                                                  0
# 80                                                  0
# 81                                           32814.61
#
# 0  Manufacture of furniture; other manufacturing
# 0                                      175134.17  \
# 1                                         130.82
# 2                                         922.93
# 3                                            8.8
# 4                                         674.16
# ..                                           ...
# 77                                     177003.65
# 78                                     177003.65
# 79                                             0
# 80                                             0
# 81                                      29229.35
#
# 0  Sewerage, waste management, remediation activities
# 0                                           171307.78  \
# 1                                               61.35
# 2                                               10.99
# 3                                                 4.5
# 4                                              473.93
# ..                                                ...
# 77                                          176732.77
# 78                                          176732.77
# 79                                                  0
# 80                                                  0
# 81                                           12357.78
#
# 0  Motion picture, video, television programme production; programming and broadcasting activities
# 0                                            95966.37                                               \
# 1                                               31.28
# 2                                                2.71
# 3                                                4.62
# 4                                               15.35
# ..                                                ...
# 77                                           96894.01
# 78                                           96894.01
# 79                                                  0
# 80                                                  0
# 81                                           14093.13
#
# 0  Computer programming, consultancy, and information service activities
# 0                                           496191.44                     \
# 1                                                10.5
# 2                                                0.31
# 3                                                 8.9
# 4                                               32.83
# ..                                                ...
# 77                                           500556.3
# 78                                           500556.3
# 79                                                  0
# 80                                                  0
# 81                                           95126.51
#
# 0  Imputed rents of owner-occupied dwellings
# 0                                          :  \
# 1                                          :
# 2                                          :
# 3                                          :
# 4                                          :
# ..                                       ...
# 77                                         :
# 78                                         :
# 79                                         :
# 80                                         :
# 81                                         :
#
# 0  Real estate activities excluding imputed rents  ...
# 0                                       443570.91  ...  \
# 1                                           71.09  ...
# 2                                           17.07  ...
# 3                                            5.34  ...
# 4                                           291.5  ...
# ..                                            ...  ...
# 77                                       472807.3  ...
# 78                                       472807.3  ...
# 79                                              0  ...
# 80                                              :  ...
# 81                                       13780.09  ...
#
# 0  Gross capital formation
# 0               3680502.16  \
# 1                 17919.23
# 2                 11542.35
# 3                    10.29
# 4                  3949.72
# ..                     ...
# 77              3680502.16
# 78              3680502.16
# 79                       0
# 80                       :
# 81                       :
#
# 0  Changes in inventories and acquisition less disposals of valuables
# 0                                           360243.46                  \
# 1                                            10474.61
# 2                                            11085.96
# 3                                              -45.88
# 4                                             2681.28
# ..                                                ...
# 77                                          366033.71
# 78                                          366033.71
# 79                                                  0
# 80                                                  :
# 81                                          109598.17
#
# 0  Exports of goods and services Exports to EU members states
# 0                     3291159.74                            :  \
# 1                       30647.16                            :
# 2                        2148.11                            :
# 3                         575.75                            :
# 4                       10117.36                            :
# ..                           ...                          ...
# 77                    3291159.74                            :
# 78                    3291159.74                            :
# 79                             0                            :
# 80                             :                            :
# 81                             :                            :
#
# 0  Exports to non-member of the EU Exports to members of the euro area
# 0                       3291159.74                                   :  \
# 1                         30647.16                                   :
# 2                          2148.11                                   :
# 3                           575.75                                   :
# 4                         10117.36                                   :
# ..                             ...                                 ...
# 77                      3291159.74                                   :
# 78                      3291159.74                                   :
# 79                               :                                   :
# 80                               :                                   :
# 81                               :                                   :
#
# 0  Exports to non-members of the euro area Gross fixed capital formation
# 0                                        :                     3320258.7  \
# 1                                        :                       7444.62
# 2                                        :                        456.39
# 3                                        :                         56.16
# 4                                        :                       1268.44
# ..                                     ...                           ...
# 77                                       :                    3566539.64
# 78                                       :                    3566539.64
# 79                                       :                             0
# 80                                       :                             :
# 81                                       :                        322845
#
# 0     Total use Total final use
# 0   34779463.55     17839762.37
# 1     574835.97       192964.59
# 2      64969.36        22104.99
# 3      22289.98         11309.9
# 4     364123.89        26828.33
# ..          ...             ...
# 77  34867131.65     17927430.47
# 78  34779463.55     17839762.37
# 79            0               0
# 80            :               :
# 81            :               :
#
# [82 rows x 29 columns]

# %%
sbs = pd.read_excel('sbs.xlsx', sheet_name = 'Sheet 1')
#pd.set_option('display.max_rows', 1000)
#sbs = sbs.drop(index=9) #empty values for all the row
sbs = sbs.iloc[8:26]
sbs = sbs.reset_index(drop=True)
sbs = sbs.replace(":", np.nan)
sbs = sbs.replace("e", np.nan) #e = estimated
sbs = sbs.replace("c", np.nan) #c = confidential
sbs.columns=sbs.iloc[0,:]
sbs = sbs.dropna(axis=1,how='all')
sbs = sbs.drop(index=[0,1]) #empty values for all the row
sbs = sbs.reset_index(drop=True)

sbs
# Out:
# 0                                   SIZE_EMP (Labels)     Total
# 0                                Mining and quarrying    371000  \
# 1                                       Manufacturing  30007527
# 2   Electricity, gas, steam and air conditioning s...   1380000
# 3   Water supply; sewerage, waste management and r...   1585225
# 4                                        Construction  13814274
# 5   Wholesale and retail trade; repair of motor ve...  29779934
# 6                          Transportation and storage  10368577
# 7           Accommodation and food service activities  10888928
# 8                       Information and communication   7169884
# 9                  Financial and insurance activities   4950777
# 10                             Real estate activities   2674967
# 11  Professional, scientific and technical activities  12013424
# 12      Administrative and support service activities  13987371
# 13                                          Education   2453280
# 14            Human health and social work activities  13308561
# 15                 Arts, entertainment and recreation   2192933
#
# 0  From 0 to 1 person employed From 0 to 9 persons employed
# 0                          NaN                        30000  \
# 1                          NaN                      3720000
# 2                          NaN                       192263
# 3                          NaN                       134000
# 4                      2292700                      6463861
# 5                      2869697                     10159638
# 6                       795843                      2132860
# 7                       670000                      4500000
# 8                       839595                      1694054
# 9                          NaN                       912551
# 10                      732689                      1703331
# 11                     3268760                      6306152
# 12                     1054559                      2443205
# 13                      572741                      1074485
# 14                     1528116                      3417453
# 15                      532163                      1018050
#
# 0  From 2 to 9 persons employed From 10 to 19 persons employed
# 0                           NaN                          24400  \
# 1                           NaN                        2130000
# 2                           NaN                          26554
# 3                           NaN                          80000
# 4                       4171161                        1989977
# 5                       7289941                        2867238
# 6                       1337017                         778285
# 7                       3800000                        1850000
# 8                        854459                         458755
# 9                           NaN                            NaN
# 10                       970642                         204985
# 11                      3037392                        1085161
# 12                      1388646                         730461
# 13                       501744                         221804
# 14                      1889337                         944000
# 15                       485887                         203295
#
# 0  From 20 to 49 persons employed From 50 to 249 persons employed
# 0                           38600                           63848  \
# 1                         3137995                         6501120
# 2                           48700                          137668
# 3                          150000                          370000
# 4                         1869881                         1756785
# 5                         3099214                         4100000
# 6                         1090577                         1605824
# 7                         1570000                         1421984
# 8                          648890                         1252840
# 9                          177248                          494777
# 10                         198000                          271677
# 11                        1100000                         1360181
# 12                        1093974                         2313468
# 13                         290962                          417229
# 14                         994469                         1780000
# 15                         247350                          314087
#
# 0  250 persons employed or more
# 0                        213000
# 1                      14514113
# 2                        977247
# 3                           NaN
# 4                       1733772
# 5                       9600000
# 6                       4761030
# 7                       1570000
# 8                       3115346
# 9                           NaN
# 10                          NaN
# 11                      2200000
# 12                      7406264
# 13                       448801
# 14                      6169122
# 15                       410147

# %%
naio.to_pickle("./naio.p")

# %%
sbs.to_pickle("./sbs.p")
