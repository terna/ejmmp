# %% [markdown]
# ### test ff
# Powered by [Eleonora Priori](https://www.ecoaz.unito.it/do/docenti.pl/Alias?eleonora.priori#tab-profilo) and [Pietro Terna](https://terna.to.it/)

# %%
from mpi4py import MPI
from repast4py import context as ctx
import repast4py 
from repast4py import parameters
from repast4py import schedule
from repast4py import core
from typing import Tuple, List, Dict
import numpy as np
import pandas as pd
import pickle
import csv
import os
import sys
import time
import sectors

comm = MPI.COMM_WORLD
rank    = comm.Get_rank()
rankNum = comm.Get_size() 

# create the context to hold the agents and manage cross process
# synchronization
context = ctx.SharedContext(comm)

# Initialize the default schedule runner, HERE to create the t() function,
# returning the tick value
runner = schedule.init_schedule_runner(comm)



#generate random seed
repast4py.random.init(rng_seed=12345)
rng = repast4py.random.default_rng 

#timer T()
startTime=-1
def T():
    global startTime
    if startTime < 0:
        startTime=time.time()
    return time.time() - startTime
T() #launches the timer

#cpuTimer Tc()
startCpuTime=-1
def Tc():
    global startCpuTime
    if startCpuTime < 0:
        startCpuTime=time.process_time()
    return time.process_time() - startCpuTime
Tc() #launches the cpu timer

#read control key from firm-features-generarion
with open("control4text_ff.txt", "r") as f:
    control = int(f.read())

# %%
class Firm(core.Agent):

    TYPE = 0
    
    def __init__(self, local_id: int, rank: int, sector: int, labor: int, capital: float, capitalR: float, wage: float,\
                 intermediate: list, country: int): 
                 #, minOrderDuration:int,\
                 #maxOrderDuration:int, recipe: float, laborProductivity: float, maxOrderProduction: float,\
                 #assetsUsefulLife: float, plannedMarkup: float, orderObservationFrequency: int, productionType: int,\
                 #sectorialClass: int):
        super().__init__(id=local_id, type=Firm.TYPE, rank=rank) #uid

        self.sector=sector
        self.labor=labor
        self.capital=capital
        self.capitalR=capitalR
        self.wage=wage
        self.intermediate = intermediate
        self.country = country
        #self.investment = investment
    
        """
        self.unavailableLabor=0
        self.unavailableCapital=0
        self.minOrderDuration=minOrderDuration
        self.maxOrderDuration=maxOrderDuration
        self.recipe = recipe
        self.laborProductivity=laborProductivity
        self.maxOrderProduction=maxOrderProduction
        self.assetsUsefulLife=assetsUsefulLife
        self.plannedMarkup=plannedMarkup
        self.orderObservationFrequency=orderObservationFrequency
        self.productionType=productionType
        self.sectorialClass=sectorialClass 
        """

# %%
def statistics(y_true, y_est):

    y_true = np.array(y_true)
    y_est  = np.array(y_est)

    n = y_true.shape[0]
    
    #MAE, Mean Absolute Error
    # $ MAE = \frac{1}{n}\sum_{i=1}^n | yi - \hat{y}_i | $
    mae = abs(y_true - y_est).mean()

    # RMSE, Root Mean Squared Error
    # $ RMSE = \sqrt{\frac{1}{n}\sum_{i=1}^n ( y_i - \hat{y}_i )^2} $
    rmse = (((y_true - y_est)**2).sum()/n)**0.5

    # MAPE, Mean Absolute Percentage Error
    # $ MAPE = \frac{100}{n}\sum_{i=1}^n \left| \frac{y_i - \hat{y}_i}{y_i} \right| $
    safeDiv = np.where(y_true == 0, 0.000001, 0)
    mape = (abs((y_true - y_est) / (y_true+safeDiv)).sum()) * 100 / n

    # R², coefficient of determination
    # $ R^2 = 1 - \frac{\sum (y_i - \hat{y}_i)^2}{\sum (y_i - \bar{y})^2} $
    if ((y_true - y_true.mean())**2).sum() == 0: r2 = 0
    else: r2 = 1 - (((y_true - y_est)**2).sum()/((y_true - y_true.mean())**2).sum())**0.5

    return (mae,rmse,mape,r2,n)  #,rmse, mape,r2,count)

# %% [markdown]
#
#
# $ MAE = \frac{1}{n}\sum_{i=1}^n | yi - \hat{y}_i | $
#
# $ RMSE = \sqrt{\frac{1}{n}\sum_{i=1}^n ( y_i - \hat{y}_i )^2} $
#
# $ MAPE = \frac{100}{n}\sum_{i=1}^n \left| \frac{y_i - \hat{y}_i}{y_i} \right| $
#
# $ R^2 = 1 - \frac{\sum (y_i - \hat{y}_i)^2}{\sum (y_i - \bar{y})^2} $

# %%
def stop_execution(message):
    print(message)
    raise SystemExit(0)

# %% [markdown]
# $ MAE = \frac{1}{n}\sum_{i=1}^n | yi - \hat{y}_i | $
#
# $ RMSE = \sqrt{\frac{1}{n}\sum_{i=1}^n ( y_i - \hat{y}_i )^2} $
#
# $ MAPE = \frac{100}{n}\sum_{i=1}^n \left| \frac{y_i - \hat{y}_i}{y_i} \right| $
#
# $ R^2 = 1 - \frac{\sum (y_i - \hat{y}_i)^2}{\sum (y_i - \bar{y})^2} $

# %%
class Model:
    
    def __init__(self):
        
      
        runner.schedule_repeating_event(0.0,  1, self.interactingWithFirms)

        runner.schedule_stop(0)
        runner.schedule_end_event(self.finish)
        
        ####################################################################################################
        ###################################### CREATE FIRM AGENTS ##########################################
        ####################################################################################################

        
        with open('naio_io_N.xp', 'rb') as f:
            intermediateInputs = pickle.load(f) #numpy array, only numeric, see last row of firm-features-generation.ipynb
                                                #eliminating nan in col 43 (used), not in 64 (never used)
            
        #firm investment shares
        nama = 3
        while nama != 0 and nama != 1 and nama != 2:
            nama = int(input("What table of investment shares? "+\
                             "Please, use only 0/1/2 to chose invTableNoNama (0) or invTableNama (1) or invTableNamaIPF (2)"))
            if nama != 0 and nama != 1 and nama != 2: 
                print("Please, use only 1/0 to express yes/no values")

        if nama==0: self.invShares = pd.read_pickle("./invTableNoNama.xp") #ignoring nama infos
        if nama==1: self.invShares = pd.read_pickle("./invTableNama.xp")   #using nama infos
        if nama==2: self.invShares = pd.read_pickle("./invTableNamaIPF.xp")   #using nama infos

        self.invSharesNp = self.invShares.to_numpy()
        #print(self.invSharesNp)

        #65 rows x 66 columns
        #print (self.invShares)
        #print (self.invShares.iloc[0,0]) #Crop
        #print (self.invShares.iloc[1,0]) #Forest
        #print (self.invShares.iloc[0,1]) #0.002242 values for invTableNoNama (here and following)
        #print (self.invShares.iloc[1,1]) #0.002242
        #print (self.invShares.iloc[0,2]) #0.000131
        #print (self.invShares.iloc[1,2]) #0.000131
        #print (self.invShares.iloc[43,0]) #Imputed 
        #print (self.invShares.iloc[44,0]) #Real
            
        for i in range(64): #64, as rows 0:63
            intermediateInputs[i,43]=0
            #intermediateInputs[i,64]=0 #col 64 never user, as sector 65 was dropped

        fileName = "ff_with_class_limits.csv" #input("file name? ")
        self.simulationFirmsExAnteNumber = int(input("how many firms? "))
        
        self.smart_capital = 2
        while self.smart_capital != 0 and self.smart_capital != 1:
            self.smart_capital = int(input("use smart capital? (Please, use only 1/0 to express True/False values) "))
            if self.smart_capital != 0 and self.smart_capital != 1: print("Please, use only 1/0 to express True/False values")

        eu_firms_by_employed_number = pd.read_pickle("./eu_firms_by_employed_number.xp") # this is a list of dfs (0-9, 10-19,20-49,50-249,>250)
        sector_special_cases = ['1', '2', '3', '44'] # agri-silvi-fish and imputed rents

        agri_eu27 = pd.read_pickle("./agri_eu27.xp")
        
        #importing csv file containing info about firms 
        with open(fileName, newline='') as csvfile:
            firmReader= csv.reader(csvfile, delimiter=',')#, quoting=csv.QUOTE_NONNUMERIC)
    
            self.rowNumber=-1 #to skip the row of the headers
            k=0 
            self.countImputedRentsFirms=0
            for row in firmReader: #for each record in .csv
                #print(row)
                labor = 0 
                if self.rowNumber>=0:
                    if row[4]=='': row[4]=0 # it pertains with last rows (naio sector 65)
                        
                    sector = row[0]
                    firmCreationNumber=int(float(row[4]) * self.simulationFirmsExAnteNumber)// rankNum
                    if sector=='44' and self.countImputedRentsFirms==0:
                        firmCreationNumber=1
                        self.countImputedRentsFirms=1
                    
                    for i in range(firmCreationNumber):
                        if row[0] == '1' or row[0] == '2' or row[0] == '3': #agri, silvi and fishing
                            randomizer = rng.uniform()
                            if randomizer <= 0.2: labor = 0
                            elif randomizer <= 0.9 : labor = 1
                            else: labor = 2
                        else:
                            ## if int(row[7]) == 0: row[7] = '1' # to avoid firms with 0 workers in the 0-9 class
                            labor= rng.integers(int(row[7]), int(row[8])+1) # because integers exclude extremes                         
                            # at https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.integers.html
                            # random.Generator.integers(low, high=None,...
                            # high, if provided, one above the largest (signed) integer to be drawn from the distribution
                        
                        # assignation of EU country label/number 
                        if row[3] == "From 0 to 9 persons employed": cl = 0
                        if row[3] == "From 10 to 19 persons employed": cl = 1
                        if row[3] == "From 20 to 49 persons employed": cl = 2
                        if row[3] == "From 50 to 249 persons employed": cl = 3
                        if row[3] == "250 persons employed or more": cl = 4

                        country_randomizer = rng.uniform()
                        # the assigning rule is that we must attribute the first country with a cumulative share higher than the random number we draw
                        # non-special cases sectors come from the sbs_countries file, while agriculture sector is treaten in the agri_eu27 file
                    
                        if not row[0] in sector_special_cases:
                            country_counter = 0
                            if eu_firms_by_employed_number[cl].iloc[int(row[0]), -1] != 0: # to avoid sectors with all zeros                                
                                while eu_firms_by_employed_number[cl].iloc[int(row[0]), country_counter] <= country_randomizer: country_counter += 1
                            
                        else:
                            # use agri_eu27 for agri forestry and fishing
                            continue
                        
                       

                        
                        capital= float(row[11]) + rng.random()*(float(row[12]) - float(row[11]))
                        if self.smart_capital:
                            capital = labor * float(row[10]) # row[10] = recipe 
                            
                        capitalR = float(row[13])
                        wage = float(row[14])

                        intermediate=[]
                        
                        for s in range(65):
                            intermediate.append(intermediateInputs[s,int(row[0])-1]*(0.95+0.10*rng.random()))
                        
                        """
                        minOrderDuration= row[5]
                        maxOrderDuration= row[6]
                        recipe= row[7] #K/L 
                        laborProductivity= row[8]
                        maxOrderProduction= row[9]
                        avgAssetsUsefulLife=row[10]  #https://www.oecd.org/sdd/productivity-stats/43734711.pdf
                        plannedMarkup=row[11]
                        orderObservationFrequency=rng.integers(row[12], row[13]+1)
                        productionType=int(row[14]) #productionType in firm-features.csv indicates the production of
                                                #investment goods if it is into the investmentGoods list in yaml
                        sectorialClass=int(self.rowNumber)
                        """
                        
                        aFirm =Firm(k, rank, int(sector), labor, capital, capitalR, wage, intermediate, country_counter) #, minOrderDuration,\
                                #maxOrderDuration, recipe, laborProductivity,\
                                #maxOrderProduction, avgAssetsUsefulLife, plannedMarkup, orderObservationFrequency, productionType,\
                                #sectorialClass)
                        context.add(aFirm)
                        k += 1 # first element of the UID of the agents
                self.rowNumber += 1
                self.simulationFirmsExPostNumber=k #one more, here is a count, not an id
        
    #interactingWithFirms
    def interactingWithFirms(self):

        #print(self.firmCount)

        if self.simulationFirmsExPostNumber==0:
            print("No firms created.")
        else:
            # a check
            countActualExPostFirmNumber = len(list(context.agents(agent_type=0)))
            if countActualExPostFirmNumber != self.simulationFirmsExPostNumber:
                print("DISASTER")
                quit()

            AFF_FirmNumber = 10000000
            Eu_FirmNumber = 21831369
            AFF_WorkerNumber = 9000000
            Eu_WorkerNumber = 152702115+9000000
            Eu_EmployeeCompensations = 7447036.79
            Eu_GDP_withVAT2022 = 16144780 #https://ec.europa.eu/eurostat/databrowser/view/tec00001/default/table?lang=en
            Eu_AddedValue2022 = 14303899 #naio table 2022 (milions) total Added value, gross
            Eu_Intermediate2022 = 16939701.18 	 
            propFactor = Eu_FirmNumber / countActualExPostFirmNumber

            countWorkers = 0
            countEmployeeCompensations = 0
            countCapitalR = 0
            countAFF_Firms = 0
            countAFF_Workers = 0
            intermediateTotal = 0
            intBySectors=[0]*64
            addValBySectors=[0]*64
            substitutionRate =0.1
            substitutionRateL=0.01667 #for sectors 44 and 45, 60 years of duration
            firmSubstitutions=0
            #allFirmSubstitutionsByVendorSector=[0]*65
            allFirmSubstitutionsByVendorSector=np.zeros(65)
            allFirmSubstitutionsByBuyerSector=np.zeros(65)

            
            for aFirm in context.agents(agent_type=0):
                countWorkers+=aFirm.labor              
                countEmployeeCompensations+=aFirm.labor*aFirm.wage
                countCapitalR+=aFirm.capital*aFirm.capitalR
                if int(aFirm.sector) <= 3: 
                    countAFF_Firms+=1
                    countAFF_Workers+=aFirm.labor
                    
                #added value
                addedValue=aFirm.labor*aFirm.wage + aFirm.capital*1000*aFirm.capitalR

                markupTentative=1.25
                addedValue*=markupTentative
                #addValBySectors[aFirm.sector-1]+=addedValue1

                #intermediate goods acquisition (must consider markup)
                for s in range(64):
                    intermediateTotal += addedValue*aFirm.intermediate[s]
                    #intBySectors[aFirm.sector-1]+= addedValue*aFirm.intermediate[s]

                #capital substitutions (firm capital is in thousands of euros)
                #imputed rents
                if aFirm.sector == 44 and self.countImputedRentsFirms==1: 
                    #from ff_with_class_limits, we use the number of the sector not the position!
                    aFirm.capital=30000000*1000/rankNum  # a unique firm with the whole capital into the specific rank
                    #see firm-features-generation for explanation, cell "Imputed rents special case"
                    firmSubstitutions+=((aFirm.capital*substitutionRateL)/Eu_FirmNumber)*self.simulationFirmsExAnteNumber
                                         #it will be reported to the EU scale
                    
                    allFirmSubstitutionsByBuyerSector[aFirm.sector-1] += ((aFirm.capital*substitutionRateL)/Eu_FirmNumber)*\
                                                                           self.simulationFirmsExAnteNumber

                    # buying uniquely from constructions
                    allFirmSubstitutionsByVendorSector[27-1]+=(aFirm.capital*substitutionRateL/Eu_FirmNumber)*\
                                                                           self.simulationFirmsExAnteNumber
                    #for s in range(1,66):
                    #    allFirmSubstitutionsByVendorSector[s-1]+=aFirm.capital*substitutionRateL*self.invSharesNp[aFirm.sector-1,s]
                    self.countImputedRentsFirms+=1

                #real estate
                elif aFirm.sector == 45: # from ff_with_class_limits, we use the number of sector not the position!
                    firmSubstitutions+=aFirm.capital*substitutionRateL
                    allFirmSubstitutionsByBuyerSector[aFirm.sector-1] += aFirm.capital*substitutionRateL
                    
                    for s in range(1,66):
                        allFirmSubstitutionsByVendorSector[s-1]+=aFirm.capital*substitutionRateL*self.invSharesNp[aFirm.sector-1,s]
                else:                                        
                    firmSubstitutions+=aFirm.capital*substitutionRate
                    allFirmSubstitutionsByBuyerSector[aFirm.sector-1] += aFirm.capital*substitutionRate
                    
                    for s in range(1,66):
                        #allFirmSubstitutionsByVendorSector[s-1]+=aFirm.capital*substitutionRate*self.invShares.iloc[aFirm.sector-1,s]
                        allFirmSubstitutionsByVendorSector[s-1]+=aFirm.capital*substitutionRate*self.invSharesNp[aFirm.sector-1,s]

            print("\n\nMEMO remember rankNum for multicore applications \n")
            table_data = [
                [' ',          'EU 27', 'simulation', 'simulation to'],
                [' ',          ' ',     ' ',          'EU scale'],
                ['AFF Firm Number', AFF_FirmNumber, countAFF_Firms, int(countAFF_Firms*propFactor)], 
                ['AFF Worker Number', AFF_WorkerNumber, countAFF_Workers, int(countAFF_Workers*propFactor)], 
                ['Firm Number', Eu_FirmNumber, countActualExPostFirmNumber, int(countActualExPostFirmNumber*propFactor)],
                ['Worker Number', Eu_WorkerNumber, countWorkers, int(countWorkers*propFactor)],
                ['Empl. Compens.', int(Eu_EmployeeCompensations), int(countEmployeeCompensations/1000000), 
                                                                int(countEmployeeCompensations*propFactor/1000000)],                                                                                                                              
                ['Capital R', int(Eu_AddedValue2022-Eu_EmployeeCompensations), int(countCapitalR/1000), 
                                                                int(countCapitalR*propFactor/1000)],
                ['GDP VAT', Eu_GDP_withVAT2022, 'N.B. contains VAT',' '],
                ['Add. Val. curr. p.', Eu_AddedValue2022, int(markupTentative*(countEmployeeCompensations/1000000\
                                                                 +countCapitalR/1000)),\
                                                    int(markupTentative*(countEmployeeCompensations*propFactor/1000000+\
                                                                         countCapitalR*propFactor/1000))],
                ['Int. goods curr. p.', int(Eu_Intermediate2022),int(intermediateTotal/1000000),\
                                                                 int(intermediateTotal*propFactor/1000000)]
            ]
            print(f"Markup tentative {100*(markupTentative-1)}%")
            for row in table_data:
                print("{: >20} {: >20} {: >20} {: >20}".format(*row))

            print("\n AFF => Agriculture, Forestry and Fishing\n\n")

            """
            t1=0
            t2=0
            for s in range(65):
                addValBySectors[s]*=propFactor/1000000
                intBySectors[s]*=propFactor/1000000
                t1+=addValBySectors[s]
                t2+=intBySectors[s]
                print(addValBySectors[s], intBySectors[s])
            
            print("\n",t1,t2)
            """

            #investments

            print("\nINVESTMENT TABLES\n")
            print(f"Investment regular substitution rate {substitutionRate}") 
            print(f"Investment long term substitution rate {substitutionRateL} for sectors 44 and 45")

            print()
            table2_data = [
                [' ',          'EU 27 (*)', 'simulation', 'simulation to'],
                [' ',          ' ',     ' ',          'EU scale'],
                ['Gross fixed c. formation','3320258.70',int(100*firmSubstitutions/1000)/100.0, int(100*(firmSubstitutions/1000)*\
                                                                            (Eu_FirmNumber/countActualExPostFirmNumber))/100.0]
                # /1000 to move to milions from thousands
            ]
            for row in table2_data:
                print("{: >20} {: >20} {: >20} {: >20}".format(*row))

                
            #by buying sectors
            print("\n")
            tot1=0
            buyingSectorsPurchases = []
            print(f"{'BUYING SECTORS':<35}{'Simulated investment purchases':<35}{'SIM. EU SCALE'}")
            for i in range(len(sectors.sectorNames)):
                print(f"{sectors.sectorNames[i][0:30]:<35}{allFirmSubstitutionsByBuyerSector[i]/1000:<16.2f}\
                        {(allFirmSubstitutionsByBuyerSector[i]/1000)*(Eu_FirmNumber/countActualExPostFirmNumber):.2f}")
                
                buyingSectorsPurchases.append((allFirmSubstitutionsByBuyerSector[i]/1000)*(Eu_FirmNumber/countActualExPostFirmNumber))
                tot1 += allFirmSubstitutionsByBuyerSector[i]/1000
                
            print(f"{'totals'[0:30]:<35}{tot1:<35.2f}{tot1*(Eu_FirmNumber/countActualExPostFirmNumber):.2f}")

            print("(*) EU 27 Gross Fixed Capital Formation is 3320258.70, but here we consider only substitutions."+\
                  "With ", self.simulationFirmsExAnteNumber, "ex-ante firms and smart capital option, substitutions are ",\
                  tot1*(Eu_FirmNumber/countActualExPostFirmNumber))

            with open('buyingSectorsPurchases.csv', 'w', newline='') as csvfile:
                writer = csv.writer(csvfile)
                for value in buyingSectorsPurchases:
                    writer.writerow([value])  

            #! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! 
            if int(tot1*(Eu_FirmNumber/countActualExPostFirmNumber)) != control:

                stop_execution(\
                  "\n! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! \n"+\
                  "Wrong control test, run again firm-features-generation to align investment table to new test_ff choices"+\
                   "\n! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! \n")


            print("\nINVESTMENT TABLES (continue)\n")           

            
            #by vending sectors
            print("\n\n\n")
            corrCoeff=tot1*(Eu_FirmNumber/countActualExPostFirmNumber)/3320258.70         
            #3085534.58/3320258.70 if 1,000,000 firms and smart capital; 3320258.70 is Gross Capital Formation from naio 2022
            tot1=0
            tot2=0
            tot3=0
            tot4=0
            y_true=[]
            y_est=[]
            print(f"{'VENDING SECTORS':<35}{'EU GrossCapitalFormation':<28}{'SIM. EU SCALE':<20}{'diff (sim - actual)'}")
            print(f"{'':<35}{'scaled to substitutions':28}")
            for i in range(len(sectors.sectorNames)):
                inv=(allFirmSubstitutionsByVendorSector[i]/1000)*(Eu_FirmNumber/countActualExPostFirmNumber)
                y_est.append(inv)
                y_true.append(sectors.GrossCapitalFormation[i]*corrCoeff)
                diff=inv - sectors.GrossCapitalFormation[i]*corrCoeff
                if sectors.GrossCapitalFormation[i] == 0:
                    rel100 = 0
                else:
                    rel100 = 100*diff/(sectors.GrossCapitalFormation[i]*corrCoeff)

                print(\
                f"{sectors.sectorNames[i][0:30]:<35}{sectors.GrossCapitalFormation[i]*corrCoeff:<33.2f}{inv:<20.2f}{diff:<20.3f}{rel100:.2f}%")
                tot1+=sectors.GrossCapitalFormation[i]*corrCoeff
                tot2+=inv
                tot3+=diff
                tot4+=diff**2
            print(f"{'totals'[0:30]:<35}{tot1:<33.2f}{tot2:<20.2f}{tot3:,.2f}")
            print()
            print(f"Sum of the squares of the diffs {tot4:,.2f}")

            (mae,rmse,mape,r2,ncases) = statistics(y_true, y_est)
            print(f"MAE  = {mae:.3f}")
            print(f"RMSE = {rmse:.3f}")
            print(f"MAPE = {mape:.2f}%")
            print(f"R²   = {r2:.3f}")
            print(f"n    = {ncases:.0f}")
            
    

    
    #finish
    def finish(self):
        print("\n\n")
        print(f"Gloabal time {T()}, cpu time {Tc()}")
        print("\nConcluded")
    
    def start(self):
        runner.execute()

def run():

    model = Model() 
    model.start()
    
run()

#file name: ff_with_class_limits.csv
# Out:
# What table of investment shares? Please, use only 0/1/2 to chose invTableNoNama (0) or invTableNama (1) or invTableNamaIPF (2) 2
# how many firms?  1000
# use smart capital? (Please, use only 1/0 to express True/False values)  1
# 0 5 0 0.3815959843779345 0.014118997820126296
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# 1 5 0 0.4811086430055902 0.014118997820126296
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# eccomi 1 10
# eccomi 1 11
# 0 5 0 0.20442599555676733 0.014118997820126296
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# 0 11 0 0.28027981594898466 0.02295895354082093
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# 1 11 0 0.9270228323284986 0.02295895354082093
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# eccomi 1 10
# eccomi 1 11
# eccomi 1 12
# eccomi 1 13
# eccomi 1 14
# eccomi 1 15
# eccomi 1 16
# eccomi 1 17
# eccomi 1 18
# eccomi 1 19
# eccomi 1 20
# eccomi 1 21
# eccomi 1 22
# eccomi 1 23
# eccomi 1 24
# 0 13 0 0.6049532464296768 0.010748642983823293
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# eccomi 0 14
# eccomi 0 15
# eccomi 0 16
# eccomi 0 17
# eccomi 0 18
# eccomi 0 19
# 0 14 0 0.4419497542110792 0.013010068220435697
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# 0 15 0 0.10616614108847089 0.003691593713743276
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# 0 16 0 0.15184446366531779 0.00897855801563387
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# 1 16 0 0.26152564216842666 0.00897855801563387
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# 2 16 0 0.3792579959517274 0.00897855801563387
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# eccomi 2 5
# eccomi 2 6
# eccomi 2 7
# eccomi 2 8
# eccomi 2 9
# eccomi 2 10
# eccomi 2 11
# 0 18 0 0.13914745714607846 0.011290221413786616
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# 0 19 0 0.44816838224738786 0.01526396863184428
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# 1 19 0 0.3968470915800175 0.01526396863184428
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# eccomi 1 10
# 0 19 0 0.6130197212683515 0.01526396863184428
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# 1 19 0 0.9624648040549804 0.01526396863184428
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# eccomi 1 10
# eccomi 1 11
# eccomi 1 12
# eccomi 1 13
# eccomi 1 14
# eccomi 1 15
# eccomi 1 16
# eccomi 1 17
# eccomi 1 18
# eccomi 1 19
# eccomi 1 20
# eccomi 1 21
# eccomi 1 22
# eccomi 1 23
# eccomi 1 24
# 0 20 0 0.12668477354869834 0.011283851554663993
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# 0 20 0 0.23467793402473613 0.011283851554663993
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# 0 23 0 0.15592401870361583 0.011708133994721301
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# 0 24 0 0.11337466794662898 0.021150276255231276
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# 0 27 0 0.1346546635178144 0.009392550021725524
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# 0 27 0 0.3342659372460126 0.009392550021725524
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# 1 27 0 0.32042244377329054 0.009392550021725524
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# 2 27 0 0.5228064946463322 0.009392550021725524
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# eccomi 2 5
# eccomi 2 6
# eccomi 2 7
# eccomi 2 8
# eccomi 2 9
# eccomi 2 10
# eccomi 2 11
# eccomi 2 12
# eccomi 2 13
# 3 27 0 0.8342284162828107 0.009392550021725524
# eccomi 3 0
# eccomi 3 1
# eccomi 3 2
# eccomi 3 3
# eccomi 3 4
# eccomi 3 5
# eccomi 3 6
# eccomi 3 7
# eccomi 3 8
# eccomi 3 9
# eccomi 3 10
# eccomi 3 11
# eccomi 3 12
# eccomi 3 13
# eccomi 3 14
# eccomi 3 15
# eccomi 3 16
# eccomi 3 17
# eccomi 3 18
# eccomi 3 19
# eccomi 3 20
# eccomi 3 21
# eccomi 3 22
# 4 27 0 0.8717662786322675 0.009392550021725524
# eccomi 4 0
# eccomi 4 1
# eccomi 4 2
# eccomi 4 3
# eccomi 4 4
# eccomi 4 5
# eccomi 4 6
# eccomi 4 7
# eccomi 4 8
# eccomi 4 9
# eccomi 4 10
# eccomi 4 11
# eccomi 4 12
# eccomi 4 13
# eccomi 4 14
# eccomi 4 15
# eccomi 4 16
# eccomi 4 17
# eccomi 4 18
# eccomi 4 19
# eccomi 4 20
# eccomi 4 21
# eccomi 4 22
# eccomi 4 23
# eccomi 4 24
# 5 27 0 0.38727769579109617 0.009392550021725524
# eccomi 5 0
# eccomi 5 1
# eccomi 5 2
# eccomi 5 3
# eccomi 5 4
# eccomi 5 5
# eccomi 5 6
# eccomi 5 7
# eccomi 5 8
# eccomi 5 9
# eccomi 5 10
# 6 27 0 0.37089115884435486 0.009392550021725524
# eccomi 6 0
# eccomi 6 1
# eccomi 6 2
# eccomi 6 3
# eccomi 6 4
# eccomi 6 5
# eccomi 6 6
# eccomi 6 7
# eccomi 6 8
# eccomi 6 9
# 7 27 0 0.7656150873322012 0.009392550021725524
# eccomi 7 0
# eccomi 7 1
# eccomi 7 2
# eccomi 7 3
# eccomi 7 4
# eccomi 7 5
# eccomi 7 6
# eccomi 7 7
# eccomi 7 8
# eccomi 7 9
# eccomi 7 10
# eccomi 7 11
# eccomi 7 12
# eccomi 7 13
# eccomi 7 14
# eccomi 7 15
# eccomi 7 16
# eccomi 7 17
# eccomi 7 18
# eccomi 7 19
# 8 27 0 0.9749498184083472 0.009392550021725524
# eccomi 8 0
# eccomi 8 1
# eccomi 8 2
# eccomi 8 3
# eccomi 8 4
# eccomi 8 5
# eccomi 8 6
# eccomi 8 7
# eccomi 8 8
# eccomi 8 9
# eccomi 8 10
# eccomi 8 11
# eccomi 8 12
# eccomi 8 13
# eccomi 8 14
# eccomi 8 15
# eccomi 8 16
# eccomi 8 17
# eccomi 8 18
# eccomi 8 19
# eccomi 8 20
# eccomi 8 21
# eccomi 8 22
# eccomi 8 23
# eccomi 8 24
# eccomi 8 25
# 9 27 0 0.755218531545742 0.009392550021725524
# eccomi 9 0
# eccomi 9 1
# eccomi 9 2
# eccomi 9 3
# eccomi 9 4
# eccomi 9 5
# eccomi 9 6
# eccomi 9 7
# eccomi 9 8
# eccomi 9 9
# eccomi 9 10
# eccomi 9 11
# eccomi 9 12
# eccomi 9 13
# eccomi 9 14
# eccomi 9 15
# eccomi 9 16
# eccomi 9 17
# eccomi 9 18
# eccomi 9 19
# 10 27 0 0.7751859505552492 0.009392550021725524
# eccomi 10 0
# eccomi 10 1
# eccomi 10 2
# eccomi 10 3
# eccomi 10 4
# eccomi 10 5
# eccomi 10 6
# eccomi 10 7
# eccomi 10 8
# eccomi 10 9
# eccomi 10 10
# eccomi 10 11
# eccomi 10 12
# eccomi 10 13
# eccomi 10 14
# eccomi 10 15
# eccomi 10 16
# eccomi 10 17
# eccomi 10 18
# eccomi 10 19
# eccomi 10 20
# 11 27 0 0.7298702607772944 0.009392550021725524
# eccomi 11 0
# eccomi 11 1
# eccomi 11 2
# eccomi 11 3
# eccomi 11 4
# eccomi 11 5
# eccomi 11 6
# eccomi 11 7
# eccomi 11 8
# eccomi 11 9
# eccomi 11 10
# eccomi 11 11
# eccomi 11 12
# eccomi 11 13
# eccomi 11 14
# eccomi 11 15
# eccomi 11 16
# eccomi 11 17
# eccomi 11 18
# eccomi 11 19
# 12 27 0 0.8913281929058448 0.009392550021725524
# eccomi 12 0
# eccomi 12 1
# eccomi 12 2
# eccomi 12 3
# eccomi 12 4
# eccomi 12 5
# eccomi 12 6
# eccomi 12 7
# eccomi 12 8
# eccomi 12 9
# eccomi 12 10
# eccomi 12 11
# eccomi 12 12
# eccomi 12 13
# eccomi 12 14
# eccomi 12 15
# eccomi 12 16
# eccomi 12 17
# eccomi 12 18
# eccomi 12 19
# eccomi 12 20
# eccomi 12 21
# eccomi 12 22
# eccomi 12 23
# eccomi 12 24
# 13 27 0 0.6654170688013483 0.009392550021725524
# eccomi 13 0
# eccomi 13 1
# eccomi 13 2
# eccomi 13 3
# eccomi 13 4
# eccomi 13 5
# eccomi 13 6
# eccomi 13 7
# eccomi 13 8
# eccomi 13 9
# eccomi 13 10
# eccomi 13 11
# eccomi 13 12
# eccomi 13 13
# eccomi 13 14
# eccomi 13 15
# eccomi 13 16
# eccomi 13 17
# eccomi 13 18
# 14 27 0 0.4956172795039634 0.009392550021725524
# eccomi 14 0
# eccomi 14 1
# eccomi 14 2
# eccomi 14 3
# eccomi 14 4
# eccomi 14 5
# eccomi 14 6
# eccomi 14 7
# eccomi 14 8
# eccomi 14 9
# eccomi 14 10
# eccomi 14 11
# eccomi 14 12
# eccomi 14 13
# 15 27 0 0.5677110403773605 0.009392550021725524
# eccomi 15 0
# eccomi 15 1
# eccomi 15 2
# eccomi 15 3
# eccomi 15 4
# eccomi 15 5
# eccomi 15 6
# eccomi 15 7
# eccomi 15 8
# eccomi 15 9
# eccomi 15 10
# eccomi 15 11
# eccomi 15 12
# eccomi 15 13
# 16 27 0 0.417325090123263 0.009392550021725524
# eccomi 16 0
# eccomi 16 1
# eccomi 16 2
# eccomi 16 3
# eccomi 16 4
# eccomi 16 5
# eccomi 16 6
# eccomi 16 7
# eccomi 16 8
# eccomi 16 9
# eccomi 16 10
# eccomi 16 11
# 17 27 0 0.49954311853025757 0.009392550021725524
# eccomi 17 0
# eccomi 17 1
# eccomi 17 2
# eccomi 17 3
# eccomi 17 4
# eccomi 17 5
# eccomi 17 6
# eccomi 17 7
# eccomi 17 8
# eccomi 17 9
# eccomi 17 10
# eccomi 17 11
# eccomi 17 12
# eccomi 17 13
# 18 27 0 0.5731299689838099 0.009392550021725524
# eccomi 18 0
# eccomi 18 1
# eccomi 18 2
# eccomi 18 3
# eccomi 18 4
# eccomi 18 5
# eccomi 18 6
# eccomi 18 7
# eccomi 18 8
# eccomi 18 9
# eccomi 18 10
# eccomi 18 11
# eccomi 18 12
# eccomi 18 13
# 19 27 0 0.8322859827305917 0.009392550021725524
# eccomi 19 0
# eccomi 19 1
# eccomi 19 2
# eccomi 19 3
# eccomi 19 4
# eccomi 19 5
# eccomi 19 6
# eccomi 19 7
# eccomi 19 8
# eccomi 19 9
# eccomi 19 10
# eccomi 19 11
# eccomi 19 12
# eccomi 19 13
# eccomi 19 14
# eccomi 19 15
# eccomi 19 16
# eccomi 19 17
# eccomi 19 18
# eccomi 19 19
# eccomi 19 20
# eccomi 19 21
# eccomi 19 22
# 20 27 0 0.5970899996125458 0.009392550021725524
# eccomi 20 0
# eccomi 20 1
# eccomi 20 2
# eccomi 20 3
# eccomi 20 4
# eccomi 20 5
# eccomi 20 6
# eccomi 20 7
# eccomi 20 8
# eccomi 20 9
# eccomi 20 10
# eccomi 20 11
# eccomi 20 12
# eccomi 20 13
# eccomi 20 14
# eccomi 20 15
# eccomi 20 16
# eccomi 20 17
# 21 27 0 0.10389342194870932 0.009392550021725524
# eccomi 21 0
# eccomi 21 1
# eccomi 21 2
# eccomi 21 3
# eccomi 21 4
# 22 27 0 0.5285065081928294 0.009392550021725524
# eccomi 22 0
# eccomi 22 1
# eccomi 22 2
# eccomi 22 3
# eccomi 22 4
# eccomi 22 5
# eccomi 22 6
# eccomi 22 7
# eccomi 22 8
# eccomi 22 9
# eccomi 22 10
# eccomi 22 11
# eccomi 22 12
# eccomi 22 13
# 23 27 0 0.2764742640954224 0.009392550021725524
# eccomi 23 0
# eccomi 23 1
# eccomi 23 2
# eccomi 23 3
# eccomi 23 4
# eccomi 23 5
# eccomi 23 6
# eccomi 23 7
# eccomi 23 8
# 24 27 0 0.060044155946048394 0.009392550021725524
# eccomi 24 0
# eccomi 24 1
# eccomi 24 2
# eccomi 24 3
# 25 27 0 0.9632296579000684 0.009392550021725524
# eccomi 25 0
# eccomi 25 1
# eccomi 25 2
# eccomi 25 3
# eccomi 25 4
# eccomi 25 5
# eccomi 25 6
# eccomi 25 7
# eccomi 25 8
# eccomi 25 9
# eccomi 25 10
# eccomi 25 11
# eccomi 25 12
# eccomi 25 13
# eccomi 25 14
# eccomi 25 15
# eccomi 25 16
# eccomi 25 17
# eccomi 25 18
# eccomi 25 19
# eccomi 25 20
# eccomi 25 21
# eccomi 25 22
# eccomi 25 23
# eccomi 25 24
# 26 27 0 0.7281192258052512 0.009392550021725524
# eccomi 26 0
# eccomi 26 1
# eccomi 26 2
# eccomi 26 3
# eccomi 26 4
# eccomi 26 5
# eccomi 26 6
# eccomi 26 7
# eccomi 26 8
# eccomi 26 9
# eccomi 26 10
# eccomi 26 11
# eccomi 26 12
# eccomi 26 13
# eccomi 26 14
# eccomi 26 15
# eccomi 26 16
# eccomi 26 17
# eccomi 26 18
# eccomi 26 19
# 27 27 0 0.42796768595199053 0.009392550021725524
# eccomi 27 0
# eccomi 27 1
# eccomi 27 2
# eccomi 27 3
# eccomi 27 4
# eccomi 27 5
# eccomi 27 6
# eccomi 27 7
# eccomi 27 8
# eccomi 27 9
# eccomi 27 10
# eccomi 27 11
# eccomi 27 12
# 28 27 0 0.990472405794055 0.009392550021725524
# eccomi 28 0
# eccomi 28 1
# eccomi 28 2
# eccomi 28 3
# eccomi 28 4
# eccomi 28 5
# eccomi 28 6
# eccomi 28 7
# eccomi 28 8
# eccomi 28 9
# eccomi 28 10
# eccomi 28 11
# eccomi 28 12
# eccomi 28 13
# eccomi 28 14
# eccomi 28 15
# eccomi 28 16
# eccomi 28 17
# eccomi 28 18
# eccomi 28 19
# eccomi 28 20
# eccomi 28 21
# eccomi 28 22
# eccomi 28 23
# eccomi 28 24
# eccomi 28 25
# 29 27 0 0.054633588858534865 0.009392550021725524
# eccomi 29 0
# eccomi 29 1
# eccomi 29 2
# 30 27 0 0.249713440609172 0.009392550021725524
# eccomi 30 0
# eccomi 30 1
# eccomi 30 2
# eccomi 30 3
# eccomi 30 4
# eccomi 30 5
# eccomi 30 6
# eccomi 30 7
# eccomi 30 8
# 31 27 0 0.8077246987383074 0.009392550021725524
# eccomi 31 0
# eccomi 31 1
# eccomi 31 2
# eccomi 31 3
# eccomi 31 4
# eccomi 31 5
# eccomi 31 6
# eccomi 31 7
# eccomi 31 8
# eccomi 31 9
# eccomi 31 10
# eccomi 31 11
# eccomi 31 12
# eccomi 31 13
# eccomi 31 14
# eccomi 31 15
# eccomi 31 16
# eccomi 31 17
# eccomi 31 18
# eccomi 31 19
# eccomi 31 20
# eccomi 31 21
# 32 27 0 0.4643220036211113 0.009392550021725524
# eccomi 32 0
# eccomi 32 1
# eccomi 32 2
# eccomi 32 3
# eccomi 32 4
# eccomi 32 5
# eccomi 32 6
# eccomi 32 7
# eccomi 32 8
# eccomi 32 9
# eccomi 32 10
# eccomi 32 11
# eccomi 32 12
# eccomi 32 13
# 33 27 0 0.22789067852400025 0.009392550021725524
# eccomi 33 0
# eccomi 33 1
# eccomi 33 2
# eccomi 33 3
# eccomi 33 4
# eccomi 33 5
# eccomi 33 6
# eccomi 33 7
# eccomi 33 8
# 34 27 0 0.6561786263310475 0.009392550021725524
# eccomi 34 0
# eccomi 34 1
# eccomi 34 2
# eccomi 34 3
# eccomi 34 4
# eccomi 34 5
# eccomi 34 6
# eccomi 34 7
# eccomi 34 8
# eccomi 34 9
# eccomi 34 10
# eccomi 34 11
# eccomi 34 12
# eccomi 34 13
# eccomi 34 14
# eccomi 34 15
# eccomi 34 16
# eccomi 34 17
# eccomi 34 18
# 35 27 0 0.9718347908965224 0.009392550021725524
# eccomi 35 0
# eccomi 35 1
# eccomi 35 2
# eccomi 35 3
# eccomi 35 4
# eccomi 35 5
# eccomi 35 6
# eccomi 35 7
# eccomi 35 8
# eccomi 35 9
# eccomi 35 10
# eccomi 35 11
# eccomi 35 12
# eccomi 35 13
# eccomi 35 14
# eccomi 35 15
# eccomi 35 16
# eccomi 35 17
# eccomi 35 18
# eccomi 35 19
# eccomi 35 20
# eccomi 35 21
# eccomi 35 22
# eccomi 35 23
# eccomi 35 24
# 36 27 0 0.7506731031124444 0.009392550021725524
# eccomi 36 0
# eccomi 36 1
# eccomi 36 2
# eccomi 36 3
# eccomi 36 4
# eccomi 36 5
# eccomi 36 6
# eccomi 36 7
# eccomi 36 8
# eccomi 36 9
# eccomi 36 10
# eccomi 36 11
# eccomi 36 12
# eccomi 36 13
# eccomi 36 14
# eccomi 36 15
# eccomi 36 16
# eccomi 36 17
# eccomi 36 18
# eccomi 36 19
# 37 27 0 0.4457201522635109 0.009392550021725524
# eccomi 37 0
# eccomi 37 1
# eccomi 37 2
# eccomi 37 3
# eccomi 37 4
# eccomi 37 5
# eccomi 37 6
# eccomi 37 7
# eccomi 37 8
# eccomi 37 9
# eccomi 37 10
# eccomi 37 11
# eccomi 37 12
# 38 27 0 0.3201790546496347 0.009392550021725524
# eccomi 38 0
# eccomi 38 1
# eccomi 38 2
# eccomi 38 3
# eccomi 38 4
# eccomi 38 5
# eccomi 38 6
# eccomi 38 7
# eccomi 38 8
# eccomi 38 9
# 0 27 1 0.34161739551604065 0.026954811249185986
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# 1 27 1 0.24031227525054755 0.026954811249185986
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# 2 27 1 0.1878354364150443 0.026954811249185986
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# eccomi 2 5
# eccomi 2 6
# eccomi 2 7
# eccomi 2 8
# 0 27 2 0.8787768030167123 0.03564032172614747
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# eccomi 0 14
# eccomi 0 15
# eccomi 0 16
# eccomi 0 17
# eccomi 0 18
# eccomi 0 19
# eccomi 0 20
# eccomi 0 21
# eccomi 0 22
# eccomi 0 23
# eccomi 0 24
# 0 27 0 0.2744298229396229 0.009392550021725524
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# 1 27 0 0.40238712667745435 0.009392550021725524
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# eccomi 1 10
# eccomi 1 11
# 2 27 0 0.10933843791326225 0.009392550021725524
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# 3 27 0 0.3582518418056758 0.009392550021725524
# eccomi 3 0
# eccomi 3 1
# eccomi 3 2
# eccomi 3 3
# eccomi 3 4
# eccomi 3 5
# eccomi 3 6
# eccomi 3 7
# eccomi 3 8
# eccomi 3 9
# 4 27 0 0.5406114467519006 0.009392550021725524
# eccomi 4 0
# eccomi 4 1
# eccomi 4 2
# eccomi 4 3
# eccomi 4 4
# eccomi 4 5
# eccomi 4 6
# eccomi 4 7
# eccomi 4 8
# eccomi 4 9
# eccomi 4 10
# eccomi 4 11
# eccomi 4 12
# eccomi 4 13
# 5 27 0 0.9372219289054372 0.009392550021725524
# eccomi 5 0
# eccomi 5 1
# eccomi 5 2
# eccomi 5 3
# eccomi 5 4
# eccomi 5 5
# eccomi 5 6
# eccomi 5 7
# eccomi 5 8
# eccomi 5 9
# eccomi 5 10
# eccomi 5 11
# eccomi 5 12
# eccomi 5 13
# eccomi 5 14
# eccomi 5 15
# eccomi 5 16
# eccomi 5 17
# eccomi 5 18
# eccomi 5 19
# eccomi 5 20
# eccomi 5 21
# eccomi 5 22
# eccomi 5 23
# eccomi 5 24
# 6 27 0 0.3818482556067182 0.009392550021725524
# eccomi 6 0
# eccomi 6 1
# eccomi 6 2
# eccomi 6 3
# eccomi 6 4
# eccomi 6 5
# eccomi 6 6
# eccomi 6 7
# eccomi 6 8
# eccomi 6 9
# eccomi 6 10
# 7 27 0 0.3134800429435607 0.009392550021725524
# eccomi 7 0
# eccomi 7 1
# eccomi 7 2
# eccomi 7 3
# eccomi 7 4
# eccomi 7 5
# eccomi 7 6
# eccomi 7 7
# eccomi 7 8
# eccomi 7 9
# 8 27 0 0.5173911712674284 0.009392550021725524
# eccomi 8 0
# eccomi 8 1
# eccomi 8 2
# eccomi 8 3
# eccomi 8 4
# eccomi 8 5
# eccomi 8 6
# eccomi 8 7
# eccomi 8 8
# eccomi 8 9
# eccomi 8 10
# eccomi 8 11
# eccomi 8 12
# eccomi 8 13
# 9 27 0 0.014592399689986157 0.009392550021725524
# eccomi 9 0
# 10 27 0 0.8014954362858971 0.009392550021725524
# eccomi 10 0
# eccomi 10 1
# eccomi 10 2
# eccomi 10 3
# eccomi 10 4
# eccomi 10 5
# eccomi 10 6
# eccomi 10 7
# eccomi 10 8
# eccomi 10 9
# eccomi 10 10
# eccomi 10 11
# eccomi 10 12
# eccomi 10 13
# eccomi 10 14
# eccomi 10 15
# eccomi 10 16
# eccomi 10 17
# eccomi 10 18
# eccomi 10 19
# eccomi 10 20
# eccomi 10 21
# 11 27 0 0.03507667102167544 0.009392550021725524
# eccomi 11 0
# 12 27 0 0.20352045113465722 0.009392550021725524
# eccomi 12 0
# eccomi 12 1
# eccomi 12 2
# eccomi 12 3
# eccomi 12 4
# eccomi 12 5
# eccomi 12 6
# eccomi 12 7
# eccomi 12 8
# 13 27 0 0.6260449910371789 0.009392550021725524
# eccomi 13 0
# eccomi 13 1
# eccomi 13 2
# eccomi 13 3
# eccomi 13 4
# eccomi 13 5
# eccomi 13 6
# eccomi 13 7
# eccomi 13 8
# eccomi 13 9
# eccomi 13 10
# eccomi 13 11
# eccomi 13 12
# eccomi 13 13
# eccomi 13 14
# eccomi 13 15
# eccomi 13 16
# eccomi 13 17
# eccomi 13 18
# 14 27 0 0.014449901115098918 0.009392550021725524
# eccomi 14 0
# 15 27 0 0.11456631570079445 0.009392550021725524
# eccomi 15 0
# eccomi 15 1
# eccomi 15 2
# eccomi 15 3
# eccomi 15 4
# eccomi 15 5
# 16 27 0 0.8343914104630915 0.009392550021725524
# eccomi 16 0
# eccomi 16 1
# eccomi 16 2
# eccomi 16 3
# eccomi 16 4
# eccomi 16 5
# eccomi 16 6
# eccomi 16 7
# eccomi 16 8
# eccomi 16 9
# eccomi 16 10
# eccomi 16 11
# eccomi 16 12
# eccomi 16 13
# eccomi 16 14
# eccomi 16 15
# eccomi 16 16
# eccomi 16 17
# eccomi 16 18
# eccomi 16 19
# eccomi 16 20
# eccomi 16 21
# eccomi 16 22
# 17 27 0 0.10478002651963303 0.009392550021725524
# eccomi 17 0
# eccomi 17 1
# eccomi 17 2
# eccomi 17 3
# eccomi 17 4
# 18 27 0 0.8312684959658029 0.009392550021725524
# eccomi 18 0
# eccomi 18 1
# eccomi 18 2
# eccomi 18 3
# eccomi 18 4
# eccomi 18 5
# eccomi 18 6
# eccomi 18 7
# eccomi 18 8
# eccomi 18 9
# eccomi 18 10
# eccomi 18 11
# eccomi 18 12
# eccomi 18 13
# eccomi 18 14
# eccomi 18 15
# eccomi 18 16
# eccomi 18 17
# eccomi 18 18
# eccomi 18 19
# eccomi 18 20
# eccomi 18 21
# eccomi 18 22
# 19 27 0 0.175402948965792 0.009392550021725524
# eccomi 19 0
# eccomi 19 1
# eccomi 19 2
# eccomi 19 3
# eccomi 19 4
# eccomi 19 5
# eccomi 19 6
# eccomi 19 7
# eccomi 19 8
# 20 27 0 0.4153520439539512 0.009392550021725524
# eccomi 20 0
# eccomi 20 1
# eccomi 20 2
# eccomi 20 3
# eccomi 20 4
# eccomi 20 5
# eccomi 20 6
# eccomi 20 7
# eccomi 20 8
# eccomi 20 9
# eccomi 20 10
# eccomi 20 11
# 21 27 0 0.41116406410810824 0.009392550021725524
# eccomi 21 0
# eccomi 21 1
# eccomi 21 2
# eccomi 21 3
# eccomi 21 4
# eccomi 21 5
# eccomi 21 6
# eccomi 21 7
# eccomi 21 8
# eccomi 21 9
# eccomi 21 10
# eccomi 21 11
# 22 27 0 0.7593835934196496 0.009392550021725524
# eccomi 22 0
# eccomi 22 1
# eccomi 22 2
# eccomi 22 3
# eccomi 22 4
# eccomi 22 5
# eccomi 22 6
# eccomi 22 7
# eccomi 22 8
# eccomi 22 9
# eccomi 22 10
# eccomi 22 11
# eccomi 22 12
# eccomi 22 13
# eccomi 22 14
# eccomi 22 15
# eccomi 22 16
# eccomi 22 17
# eccomi 22 18
# eccomi 22 19
# 23 27 0 0.5696783675946242 0.009392550021725524
# eccomi 23 0
# eccomi 23 1
# eccomi 23 2
# eccomi 23 3
# eccomi 23 4
# eccomi 23 5
# eccomi 23 6
# eccomi 23 7
# eccomi 23 8
# eccomi 23 9
# eccomi 23 10
# eccomi 23 11
# eccomi 23 12
# eccomi 23 13
# 0 27 1 0.1266249595876966 0.026954811249185986
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# 1 27 1 0.29736698057077093 0.026954811249185986
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# 0 28 0 0.16296460636608245 0.015579245420004356
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# 1 28 0 0.20393149007546763 0.015579245420004356
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# 2 28 0 0.07428976788673569 0.015579245420004356
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# 3 28 0 0.25408728677997605 0.015579245420004356
# eccomi 3 0
# eccomi 3 1
# eccomi 3 2
# eccomi 3 3
# eccomi 3 4
# eccomi 3 5
# eccomi 3 6
# eccomi 3 7
# eccomi 3 8
# 4 28 0 0.8532376200863091 0.015579245420004356
# eccomi 4 0
# eccomi 4 1
# eccomi 4 2
# eccomi 4 3
# eccomi 4 4
# eccomi 4 5
# eccomi 4 6
# eccomi 4 7
# eccomi 4 8
# eccomi 4 9
# eccomi 4 10
# eccomi 4 11
# eccomi 4 12
# eccomi 4 13
# eccomi 4 14
# eccomi 4 15
# eccomi 4 16
# eccomi 4 17
# eccomi 4 18
# eccomi 4 19
# eccomi 4 20
# eccomi 4 21
# 0 28 0 0.441661326399608 0.015579245420004356
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# 0 28 0 0.6369068686353099 0.015579245420004356
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# eccomi 0 14
# eccomi 0 15
# eccomi 0 16
# eccomi 0 17
# eccomi 0 18
# 1 28 0 0.8233331854746504 0.015579245420004356
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# eccomi 1 10
# eccomi 1 11
# eccomi 1 12
# eccomi 1 13
# eccomi 1 14
# eccomi 1 15
# eccomi 1 16
# eccomi 1 17
# eccomi 1 18
# eccomi 1 19
# eccomi 1 20
# 2 28 0 0.7256684990549803 0.015579245420004356
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# eccomi 2 5
# eccomi 2 6
# eccomi 2 7
# eccomi 2 8
# eccomi 2 9
# eccomi 2 10
# eccomi 2 11
# eccomi 2 12
# eccomi 2 13
# eccomi 2 14
# eccomi 2 15
# eccomi 2 16
# eccomi 2 17
# eccomi 2 18
# eccomi 2 19
# 3 28 0 0.49429554117675834 0.015579245420004356
# eccomi 3 0
# eccomi 3 1
# eccomi 3 2
# eccomi 3 3
# eccomi 3 4
# eccomi 3 5
# eccomi 3 6
# eccomi 3 7
# eccomi 3 8
# eccomi 3 9
# eccomi 3 10
# eccomi 3 11
# eccomi 3 12
# eccomi 3 13
# 4 28 0 0.47473480579651595 0.015579245420004356
# eccomi 4 0
# eccomi 4 1
# eccomi 4 2
# eccomi 4 3
# eccomi 4 4
# eccomi 4 5
# eccomi 4 6
# eccomi 4 7
# eccomi 4 8
# eccomi 4 9
# eccomi 4 10
# eccomi 4 11
# eccomi 4 12
# eccomi 4 13
# 5 28 0 0.07765107199280097 0.015579245420004356
# eccomi 5 0
# eccomi 5 1
# eccomi 5 2
# eccomi 5 3
# eccomi 5 4
# 0 29 0 0.29815420092447187 0.014574498744287538
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# 1 29 0 0.8366990634159466 0.014574498744287538
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# eccomi 1 10
# eccomi 1 11
# eccomi 1 12
# eccomi 1 13
# eccomi 1 14
# eccomi 1 15
# eccomi 1 16
# eccomi 1 17
# eccomi 1 18
# eccomi 1 19
# eccomi 1 20
# eccomi 1 21
# eccomi 1 22
# 2 29 0 0.1212049704123852 0.014574498744287538
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# eccomi 2 5
# eccomi 2 6
# 3 29 0 0.5143100913480375 0.014574498744287538
# eccomi 3 0
# eccomi 3 1
# eccomi 3 2
# eccomi 3 3
# eccomi 3 4
# eccomi 3 5
# eccomi 3 6
# eccomi 3 7
# eccomi 3 8
# eccomi 3 9
# eccomi 3 10
# eccomi 3 11
# eccomi 3 12
# eccomi 3 13
# 4 29 0 0.08568467659206558 0.014574498744287538
# eccomi 4 0
# eccomi 4 1
# eccomi 4 2
# eccomi 4 3
# eccomi 4 4
# 5 29 0 0.19449764760128319 0.014574498744287538
# eccomi 5 0
# eccomi 5 1
# eccomi 5 2
# eccomi 5 3
# eccomi 5 4
# eccomi 5 5
# eccomi 5 6
# eccomi 5 7
# eccomi 5 8
# 6 29 0 0.3943165928527447 0.014574498744287538
# eccomi 6 0
# eccomi 6 1
# eccomi 6 2
# eccomi 6 3
# eccomi 6 4
# eccomi 6 5
# eccomi 6 6
# eccomi 6 7
# eccomi 6 8
# eccomi 6 9
# eccomi 6 10
# eccomi 6 11
# eccomi 6 12
# eccomi 6 13
# 7 29 0 0.06847108459965723 0.014574498744287538
# eccomi 7 0
# eccomi 7 1
# eccomi 7 2
# eccomi 7 3
# eccomi 7 4
# 8 29 0 0.7518485922949976 0.014574498744287538
# eccomi 8 0
# eccomi 8 1
# eccomi 8 2
# eccomi 8 3
# eccomi 8 4
# eccomi 8 5
# eccomi 8 6
# eccomi 8 7
# eccomi 8 8
# eccomi 8 9
# eccomi 8 10
# eccomi 8 11
# eccomi 8 12
# eccomi 8 13
# eccomi 8 14
# eccomi 8 15
# eccomi 8 16
# eccomi 8 17
# eccomi 8 18
# eccomi 8 19
# eccomi 8 20
# 0 29 0 0.6950794600965782 0.014574498744287538
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# eccomi 0 14
# eccomi 0 15
# eccomi 0 16
# eccomi 0 17
# eccomi 0 18
# eccomi 0 19
# 1 29 0 0.02302423996933045 0.014574498744287538
# eccomi 1 0
# 2 29 0 0.16744108988174944 0.014574498744287538
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# eccomi 2 5
# eccomi 2 6
# eccomi 2 7
# eccomi 2 8
# 0 29 0 0.23403117980036758 0.014574498744287538
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# 1 29 0 0.20916194065949179 0.014574498744287538
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# 2 29 0 0.5024797229306536 0.014574498744287538
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# eccomi 2 5
# eccomi 2 6
# eccomi 2 7
# eccomi 2 8
# eccomi 2 9
# eccomi 2 10
# eccomi 2 11
# eccomi 2 12
# eccomi 2 13
# 3 29 0 0.8939439467297525 0.014574498744287538
# eccomi 3 0
# eccomi 3 1
# eccomi 3 2
# eccomi 3 3
# eccomi 3 4
# eccomi 3 5
# eccomi 3 6
# eccomi 3 7
# eccomi 3 8
# eccomi 3 9
# eccomi 3 10
# eccomi 3 11
# eccomi 3 12
# eccomi 3 13
# eccomi 3 14
# eccomi 3 15
# eccomi 3 16
# eccomi 3 17
# eccomi 3 18
# eccomi 3 19
# eccomi 3 20
# eccomi 3 21
# eccomi 3 22
# eccomi 3 23
# eccomi 3 24
# 4 29 0 0.9912992870992412 0.014574498744287538
# eccomi 4 0
# eccomi 4 1
# eccomi 4 2
# eccomi 4 3
# eccomi 4 4
# eccomi 4 5
# eccomi 4 6
# eccomi 4 7
# eccomi 4 8
# eccomi 4 9
# eccomi 4 10
# eccomi 4 11
# eccomi 4 12
# eccomi 4 13
# eccomi 4 14
# eccomi 4 15
# eccomi 4 16
# eccomi 4 17
# eccomi 4 18
# eccomi 4 19
# eccomi 4 20
# eccomi 4 21
# eccomi 4 22
# eccomi 4 23
# eccomi 4 24
# eccomi 4 25
# 5 29 0 0.09618390589229986 0.014574498744287538
# eccomi 5 0
# eccomi 5 1
# eccomi 5 2
# eccomi 5 3
# eccomi 5 4
# 6 29 0 0.09869126575872722 0.014574498744287538
# eccomi 6 0
# eccomi 6 1
# eccomi 6 2
# eccomi 6 3
# eccomi 6 4
# 7 29 0 0.7020212199462612 0.014574498744287538
# eccomi 7 0
# eccomi 7 1
# eccomi 7 2
# eccomi 7 3
# eccomi 7 4
# eccomi 7 5
# eccomi 7 6
# eccomi 7 7
# eccomi 7 8
# eccomi 7 9
# eccomi 7 10
# eccomi 7 11
# eccomi 7 12
# eccomi 7 13
# eccomi 7 14
# eccomi 7 15
# eccomi 7 16
# eccomi 7 17
# eccomi 7 18
# eccomi 7 19
# 8 29 0 0.24180407945653948 0.014574498744287538
# eccomi 8 0
# eccomi 8 1
# eccomi 8 2
# eccomi 8 3
# eccomi 8 4
# eccomi 8 5
# eccomi 8 6
# eccomi 8 7
# eccomi 8 8
# eccomi 8 9
# 9 29 0 0.9048793608750948 0.014574498744287538
# eccomi 9 0
# eccomi 9 1
# eccomi 9 2
# eccomi 9 3
# eccomi 9 4
# eccomi 9 5
# eccomi 9 6
# eccomi 9 7
# eccomi 9 8
# eccomi 9 9
# eccomi 9 10
# eccomi 9 11
# eccomi 9 12
# eccomi 9 13
# eccomi 9 14
# eccomi 9 15
# eccomi 9 16
# eccomi 9 17
# eccomi 9 18
# eccomi 9 19
# eccomi 9 20
# eccomi 9 21
# eccomi 9 22
# eccomi 9 23
# eccomi 9 24
# 10 29 0 0.8638754110740533 0.014574498744287538
# eccomi 10 0
# eccomi 10 1
# eccomi 10 2
# eccomi 10 3
# eccomi 10 4
# eccomi 10 5
# eccomi 10 6
# eccomi 10 7
# eccomi 10 8
# eccomi 10 9
# eccomi 10 10
# eccomi 10 11
# eccomi 10 12
# eccomi 10 13
# eccomi 10 14
# eccomi 10 15
# eccomi 10 16
# eccomi 10 17
# eccomi 10 18
# eccomi 10 19
# eccomi 10 20
# eccomi 10 21
# eccomi 10 22
# eccomi 10 23
# eccomi 10 24
# 11 29 0 0.2879663204079226 0.014574498744287538
# eccomi 11 0
# eccomi 11 1
# eccomi 11 2
# eccomi 11 3
# eccomi 11 4
# eccomi 11 5
# eccomi 11 6
# eccomi 11 7
# eccomi 11 8
# eccomi 11 9
# 12 29 0 0.7996524137168165 0.014574498744287538
# eccomi 12 0
# eccomi 12 1
# eccomi 12 2
# eccomi 12 3
# eccomi 12 4
# eccomi 12 5
# eccomi 12 6
# eccomi 12 7
# eccomi 12 8
# eccomi 12 9
# eccomi 12 10
# eccomi 12 11
# eccomi 12 12
# eccomi 12 13
# eccomi 12 14
# eccomi 12 15
# eccomi 12 16
# eccomi 12 17
# eccomi 12 18
# eccomi 12 19
# eccomi 12 20
# eccomi 12 21
# 13 29 0 0.0810744841463713 0.014574498744287538
# eccomi 13 0
# eccomi 13 1
# eccomi 13 2
# eccomi 13 3
# eccomi 13 4
# 14 29 0 0.7674048740599093 0.014574498744287538
# eccomi 14 0
# eccomi 14 1
# eccomi 14 2
# eccomi 14 3
# eccomi 14 4
# eccomi 14 5
# eccomi 14 6
# eccomi 14 7
# eccomi 14 8
# eccomi 14 9
# eccomi 14 10
# eccomi 14 11
# eccomi 14 12
# eccomi 14 13
# eccomi 14 14
# eccomi 14 15
# eccomi 14 16
# eccomi 14 17
# eccomi 14 18
# eccomi 14 19
# eccomi 14 20
# 15 29 0 0.23496868170561813 0.014574498744287538
# eccomi 15 0
# eccomi 15 1
# eccomi 15 2
# eccomi 15 3
# eccomi 15 4
# eccomi 15 5
# eccomi 15 6
# eccomi 15 7
# eccomi 15 8
# eccomi 15 9
# 16 29 0 0.5064833252795203 0.014574498744287538
# eccomi 16 0
# eccomi 16 1
# eccomi 16 2
# eccomi 16 3
# eccomi 16 4
# eccomi 16 5
# eccomi 16 6
# eccomi 16 7
# eccomi 16 8
# eccomi 16 9
# eccomi 16 10
# eccomi 16 11
# eccomi 16 12
# eccomi 16 13
# 17 29 0 0.801039303284621 0.014574498744287538
# eccomi 17 0
# eccomi 17 1
# eccomi 17 2
# eccomi 17 3
# eccomi 17 4
# eccomi 17 5
# eccomi 17 6
# eccomi 17 7
# eccomi 17 8
# eccomi 17 9
# eccomi 17 10
# eccomi 17 11
# eccomi 17 12
# eccomi 17 13
# eccomi 17 14
# eccomi 17 15
# eccomi 17 16
# eccomi 17 17
# eccomi 17 18
# eccomi 17 19
# eccomi 17 20
# eccomi 17 21
# 18 29 0 0.47309172435324154 0.014574498744287538
# eccomi 18 0
# eccomi 18 1
# eccomi 18 2
# eccomi 18 3
# eccomi 18 4
# eccomi 18 5
# eccomi 18 6
# eccomi 18 7
# eccomi 18 8
# eccomi 18 9
# eccomi 18 10
# eccomi 18 11
# eccomi 18 12
# eccomi 18 13
# 19 29 0 0.9687548830305943 0.014574498744287538
# eccomi 19 0
# eccomi 19 1
# eccomi 19 2
# eccomi 19 3
# eccomi 19 4
# eccomi 19 5
# eccomi 19 6
# eccomi 19 7
# eccomi 19 8
# eccomi 19 9
# eccomi 19 10
# eccomi 19 11
# eccomi 19 12
# eccomi 19 13
# eccomi 19 14
# eccomi 19 15
# eccomi 19 16
# eccomi 19 17
# eccomi 19 18
# eccomi 19 19
# eccomi 19 20
# eccomi 19 21
# eccomi 19 22
# eccomi 19 23
# eccomi 19 24
# 20 29 0 0.754392651580996 0.014574498744287538
# eccomi 20 0
# eccomi 20 1
# eccomi 20 2
# eccomi 20 3
# eccomi 20 4
# eccomi 20 5
# eccomi 20 6
# eccomi 20 7
# eccomi 20 8
# eccomi 20 9
# eccomi 20 10
# eccomi 20 11
# eccomi 20 12
# eccomi 20 13
# eccomi 20 14
# eccomi 20 15
# eccomi 20 16
# eccomi 20 17
# eccomi 20 18
# eccomi 20 19
# eccomi 20 20
# 21 29 0 0.04246630399715723 0.014574498744287538
# eccomi 21 0
# eccomi 21 1
# 22 29 0 0.5208764792929332 0.014574498744287538
# eccomi 22 0
# eccomi 22 1
# eccomi 22 2
# eccomi 22 3
# eccomi 22 4
# eccomi 22 5
# eccomi 22 6
# eccomi 22 7
# eccomi 22 8
# eccomi 22 9
# eccomi 22 10
# eccomi 22 11
# eccomi 22 12
# eccomi 22 13
# 23 29 0 0.9996268388190226 0.014574498744287538
# eccomi 23 0
# eccomi 23 1
# eccomi 23 2
# eccomi 23 3
# eccomi 23 4
# eccomi 23 5
# eccomi 23 6
# eccomi 23 7
# eccomi 23 8
# eccomi 23 9
# eccomi 23 10
# eccomi 23 11
# eccomi 23 12
# eccomi 23 13
# eccomi 23 14
# eccomi 23 15
# eccomi 23 16
# eccomi 23 17
# eccomi 23 18
# eccomi 23 19
# eccomi 23 20
# eccomi 23 21
# eccomi 23 22
# eccomi 23 23
# eccomi 23 24
# eccomi 23 25
# 24 29 0 0.8008076362553173 0.014574498744287538
# eccomi 24 0
# eccomi 24 1
# eccomi 24 2
# eccomi 24 3
# eccomi 24 4
# eccomi 24 5
# eccomi 24 6
# eccomi 24 7
# eccomi 24 8
# eccomi 24 9
# eccomi 24 10
# eccomi 24 11
# eccomi 24 12
# eccomi 24 13
# eccomi 24 14
# eccomi 24 15
# eccomi 24 16
# eccomi 24 17
# eccomi 24 18
# eccomi 24 19
# eccomi 24 20
# eccomi 24 21
# 25 29 0 0.934624842720842 0.014574498744287538
# eccomi 25 0
# eccomi 25 1
# eccomi 25 2
# eccomi 25 3
# eccomi 25 4
# eccomi 25 5
# eccomi 25 6
# eccomi 25 7
# eccomi 25 8
# eccomi 25 9
# eccomi 25 10
# eccomi 25 11
# eccomi 25 12
# eccomi 25 13
# eccomi 25 14
# eccomi 25 15
# eccomi 25 16
# eccomi 25 17
# eccomi 25 18
# eccomi 25 19
# eccomi 25 20
# eccomi 25 21
# eccomi 25 22
# eccomi 25 23
# eccomi 25 24
# 26 29 0 0.12900942682846195 0.014574498744287538
# eccomi 26 0
# eccomi 26 1
# eccomi 26 2
# eccomi 26 3
# eccomi 26 4
# eccomi 26 5
# eccomi 26 6
# eccomi 26 7
# 27 29 0 0.8775462625218838 0.014574498744287538
# eccomi 27 0
# eccomi 27 1
# eccomi 27 2
# eccomi 27 3
# eccomi 27 4
# eccomi 27 5
# eccomi 27 6
# eccomi 27 7
# eccomi 27 8
# eccomi 27 9
# eccomi 27 10
# eccomi 27 11
# eccomi 27 12
# eccomi 27 13
# eccomi 27 14
# eccomi 27 15
# eccomi 27 16
# eccomi 27 17
# eccomi 27 18
# eccomi 27 19
# eccomi 27 20
# eccomi 27 21
# eccomi 27 22
# eccomi 27 23
# eccomi 27 24
# 28 29 0 0.3276633573370824 0.014574498744287538
# eccomi 28 0
# eccomi 28 1
# eccomi 28 2
# eccomi 28 3
# eccomi 28 4
# eccomi 28 5
# eccomi 28 6
# eccomi 28 7
# eccomi 28 8
# eccomi 28 9
# eccomi 28 10
# 29 29 0 0.5411235329630625 0.014574498744287538
# eccomi 29 0
# eccomi 29 1
# eccomi 29 2
# eccomi 29 3
# eccomi 29 4
# eccomi 29 5
# eccomi 29 6
# eccomi 29 7
# eccomi 29 8
# eccomi 29 9
# eccomi 29 10
# eccomi 29 11
# eccomi 29 12
# eccomi 29 13
# 30 29 0 0.8332275141052445 0.014574498744287538
# eccomi 30 0
# eccomi 30 1
# eccomi 30 2
# eccomi 30 3
# eccomi 30 4
# eccomi 30 5
# eccomi 30 6
# eccomi 30 7
# eccomi 30 8
# eccomi 30 9
# eccomi 30 10
# eccomi 30 11
# eccomi 30 12
# eccomi 30 13
# eccomi 30 14
# eccomi 30 15
# eccomi 30 16
# eccomi 30 17
# eccomi 30 18
# eccomi 30 19
# eccomi 30 20
# eccomi 30 21
# eccomi 30 22
# 31 29 0 0.21596850773717102 0.014574498744287538
# eccomi 31 0
# eccomi 31 1
# eccomi 31 2
# eccomi 31 3
# eccomi 31 4
# eccomi 31 5
# eccomi 31 6
# eccomi 31 7
# eccomi 31 8
# 32 29 0 0.7102343201509955 0.014574498744287538
# eccomi 32 0
# eccomi 32 1
# eccomi 32 2
# eccomi 32 3
# eccomi 32 4
# eccomi 32 5
# eccomi 32 6
# eccomi 32 7
# eccomi 32 8
# eccomi 32 9
# eccomi 32 10
# eccomi 32 11
# eccomi 32 12
# eccomi 32 13
# eccomi 32 14
# eccomi 32 15
# eccomi 32 16
# eccomi 32 17
# eccomi 32 18
# eccomi 32 19
# 33 29 0 0.07641340746932856 0.014574498744287538
# eccomi 33 0
# eccomi 33 1
# eccomi 33 2
# eccomi 33 3
# eccomi 33 4
# 34 29 0 0.9568491078213573 0.014574498744287538
# eccomi 34 0
# eccomi 34 1
# eccomi 34 2
# eccomi 34 3
# eccomi 34 4
# eccomi 34 5
# eccomi 34 6
# eccomi 34 7
# eccomi 34 8
# eccomi 34 9
# eccomi 34 10
# eccomi 34 11
# eccomi 34 12
# eccomi 34 13
# eccomi 34 14
# eccomi 34 15
# eccomi 34 16
# eccomi 34 17
# eccomi 34 18
# eccomi 34 19
# eccomi 34 20
# eccomi 34 21
# eccomi 34 22
# eccomi 34 23
# eccomi 34 24
# 35 29 0 0.4636851134747434 0.014574498744287538
# eccomi 35 0
# eccomi 35 1
# eccomi 35 2
# eccomi 35 3
# eccomi 35 4
# eccomi 35 5
# eccomi 35 6
# eccomi 35 7
# eccomi 35 8
# eccomi 35 9
# eccomi 35 10
# eccomi 35 11
# eccomi 35 12
# eccomi 35 13
# 36 29 0 0.6205159715449179 0.014574498744287538
# eccomi 36 0
# eccomi 36 1
# eccomi 36 2
# eccomi 36 3
# eccomi 36 4
# eccomi 36 5
# eccomi 36 6
# eccomi 36 7
# eccomi 36 8
# eccomi 36 9
# eccomi 36 10
# eccomi 36 11
# eccomi 36 12
# eccomi 36 13
# eccomi 36 14
# eccomi 36 15
# eccomi 36 16
# eccomi 36 17
# eccomi 36 18
# 0 29 1 0.29988468382219624 0.024089962938518557
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# 1 29 1 0.6551364667212168 0.024089962938518557
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# eccomi 1 10
# eccomi 1 11
# eccomi 1 12
# eccomi 1 13
# eccomi 1 14
# eccomi 1 15
# eccomi 1 16
# eccomi 1 17
# eccomi 1 18
# 2 29 1 0.4248350406568159 0.024089962938518557
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# eccomi 2 5
# eccomi 2 6
# eccomi 2 7
# eccomi 2 8
# eccomi 2 9
# eccomi 2 10
# eccomi 2 11
# 0 29 2 0.9929057782375315 0.02434141874480908
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# eccomi 0 14
# eccomi 0 15
# eccomi 0 16
# eccomi 0 17
# eccomi 0 18
# eccomi 0 19
# eccomi 0 20
# eccomi 0 21
# eccomi 0 22
# eccomi 0 23
# eccomi 0 24
# eccomi 0 25
# 0 30 0 0.6034802943179131 0.015261665068459856
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# eccomi 0 14
# eccomi 0 15
# eccomi 0 16
# eccomi 0 17
# eccomi 0 18
# 1 30 0 0.2299926349120841 0.015261665068459856
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# 2 30 0 0.4683846540845604 0.015261665068459856
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# eccomi 2 5
# eccomi 2 6
# eccomi 2 7
# eccomi 2 8
# eccomi 2 9
# eccomi 2 10
# eccomi 2 11
# eccomi 2 12
# eccomi 2 13
# 3 30 0 0.9183545478166957 0.015261665068459856
# eccomi 3 0
# eccomi 3 1
# eccomi 3 2
# eccomi 3 3
# eccomi 3 4
# eccomi 3 5
# eccomi 3 6
# eccomi 3 7
# eccomi 3 8
# eccomi 3 9
# eccomi 3 10
# eccomi 3 11
# eccomi 3 12
# eccomi 3 13
# eccomi 3 14
# eccomi 3 15
# eccomi 3 16
# eccomi 3 17
# eccomi 3 18
# eccomi 3 19
# eccomi 3 20
# eccomi 3 21
# eccomi 3 22
# eccomi 3 23
# eccomi 3 24
# 4 30 0 0.9339654213593493 0.015261665068459856
# eccomi 4 0
# eccomi 4 1
# eccomi 4 2
# eccomi 4 3
# eccomi 4 4
# eccomi 4 5
# eccomi 4 6
# eccomi 4 7
# eccomi 4 8
# eccomi 4 9
# eccomi 4 10
# eccomi 4 11
# eccomi 4 12
# eccomi 4 13
# eccomi 4 14
# eccomi 4 15
# eccomi 4 16
# eccomi 4 17
# eccomi 4 18
# eccomi 4 19
# eccomi 4 20
# eccomi 4 21
# eccomi 4 22
# eccomi 4 23
# eccomi 4 24
# 5 30 0 0.9454542791260668 0.015261665068459856
# eccomi 5 0
# eccomi 5 1
# eccomi 5 2
# eccomi 5 3
# eccomi 5 4
# eccomi 5 5
# eccomi 5 6
# eccomi 5 7
# eccomi 5 8
# eccomi 5 9
# eccomi 5 10
# eccomi 5 11
# eccomi 5 12
# eccomi 5 13
# eccomi 5 14
# eccomi 5 15
# eccomi 5 16
# eccomi 5 17
# eccomi 5 18
# eccomi 5 19
# eccomi 5 20
# eccomi 5 21
# eccomi 5 22
# eccomi 5 23
# eccomi 5 24
# 6 30 0 0.5015182220619817 0.015261665068459856
# eccomi 6 0
# eccomi 6 1
# eccomi 6 2
# eccomi 6 3
# eccomi 6 4
# eccomi 6 5
# eccomi 6 6
# eccomi 6 7
# eccomi 6 8
# eccomi 6 9
# eccomi 6 10
# eccomi 6 11
# eccomi 6 12
# eccomi 6 13
# 7 30 0 0.7038599920591674 0.015261665068459856
# eccomi 7 0
# eccomi 7 1
# eccomi 7 2
# eccomi 7 3
# eccomi 7 4
# eccomi 7 5
# eccomi 7 6
# eccomi 7 7
# eccomi 7 8
# eccomi 7 9
# eccomi 7 10
# eccomi 7 11
# eccomi 7 12
# eccomi 7 13
# eccomi 7 14
# eccomi 7 15
# eccomi 7 16
# eccomi 7 17
# eccomi 7 18
# eccomi 7 19
# 8 30 0 0.7240340859089803 0.015261665068459856
# eccomi 8 0
# eccomi 8 1
# eccomi 8 2
# eccomi 8 3
# eccomi 8 4
# eccomi 8 5
# eccomi 8 6
# eccomi 8 7
# eccomi 8 8
# eccomi 8 9
# eccomi 8 10
# eccomi 8 11
# eccomi 8 12
# eccomi 8 13
# eccomi 8 14
# eccomi 8 15
# eccomi 8 16
# eccomi 8 17
# eccomi 8 18
# eccomi 8 19
# 9 30 0 0.703256749858213 0.015261665068459856
# eccomi 9 0
# eccomi 9 1
# eccomi 9 2
# eccomi 9 3
# eccomi 9 4
# eccomi 9 5
# eccomi 9 6
# eccomi 9 7
# eccomi 9 8
# eccomi 9 9
# eccomi 9 10
# eccomi 9 11
# eccomi 9 12
# eccomi 9 13
# eccomi 9 14
# eccomi 9 15
# eccomi 9 16
# eccomi 9 17
# eccomi 9 18
# eccomi 9 19
# 10 30 0 0.7761763654337266 0.015261665068459856
# eccomi 10 0
# eccomi 10 1
# eccomi 10 2
# eccomi 10 3
# eccomi 10 4
# eccomi 10 5
# eccomi 10 6
# eccomi 10 7
# eccomi 10 8
# eccomi 10 9
# eccomi 10 10
# eccomi 10 11
# eccomi 10 12
# eccomi 10 13
# eccomi 10 14
# eccomi 10 15
# eccomi 10 16
# eccomi 10 17
# eccomi 10 18
# eccomi 10 19
# eccomi 10 20
# eccomi 10 21
# 11 30 0 0.3283141106954084 0.015261665068459856
# eccomi 11 0
# eccomi 11 1
# eccomi 11 2
# eccomi 11 3
# eccomi 11 4
# eccomi 11 5
# eccomi 11 6
# eccomi 11 7
# eccomi 11 8
# eccomi 11 9
# 12 30 0 0.3517293046186789 0.015261665068459856
# eccomi 12 0
# eccomi 12 1
# eccomi 12 2
# eccomi 12 3
# eccomi 12 4
# eccomi 12 5
# eccomi 12 6
# eccomi 12 7
# eccomi 12 8
# eccomi 12 9
# eccomi 12 10
# 13 30 0 0.6894298655784213 0.015261665068459856
# eccomi 13 0
# eccomi 13 1
# eccomi 13 2
# eccomi 13 3
# eccomi 13 4
# eccomi 13 5
# eccomi 13 6
# eccomi 13 7
# eccomi 13 8
# eccomi 13 9
# eccomi 13 10
# eccomi 13 11
# eccomi 13 12
# eccomi 13 13
# eccomi 13 14
# eccomi 13 15
# eccomi 13 16
# eccomi 13 17
# eccomi 13 18
# eccomi 13 19
# 14 30 0 0.8810125763701019 0.015261665068459856
# eccomi 14 0
# eccomi 14 1
# eccomi 14 2
# eccomi 14 3
# eccomi 14 4
# eccomi 14 5
# eccomi 14 6
# eccomi 14 7
# eccomi 14 8
# eccomi 14 9
# eccomi 14 10
# eccomi 14 11
# eccomi 14 12
# eccomi 14 13
# eccomi 14 14
# eccomi 14 15
# eccomi 14 16
# eccomi 14 17
# eccomi 14 18
# eccomi 14 19
# eccomi 14 20
# eccomi 14 21
# eccomi 14 22
# eccomi 14 23
# eccomi 14 24
# 15 30 0 0.5235276733396251 0.015261665068459856
# eccomi 15 0
# eccomi 15 1
# eccomi 15 2
# eccomi 15 3
# eccomi 15 4
# eccomi 15 5
# eccomi 15 6
# eccomi 15 7
# eccomi 15 8
# eccomi 15 9
# eccomi 15 10
# eccomi 15 11
# eccomi 15 12
# eccomi 15 13
# 16 30 0 0.7103919058812068 0.015261665068459856
# eccomi 16 0
# eccomi 16 1
# eccomi 16 2
# eccomi 16 3
# eccomi 16 4
# eccomi 16 5
# eccomi 16 6
# eccomi 16 7
# eccomi 16 8
# eccomi 16 9
# eccomi 16 10
# eccomi 16 11
# eccomi 16 12
# eccomi 16 13
# eccomi 16 14
# eccomi 16 15
# eccomi 16 16
# eccomi 16 17
# eccomi 16 18
# eccomi 16 19
# 17 30 0 0.5725611676859967 0.015261665068459856
# eccomi 17 0
# eccomi 17 1
# eccomi 17 2
# eccomi 17 3
# eccomi 17 4
# eccomi 17 5
# eccomi 17 6
# eccomi 17 7
# eccomi 17 8
# eccomi 17 9
# eccomi 17 10
# eccomi 17 11
# eccomi 17 12
# eccomi 17 13
# 18 30 0 0.7685612292278227 0.015261665068459856
# eccomi 18 0
# eccomi 18 1
# eccomi 18 2
# eccomi 18 3
# eccomi 18 4
# eccomi 18 5
# eccomi 18 6
# eccomi 18 7
# eccomi 18 8
# eccomi 18 9
# eccomi 18 10
# eccomi 18 11
# eccomi 18 12
# eccomi 18 13
# eccomi 18 14
# eccomi 18 15
# eccomi 18 16
# eccomi 18 17
# eccomi 18 18
# eccomi 18 19
# eccomi 18 20
# 19 30 0 0.035516263772670364 0.015261665068459856
# eccomi 19 0
# eccomi 19 1
# 20 30 0 0.8729852909218582 0.015261665068459856
# eccomi 20 0
# eccomi 20 1
# eccomi 20 2
# eccomi 20 3
# eccomi 20 4
# eccomi 20 5
# eccomi 20 6
# eccomi 20 7
# eccomi 20 8
# eccomi 20 9
# eccomi 20 10
# eccomi 20 11
# eccomi 20 12
# eccomi 20 13
# eccomi 20 14
# eccomi 20 15
# eccomi 20 16
# eccomi 20 17
# eccomi 20 18
# eccomi 20 19
# eccomi 20 20
# eccomi 20 21
# eccomi 20 22
# eccomi 20 23
# eccomi 20 24
# 21 30 0 0.5567732899003174 0.015261665068459856
# eccomi 21 0
# eccomi 21 1
# eccomi 21 2
# eccomi 21 3
# eccomi 21 4
# eccomi 21 5
# eccomi 21 6
# eccomi 21 7
# eccomi 21 8
# eccomi 21 9
# eccomi 21 10
# eccomi 21 11
# eccomi 21 12
# eccomi 21 13
# 22 30 0 0.7527644050443564 0.015261665068459856
# eccomi 22 0
# eccomi 22 1
# eccomi 22 2
# eccomi 22 3
# eccomi 22 4
# eccomi 22 5
# eccomi 22 6
# eccomi 22 7
# eccomi 22 8
# eccomi 22 9
# eccomi 22 10
# eccomi 22 11
# eccomi 22 12
# eccomi 22 13
# eccomi 22 14
# eccomi 22 15
# eccomi 22 16
# eccomi 22 17
# eccomi 22 18
# eccomi 22 19
# eccomi 22 20
# 23 30 0 0.4079627435828238 0.015261665068459856
# eccomi 23 0
# eccomi 23 1
# eccomi 23 2
# eccomi 23 3
# eccomi 23 4
# eccomi 23 5
# eccomi 23 6
# eccomi 23 7
# eccomi 23 8
# eccomi 23 9
# eccomi 23 10
# eccomi 23 11
# 24 30 0 0.20130489228805415 0.015261665068459856
# eccomi 24 0
# eccomi 24 1
# eccomi 24 2
# eccomi 24 3
# eccomi 24 4
# eccomi 24 5
# eccomi 24 6
# eccomi 24 7
# eccomi 24 8
# 25 30 0 0.9844410697291035 0.015261665068459856
# eccomi 25 0
# eccomi 25 1
# eccomi 25 2
# eccomi 25 3
# eccomi 25 4
# eccomi 25 5
# eccomi 25 6
# eccomi 25 7
# eccomi 25 8
# eccomi 25 9
# eccomi 25 10
# eccomi 25 11
# eccomi 25 12
# eccomi 25 13
# eccomi 25 14
# eccomi 25 15
# eccomi 25 16
# eccomi 25 17
# eccomi 25 18
# eccomi 25 19
# eccomi 25 20
# eccomi 25 21
# eccomi 25 22
# eccomi 25 23
# eccomi 25 24
# eccomi 25 25
# 26 30 0 0.24791720220722835 0.015261665068459856
# eccomi 26 0
# eccomi 26 1
# eccomi 26 2
# eccomi 26 3
# eccomi 26 4
# eccomi 26 5
# eccomi 26 6
# eccomi 26 7
# eccomi 26 8
# 0 30 1 0.12967047906888585 0.02938676839978092
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# 1 30 1 0.7533425451202288 0.02938676839978092
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# eccomi 1 10
# eccomi 1 11
# eccomi 1 12
# eccomi 1 13
# eccomi 1 14
# eccomi 1 15
# eccomi 1 16
# eccomi 1 17
# eccomi 1 18
# 0 30 2 0.6873515452703255 0.027246188777165097
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# 0 30 0 0.6909025272812283 0.015261665068459856
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# eccomi 0 14
# eccomi 0 15
# eccomi 0 16
# eccomi 0 17
# eccomi 0 18
# eccomi 0 19
# 0 30 0 0.38813774077752794 0.015261665068459856
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# 1 30 0 0.32234607922725556 0.015261665068459856
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# 2 30 0 0.1434005740123816 0.015261665068459856
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# eccomi 2 5
# eccomi 2 6
# eccomi 2 7
# eccomi 2 8
# 3 30 0 0.34437220466906626 0.015261665068459856
# eccomi 3 0
# eccomi 3 1
# eccomi 3 2
# eccomi 3 3
# eccomi 3 4
# eccomi 3 5
# eccomi 3 6
# eccomi 3 7
# eccomi 3 8
# eccomi 3 9
# eccomi 3 10
# 4 30 0 0.6257299291487626 0.015261665068459856
# eccomi 4 0
# eccomi 4 1
# eccomi 4 2
# eccomi 4 3
# eccomi 4 4
# eccomi 4 5
# eccomi 4 6
# eccomi 4 7
# eccomi 4 8
# eccomi 4 9
# eccomi 4 10
# eccomi 4 11
# eccomi 4 12
# eccomi 4 13
# eccomi 4 14
# eccomi 4 15
# eccomi 4 16
# eccomi 4 17
# eccomi 4 18
# 5 30 0 0.20681489124891717 0.015261665068459856
# eccomi 5 0
# eccomi 5 1
# eccomi 5 2
# eccomi 5 3
# eccomi 5 4
# eccomi 5 5
# eccomi 5 6
# eccomi 5 7
# eccomi 5 8
# 6 30 0 0.0006757061819260279 0.015261665068459856
# 7 30 0 0.06529490073233346 0.015261665068459856
# eccomi 7 0
# eccomi 7 1
# eccomi 7 2
# 8 30 0 0.9969139583057991 0.015261665068459856
# eccomi 8 0
# eccomi 8 1
# eccomi 8 2
# eccomi 8 3
# eccomi 8 4
# eccomi 8 5
# eccomi 8 6
# eccomi 8 7
# eccomi 8 8
# eccomi 8 9
# eccomi 8 10
# eccomi 8 11
# eccomi 8 12
# eccomi 8 13
# eccomi 8 14
# eccomi 8 15
# eccomi 8 16
# eccomi 8 17
# eccomi 8 18
# eccomi 8 19
# eccomi 8 20
# eccomi 8 21
# eccomi 8 22
# eccomi 8 23
# eccomi 8 24
# eccomi 8 25
# 9 30 0 0.6414947613677363 0.015261665068459856
# eccomi 9 0
# eccomi 9 1
# eccomi 9 2
# eccomi 9 3
# eccomi 9 4
# eccomi 9 5
# eccomi 9 6
# eccomi 9 7
# eccomi 9 8
# eccomi 9 9
# eccomi 9 10
# eccomi 9 11
# eccomi 9 12
# eccomi 9 13
# eccomi 9 14
# eccomi 9 15
# eccomi 9 16
# eccomi 9 17
# eccomi 9 18
# 10 30 0 0.6466037702103286 0.015261665068459856
# eccomi 10 0
# eccomi 10 1
# eccomi 10 2
# eccomi 10 3
# eccomi 10 4
# eccomi 10 5
# eccomi 10 6
# eccomi 10 7
# eccomi 10 8
# eccomi 10 9
# eccomi 10 10
# eccomi 10 11
# eccomi 10 12
# eccomi 10 13
# eccomi 10 14
# eccomi 10 15
# eccomi 10 16
# eccomi 10 17
# eccomi 10 18
# 0 30 1 0.6874045831400412 0.02938676839978092
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# 0 31 0 0.8971370191487837 0.011384039783035807
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# eccomi 0 14
# eccomi 0 15
# eccomi 0 16
# eccomi 0 17
# eccomi 0 18
# eccomi 0 19
# eccomi 0 20
# eccomi 0 21
# eccomi 0 22
# eccomi 0 23
# eccomi 0 24
# 0 31 0 0.6209481080076785 0.011384039783035807
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# eccomi 0 14
# eccomi 0 15
# eccomi 0 16
# eccomi 0 17
# eccomi 0 18
# eccomi 0 19
# 1 31 0 0.34818220695788527 0.011384039783035807
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# eccomi 1 10
# eccomi 1 11
# 2 31 0 0.03375498169250901 0.011384039783035807
# eccomi 2 0
# eccomi 2 1
# 3 31 0 0.2590503508557178 0.011384039783035807
# eccomi 3 0
# eccomi 3 1
# eccomi 3 2
# eccomi 3 3
# eccomi 3 4
# eccomi 3 5
# eccomi 3 6
# eccomi 3 7
# eccomi 3 8
# eccomi 3 9
# 4 31 0 0.8585798827157741 0.011384039783035807
# eccomi 4 0
# eccomi 4 1
# eccomi 4 2
# eccomi 4 3
# eccomi 4 4
# eccomi 4 5
# eccomi 4 6
# eccomi 4 7
# eccomi 4 8
# eccomi 4 9
# eccomi 4 10
# eccomi 4 11
# eccomi 4 12
# eccomi 4 13
# eccomi 4 14
# eccomi 4 15
# eccomi 4 16
# eccomi 4 17
# eccomi 4 18
# eccomi 4 19
# eccomi 4 20
# eccomi 4 21
# eccomi 4 22
# eccomi 4 23
# eccomi 4 24
# 5 31 0 0.7473685744199253 0.011384039783035807
# eccomi 5 0
# eccomi 5 1
# eccomi 5 2
# eccomi 5 3
# eccomi 5 4
# eccomi 5 5
# eccomi 5 6
# eccomi 5 7
# eccomi 5 8
# eccomi 5 9
# eccomi 5 10
# eccomi 5 11
# eccomi 5 12
# eccomi 5 13
# eccomi 5 14
# eccomi 5 15
# eccomi 5 16
# eccomi 5 17
# eccomi 5 18
# eccomi 5 19
# eccomi 5 20
# eccomi 5 21
# 6 31 0 0.8459856907929316 0.011384039783035807
# eccomi 6 0
# eccomi 6 1
# eccomi 6 2
# eccomi 6 3
# eccomi 6 4
# eccomi 6 5
# eccomi 6 6
# eccomi 6 7
# eccomi 6 8
# eccomi 6 9
# eccomi 6 10
# eccomi 6 11
# eccomi 6 12
# eccomi 6 13
# eccomi 6 14
# eccomi 6 15
# eccomi 6 16
# eccomi 6 17
# eccomi 6 18
# eccomi 6 19
# eccomi 6 20
# eccomi 6 21
# eccomi 6 22
# eccomi 6 23
# eccomi 6 24
# 0 34 0 0.5617050103667285 0.008291343212486138
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# eccomi 0 14
# eccomi 0 15
# eccomi 0 16
# eccomi 0 17
# eccomi 0 18
# 1 34 0 0.968660984958348 0.008291343212486138
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# eccomi 1 10
# eccomi 1 11
# eccomi 1 12
# eccomi 1 13
# eccomi 1 14
# eccomi 1 15
# eccomi 1 16
# eccomi 1 17
# eccomi 1 18
# eccomi 1 19
# eccomi 1 20
# eccomi 1 21
# eccomi 1 22
# eccomi 1 23
# eccomi 1 24
# 2 34 0 0.18512445532003396 0.008291343212486138
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# eccomi 2 5
# eccomi 2 6
# eccomi 2 7
# eccomi 2 8
# 3 34 0 0.8626306806211853 0.008291343212486138
# eccomi 3 0
# eccomi 3 1
# eccomi 3 2
# eccomi 3 3
# eccomi 3 4
# eccomi 3 5
# eccomi 3 6
# eccomi 3 7
# eccomi 3 8
# eccomi 3 9
# eccomi 3 10
# eccomi 3 11
# eccomi 3 12
# eccomi 3 13
# eccomi 3 14
# eccomi 3 15
# eccomi 3 16
# eccomi 3 17
# eccomi 3 18
# eccomi 3 19
# eccomi 3 20
# eccomi 3 21
# eccomi 3 22
# eccomi 3 23
# 4 34 0 0.8462316873815839 0.008291343212486138
# eccomi 4 0
# eccomi 4 1
# eccomi 4 2
# eccomi 4 3
# eccomi 4 4
# eccomi 4 5
# eccomi 4 6
# eccomi 4 7
# eccomi 4 8
# eccomi 4 9
# eccomi 4 10
# eccomi 4 11
# eccomi 4 12
# eccomi 4 13
# eccomi 4 14
# eccomi 4 15
# eccomi 4 16
# eccomi 4 17
# eccomi 4 18
# eccomi 4 19
# eccomi 4 20
# eccomi 4 21
# eccomi 4 22
# 5 34 0 0.5886960055326516 0.008291343212486138
# eccomi 5 0
# eccomi 5 1
# eccomi 5 2
# eccomi 5 3
# eccomi 5 4
# eccomi 5 5
# eccomi 5 6
# eccomi 5 7
# eccomi 5 8
# eccomi 5 9
# eccomi 5 10
# eccomi 5 11
# eccomi 5 12
# eccomi 5 13
# eccomi 5 14
# eccomi 5 15
# eccomi 5 16
# eccomi 5 17
# eccomi 5 18
# 6 34 0 0.8332083980900201 0.008291343212486138
# eccomi 6 0
# eccomi 6 1
# eccomi 6 2
# eccomi 6 3
# eccomi 6 4
# eccomi 6 5
# eccomi 6 6
# eccomi 6 7
# eccomi 6 8
# eccomi 6 9
# eccomi 6 10
# eccomi 6 11
# eccomi 6 12
# eccomi 6 13
# eccomi 6 14
# eccomi 6 15
# eccomi 6 16
# eccomi 6 17
# eccomi 6 18
# eccomi 6 19
# eccomi 6 20
# eccomi 6 21
# eccomi 6 22
# 0 35 0 0.5224426654938482 0.003920220082530949
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# 1 35 0 0.7495406464942276 0.003920220082530949
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# eccomi 1 10
# eccomi 1 11
# eccomi 1 12
# eccomi 1 13
# eccomi 1 14
# eccomi 1 15
# eccomi 1 16
# eccomi 1 17
# eccomi 1 18
# eccomi 1 19
# eccomi 1 20
# ...
# 3 56 0 0.007545204185906207 0.022934242013211148
# 4 56 0 0.9703136244116373 0.022934242013211148
# eccomi 4 0
# eccomi 4 1
# eccomi 4 2
# eccomi 4 3
# eccomi 4 4
# eccomi 4 5
# eccomi 4 6
# eccomi 4 7
# eccomi 4 8
# eccomi 4 9
# eccomi 4 10
# eccomi 4 11
# eccomi 4 12
# eccomi 4 13
# eccomi 4 14
# eccomi 4 15
# eccomi 4 16
# eccomi 4 17
# eccomi 4 18
# eccomi 4 19
# eccomi 4 20
# eccomi 4 21
# eccomi 4 22
# eccomi 4 23
# eccomi 4 24
# 0 57 0 0.48545304960816504 0.02717612274463966
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# 1 57 0 0.5081452841820279 0.02717612274463966
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# eccomi 1 10
# eccomi 1 11
# eccomi 1 12
# eccomi 1 13
# 2 57 0 0.19412288485881446 0.02717612274463966
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# eccomi 2 5
# eccomi 2 6
# eccomi 2 7
# eccomi 2 8
# 3 57 0 0.9412002887902325 0.02717612274463966
# eccomi 3 0
# eccomi 3 1
# eccomi 3 2
# eccomi 3 3
# eccomi 3 4
# eccomi 3 5
# eccomi 3 6
# eccomi 3 7
# eccomi 3 8
# eccomi 3 9
# eccomi 3 10
# eccomi 3 11
# eccomi 3 12
# eccomi 3 13
# eccomi 3 14
# eccomi 3 15
# eccomi 3 16
# eccomi 3 17
# eccomi 3 18
# eccomi 3 19
# eccomi 3 20
# eccomi 3 21
# eccomi 3 22
# eccomi 3 23
# eccomi 3 24
# 4 57 0 0.4340698736522821 0.02717612274463966
# eccomi 4 0
# eccomi 4 1
# eccomi 4 2
# eccomi 4 3
# eccomi 4 4
# eccomi 4 5
# eccomi 4 6
# eccomi 4 7
# eccomi 4 8
# eccomi 4 9
# 5 57 0 0.5954788673711782 0.02717612274463966
# eccomi 5 0
# eccomi 5 1
# eccomi 5 2
# eccomi 5 3
# eccomi 5 4
# eccomi 5 5
# eccomi 5 6
# eccomi 5 7
# eccomi 5 8
# eccomi 5 9
# eccomi 5 10
# eccomi 5 11
# eccomi 5 12
# eccomi 5 13
# 6 57 0 0.8540423579731791 0.02717612274463966
# eccomi 6 0
# eccomi 6 1
# eccomi 6 2
# eccomi 6 3
# eccomi 6 4
# eccomi 6 5
# eccomi 6 6
# eccomi 6 7
# eccomi 6 8
# eccomi 6 9
# eccomi 6 10
# eccomi 6 11
# eccomi 6 12
# eccomi 6 13
# eccomi 6 14
# eccomi 6 15
# eccomi 6 16
# eccomi 6 17
# eccomi 6 18
# eccomi 6 19
# eccomi 6 20
# 7 57 0 0.07729101274944983 0.02717612274463966
# eccomi 7 0
# eccomi 7 1
# eccomi 7 2
# eccomi 7 3
# eccomi 7 4
# eccomi 7 5
# 8 57 0 0.21235900201905566 0.02717612274463966
# eccomi 8 0
# eccomi 8 1
# eccomi 8 2
# eccomi 8 3
# eccomi 8 4
# eccomi 8 5
# eccomi 8 6
# eccomi 8 7
# eccomi 8 8
# 9 57 0 0.08780980200081434 0.02717612274463966
# eccomi 9 0
# eccomi 9 1
# eccomi 9 2
# eccomi 9 3
# eccomi 9 4
# eccomi 9 5
# eccomi 9 6
# eccomi 9 7
# 10 57 0 0.14230097887075221 0.02717612274463966
# eccomi 10 0
# eccomi 10 1
# eccomi 10 2
# eccomi 10 3
# eccomi 10 4
# eccomi 10 5
# eccomi 10 6
# eccomi 10 7
# eccomi 10 8
# 11 57 0 0.04937434534304652 0.02717612274463966
# eccomi 11 0
# 12 57 0 0.5964153301632734 0.02717612274463966
# eccomi 12 0
# eccomi 12 1
# eccomi 12 2
# eccomi 12 3
# eccomi 12 4
# eccomi 12 5
# eccomi 12 6
# eccomi 12 7
# eccomi 12 8
# eccomi 12 9
# eccomi 12 10
# eccomi 12 11
# eccomi 12 12
# eccomi 12 13
# 13 57 0 0.13018379583012984 0.02717612274463966
# eccomi 13 0
# eccomi 13 1
# eccomi 13 2
# eccomi 13 3
# eccomi 13 4
# eccomi 13 5
# eccomi 13 6
# eccomi 13 7
# eccomi 13 8
# 14 57 0 0.02174480525925704 0.02717612274463966
# 0 57 1 0.5403655764026607 0.0171873568483738
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# 0 57 0 0.0007831873034489512 0.02717612274463966
# 1 57 0 0.2629249082178805 0.02717612274463966
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# 2 57 0 0.3916934860625906 0.02717612274463966
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# eccomi 2 5
# eccomi 2 6
# eccomi 2 7
# eccomi 2 8
# eccomi 2 9
# 3 57 0 0.29902564588870306 0.02717612274463966
# eccomi 3 0
# eccomi 3 1
# eccomi 3 2
# eccomi 3 3
# eccomi 3 4
# eccomi 3 5
# eccomi 3 6
# eccomi 3 7
# eccomi 3 8
# 4 57 0 0.4805424361433215 0.02717612274463966
# eccomi 4 0
# eccomi 4 1
# eccomi 4 2
# eccomi 4 3
# eccomi 4 4
# eccomi 4 5
# eccomi 4 6
# eccomi 4 7
# eccomi 4 8
# eccomi 4 9
# eccomi 4 10
# eccomi 4 11
# 5 57 0 0.8354302843687165 0.02717612274463966
# eccomi 5 0
# eccomi 5 1
# eccomi 5 2
# eccomi 5 3
# eccomi 5 4
# eccomi 5 5
# eccomi 5 6
# eccomi 5 7
# eccomi 5 8
# eccomi 5 9
# eccomi 5 10
# eccomi 5 11
# eccomi 5 12
# eccomi 5 13
# eccomi 5 14
# eccomi 5 15
# eccomi 5 16
# eccomi 5 17
# eccomi 5 18
# eccomi 5 19
# eccomi 5 20
# 0 58 0 0.2157234248276051 0.09835980213486072
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# 1 58 0 0.10431991146633368 0.09835980213486072
# eccomi 1 0
# 2 58 0 0.7392116818631672 0.09835980213486072
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# eccomi 2 5
# eccomi 2 6
# eccomi 2 7
# eccomi 2 8
# eccomi 2 9
# eccomi 2 10
# eccomi 2 11
# eccomi 2 12
# eccomi 2 13
# eccomi 2 14
# eccomi 2 15
# eccomi 2 16
# eccomi 2 17
# eccomi 2 18
# 3 58 0 0.0468529278025277 0.09835980213486072
# 4 58 0 0.9842258067249573 0.09835980213486072
# eccomi 4 0
# eccomi 4 1
# eccomi 4 2
# eccomi 4 3
# eccomi 4 4
# eccomi 4 5
# eccomi 4 6
# eccomi 4 7
# eccomi 4 8
# eccomi 4 9
# eccomi 4 10
# eccomi 4 11
# eccomi 4 12
# eccomi 4 13
# eccomi 4 14
# eccomi 4 15
# eccomi 4 16
# eccomi 4 17
# eccomi 4 18
# eccomi 4 19
# eccomi 4 20
# eccomi 4 21
# eccomi 4 22
# eccomi 4 23
# eccomi 4 24
# eccomi 4 25
# 5 58 0 0.9281590192661027 0.09835980213486072
# eccomi 5 0
# eccomi 5 1
# eccomi 5 2
# eccomi 5 3
# eccomi 5 4
# eccomi 5 5
# eccomi 5 6
# eccomi 5 7
# eccomi 5 8
# eccomi 5 9
# eccomi 5 10
# eccomi 5 11
# eccomi 5 12
# eccomi 5 13
# eccomi 5 14
# eccomi 5 15
# eccomi 5 16
# eccomi 5 17
# eccomi 5 18
# eccomi 5 19
# eccomi 5 20
# 6 58 0 0.8799785930377976 0.09835980213486072
# eccomi 6 0
# eccomi 6 1
# eccomi 6 2
# eccomi 6 3
# eccomi 6 4
# eccomi 6 5
# eccomi 6 6
# eccomi 6 7
# eccomi 6 8
# eccomi 6 9
# eccomi 6 10
# eccomi 6 11
# eccomi 6 12
# eccomi 6 13
# eccomi 6 14
# eccomi 6 15
# eccomi 6 16
# eccomi 6 17
# eccomi 6 18
# eccomi 6 19
# 7 58 0 0.2787566861106139 0.09835980213486072
# eccomi 7 0
# eccomi 7 1
# eccomi 7 2
# eccomi 7 3
# eccomi 7 4
# eccomi 7 5
# eccomi 7 6
# eccomi 7 7
# eccomi 7 8
# eccomi 7 9
# 8 58 0 0.10153946583106688 0.09835980213486072
# eccomi 8 0
# 9 58 0 0.7455882217958292 0.09835980213486072
# eccomi 9 0
# eccomi 9 1
# eccomi 9 2
# eccomi 9 3
# eccomi 9 4
# eccomi 9 5
# eccomi 9 6
# eccomi 9 7
# eccomi 9 8
# eccomi 9 9
# eccomi 9 10
# eccomi 9 11
# eccomi 9 12
# eccomi 9 13
# eccomi 9 14
# eccomi 9 15
# eccomi 9 16
# eccomi 9 17
# eccomi 9 18
# 10 58 0 0.03331102250906437 0.09835980213486072
# 0 58 1 0.9809301677585743 0.007290095525389643
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# eccomi 0 14
# eccomi 0 15
# eccomi 0 16
# eccomi 0 17
# eccomi 0 18
# eccomi 0 19
# eccomi 0 20
# eccomi 0 21
# eccomi 0 22
# eccomi 0 23
# eccomi 0 24
# eccomi 0 25
# 0 58 0 0.16584760189986492 0.09835980213486072
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# 0 59 0 0.027613347863598814 0.03277008427561089
# 1 59 0 0.9974411249477396 0.03277008427561089
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# eccomi 1 10
# eccomi 1 11
# eccomi 1 12
# eccomi 1 13
# eccomi 1 14
# eccomi 1 15
# eccomi 1 16
# eccomi 1 17
# eccomi 1 18
# eccomi 1 19
# eccomi 1 20
# eccomi 1 21
# eccomi 1 22
# eccomi 1 23
# eccomi 1 24
# eccomi 1 25
# 2 59 0 0.734527822547037 0.03277008427561089
# eccomi 2 0
# eccomi 2 1
# eccomi 2 2
# eccomi 2 3
# eccomi 2 4
# eccomi 2 5
# eccomi 2 6
# eccomi 2 7
# eccomi 2 8
# eccomi 2 9
# eccomi 2 10
# eccomi 2 11
# eccomi 2 12
# eccomi 2 13
# eccomi 2 14
# eccomi 2 15
# eccomi 2 16
# eccomi 2 17
# eccomi 2 18
# eccomi 2 19
# eccomi 2 20
# 0 59 0 0.610474785634751 0.03277008427561089
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# eccomi 0 14
# eccomi 0 15
# eccomi 0 16
# eccomi 0 17
# eccomi 0 18
# 0 60 0 0.3831192284985061 0.023631683595616456
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# 1 60 0 0.7752151627098328 0.023631683595616456
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
# eccomi 1 9
# eccomi 1 10
# eccomi 1 11
# eccomi 1 12
# eccomi 1 13
# eccomi 1 14
# eccomi 1 15
# eccomi 1 16
# eccomi 1 17
# eccomi 1 18
# eccomi 1 19
# eccomi 1 20
# eccomi 1 21
# 0 60 0 0.7898609751037557 0.023631683595616456
# eccomi 0 0
# eccomi 0 1
# eccomi 0 2
# eccomi 0 3
# eccomi 0 4
# eccomi 0 5
# eccomi 0 6
# eccomi 0 7
# eccomi 0 8
# eccomi 0 9
# eccomi 0 10
# eccomi 0 11
# eccomi 0 12
# eccomi 0 13
# eccomi 0 14
# eccomi 0 15
# eccomi 0 16
# eccomi 0 17
# eccomi 0 18
# eccomi 0 19
# eccomi 0 20
# eccomi 0 21
# 1 60 0 0.2732378495044021 0.023631683595616456
# eccomi 1 0
# eccomi 1 1
# eccomi 1 2
# eccomi 1 3
# eccomi 1 4
# eccomi 1 5
# eccomi 1 6
# eccomi 1 7
# eccomi 1 8
#
#
# MEMO remember rankNum for multicore applications
#
# Markup tentative 25.0%
#                                     EU 27           simulation        simulation to
#                                                                            EU scale
#      AFF Firm Number             10000000                    0                    0
#    AFF Worker Number              9000000                    0                    0
#          Firm Number             21831369                  435             21831369
#        Worker Number            161702115                 2249            112870687
#       Empl. Compens.              7447036                   95              4811108
#            Capital R              6856862                   60              3046319
#              GDP VAT             16144780    N.B. contains VAT
#   Add. Val. curr. p.             14303899                  195              9821784
#  Int. goods curr. p.             16939701                  176              8866149
#
#  AFF => Agriculture, Forestry and Fishing
#
#
#
# INVESTMENT TABLES
#
# Investment regular substitution rate 0.1
# Investment long term substitution rate 0.01667 for sectors 44 and 45
#
#                                 EU 27 (*)           simulation        simulation to
#                                                                            EU scale
# Gross fixed c. formation           3320258.70                36.71           1842771.67
#
#
# BUYING SECTORS                     Simulated investment purchases     SIM. EU SCALE
# Crop and animal production, hu     0.00                                    0.00
# Forestry and logging               0.00                                    0.00
# Fishing and aquaculture            0.00                                    0.00
# Mining and quarrying               0.00                                    0.00
# Manufacture of food products;      0.10                                    4831.34
# Manufacture of textiles, weari     0.00                                    0.00
# Manufacture of wood and of pro     0.00                                    0.00
# Manufacture of paper and paper     0.00                                    0.00
# Printing and reproduction of r     0.00                                    0.00
# Manufacture of coke and refine     0.00                                    0.00
# Manufacture of chemicals and c     0.34                                    17058.23
# Manufacture of basic pharmaceu     0.00                                    0.00
# Manufacture of rubber and plas     0.04                                    2213.04
# Manufacture of other non-metal     0.11                                    5362.31
# Manufacture of basic metals        0.06                                    3260.97
# Manufacture of fabricated meta     0.10                                    5066.52
# Manufacture of computer, elect     0.00                                    0.00
# Manufacture of electrical equi     0.02                                    1019.51
# Manufacture of machinery and e     0.13                                    6580.71
# Manufacture of motor vehicles,     0.26                                    13104.50
# Manufacture of other transport     0.00                                    0.00
# Manufacture of furniture; othe     0.00                                    0.00
# Repair and installation of mac     0.00                                    0.00
# Electricity, gas, steam and ai     0.70                                    35194.77
# Water collection, treatment an     0.00                                    0.00
# Sewerage, waste management, re     0.00                                    0.00
# Construction                       1.92                                    96307.19
# Wholesale and retail trade and     0.44                                    22069.32
# Wholesale trade, except of mot     3.08                                    154604.16
# Retail trade, except of motor      2.37                                    118947.80
# Land transport and transport v     0.34                                    17082.83
# Water transport                    0.00                                    0.00
# Air transport                      0.00                                    0.00
# Warehousing and support activi     0.27                                    13362.61
# Postal and courier activities      0.10                                    5023.29
# Accommodation and food service     2.20                                    110445.06
# Publishing activities              0.00                                    0.00
# Motion picture, video, televis     0.00                                    0.00
# Telecommunications                 0.07                                    3760.43
# Computer programming, consulta     0.78                                    38921.13
# Financial service activities,      0.30                                    15030.71
# Insurance, reinsurance and pen     0.00                                    0.00
# Activities auxiliary to financ     0.06                                    2838.07
# Imputed rents of owner-occupie     0.00                                    0.00
# Real estate activities             18.76                                   941668.24
# Legal and accounting activitie     0.43                                    21505.59
# Architectural and engineering      0.16                                    8126.64
# Scientific research and develo     0.10                                    5096.39
# Advertising and market researc     0.08                                    3910.59
# Other professional, scientific     0.04                                    2136.70
# Rental and leasing activities      0.00                                    0.00
# Employment activities              0.02                                    1150.20
# Travel agency, tour operator a     0.00                                    0.00
# Security and investigation, se     0.05                                    2378.29
# Public administration and defe     0.77                                    38683.87
# Education                          0.51                                    25594.83
# Human health activities            1.02                                    51387.68
# Residential care activities an     0.88                                    43947.75
# Creative, arts and entertainme     0.07                                    3394.60
# Sports activities and amusemen     0.03                                    1705.81
# Activities of membership organ     0.00                                    0.00
# Repair of computers and person     0.00                                    0.00
# Other personal service activit     0.00                                    0.00
# Activities of households as em     0.00                                    0.00
# Activities of extraterritorial     0.00                                    0.00
# totals                             36.72                              1842771.68
# (*) EU 27 Gross Fixed Capital Formation is 3320258.70, but here we consider only substitutions.With  1000 ex-ante firms and smart capital option, substitutions are  1842771.677523573
#
# ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! !
# Wrong control test, run again firm-features-generation to align investment table to new test_ff choices
# ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! !
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /home/leolina/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
