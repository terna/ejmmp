# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fileBase="./yearlyData/PlannerPropMax"
num_of_repetitions = 100

# %%
yearlyDataAV=np.zeros((20,100))
yearlyDataCo=np.zeros((20,100))
yearlyDataIn=np.zeros((20,100))

# %%
for y in range(num_of_repetitions):
    yearlyData=np.load(fileBase+str(y)+".npy")
    yearlyDataAV[:,y]=yearlyData[:,0]
    yearlyDataCo[:,y]=yearlyData[:,1]
    yearlyDataIn[:,y]=yearlyData[:,2]

# %%
yearlyDataAV
# Out:
# array([[1526584.54722228, 1546799.97638894, 1507018.07083337, ...,
#         1568921.86388895, 1556750.30277783, 1521582.63194449],
#        [1691472.4069445 , 1711464.33472227, 1639487.50138893, ...,
#         1683134.41388895, 1701698.97638895, 1646845.96666671],
#        [1842983.75416673, 1879259.4208334 , 1793697.30972229, ...,
#         1838157.07500008, 1845943.2722223 , 1794011.43194451],
#        ...,
#        [2181003.94861108, 2171427.50277776, 2238403.79722221, ...,
#         2149443.60555555, 2178029.04166663, 2219743.1208333 ],
#        [2226167.06805553, 2160938.4972222 , 2208609.56249999, ...,
#         2146502.95694445, 2220506.95416663, 2213577.60555552],
#        [2175716.8833333 , 2195737.20555553, 2241487.22777777, ...,
#         2138576.54305556, 2201811.96944441, 2202855.88472219]],
#       shape=(20, 100))

# %%
yearlyDataCo
# Out:
# array([[ 742510.84352406,  763787.18604764,  758678.37674339, ...,
#          760608.53978585,  752921.28015546,  766963.49159471],
#        [ 746369.40156973,  756282.26767972,  742967.79733132, ...,
#          730009.76947116,  742510.81556583,  753461.12598152],
#        [ 735764.75255084,  746862.49128581,  744411.42797957, ...,
#          748514.76985358,  751680.68347548,  732179.10248067],
#        ...,
#        [1087188.31069495, 1101033.60287623, 1138400.67152915, ...,
#         1076065.20256845, 1081609.68172311, 1124152.67026487],
#        [1087311.13635783, 1090032.83152532, 1145304.14344171, ...,
#         1054767.96303932, 1090171.01571046, 1116630.47675578],
#        [1104692.10783643, 1109427.27106371, 1138980.78693287, ...,
#         1052103.15936696, 1093218.42377326, 1111975.26311407]],
#       shape=(20, 100))

# %%
yearlyDataIn
# Out:
# array([[ 754600.61596234,  749491.25299368,  703927.2220471 , ...,
#          750675.10322194,  735826.9288665 ,  692974.10479946],
#        [ 939871.07890234,  947567.47278219,  897116.1030742 , ...,
#          933327.43617883,  928534.31263378,  909826.37863219],
#        [1052193.2054964 , 1077343.19442245, 1031467.22724399, ...,
#         1080559.77681533, 1069111.14839644,  985412.07495238],
#        ...,
#        [1129276.09037699, 1069127.43217335, 1105115.38742979, ...,
#         1110712.2857751 , 1116190.66206136, 1105274.93393667],
#        [1104073.16888326, 1081606.83903006, 1065296.12888702, ...,
#         1080655.50255082, 1118358.86934249, 1102502.33119261],
#        [1109237.00888474, 1060571.35521564, 1089380.08272233, ...,
#         1094841.60929904, 1124123.11326845, 1116107.50161061]],
#       shape=(20, 100))

# %%
results=np.zeros((20,9))

# %%
for i in range(20):
    results[i,0]=yearlyDataAV[i,:].mean()
    results[i,1]=yearlyDataAV[i,:].mean()+2*yearlyDataAV[i,:].std()
    results[i,2]=yearlyDataAV[i,:].mean()-2*yearlyDataAV[i,:].std()
    results[i,3]=yearlyDataCo[i,:].mean()
    results[i,4]=yearlyDataCo[i,:].mean()+2*yearlyDataCo[i,:].std()
    results[i,5]=yearlyDataCo[i,:].mean()-2*yearlyDataCo[i,:].std()
    results[i,6]=yearlyDataIn[i,:].mean()
    results[i,7]=yearlyDataIn[i,:].mean()+2*yearlyDataIn[i,:].std()
    results[i,8]=yearlyDataIn[i,:].mean()-2*yearlyDataIn[i,:].std()

# %%
#results

# %%
AVmean = []
AVstd  = []
CONSmean = []
CONSstd  = []
INVmean = []
INVstd  = []
for i in range(20):
    AVmean.append(yearlyDataAV[i,:].mean())
    AVstd.append(yearlyDataAV[i,:].std())

    CONSmean.append(yearlyDataCo[i,:].mean())
    CONSstd.append(yearlyDataCo[i,:].std())

    INVmean.append(yearlyDataIn[i,:].mean())
    INVstd.append(yearlyDataIn[i,:].std())

# %%
# an example
for i in range(20):
    print(i, INVstd[i])
# Out:
# 0 25586.407835303835
# 1 30170.841193528802
# 2 31447.82071408039
# 3 28351.107253130263
# 4 27683.00063156712
# 5 25314.838110396377
# 6 29950.04160826358
# 7 36826.050293628185
# 8 28423.05611326016
# 9 25100.96292425222
# 10 24510.08968863089
# 11 24783.58355941566
# 12 26039.576239805025
# 13 23810.908938284316
# 14 25082.258403254353
# 15 21225.31834970524
# 16 23825.10868390604
# 17 23438.623167886944
# 18 23136.496368693082
# 19 23822.5792981594

# %%
# to study business cycle duration
AVmeanDelta = []
AVmeanDeltaRate = []
for i in range(1,20):
    AVmeanDelta.append(AVmean[i] - AVmean[i-1])
    AVmeanDeltaRate.append((AVmean[i] - AVmean[i-1])/AVmean[i-1])

# %%
for i in range(19):
    print(i+1, AVmeanDeltaRate[i])
# Out:
# 1 0.08666799915204677
# 2 0.0889208513297782
# 3 0.09562131848217158
# 4 0.08352022151737454
# 5 0.03621574086595581
# 6 0.008374240492191274
# 7 -0.013918188296327958
# 8 -0.012661040516667799
# 9 -0.012188517537981117
# 10 -0.001643881308861645
# 11 0.0011001262953071207
# 12 0.0018744845974682394
# 13 -0.0015524165920800799
# 14 0.0011605190916576117
# 15 0.000718603450754886
# 16 0.00021369112652850258
# 17 -0.0014908993775075955
# 18 0.0021738452840649666
# 19 -0.0001366601564259708

# %%
rAVmeanCONSmean  = np.corrcoef(AVmean, CONSmean)[0, 1]
rAVmeanINVmean   = np.corrcoef(AVmean, INVmean)[0, 1]
rINVmeanCONSmean = np.corrcoef(INVmean, CONSmean)[0, 1]

# %%
print("rAVmeanCONSmean =",rAVmeanCONSmean, "rAVmeanINVmean ",rAVmeanINVmean,"rINVmeanCONSmean ",rINVmeanCONSmean)
# Out:
# rAVmeanCONSmean = 0.8224741439616448 rAVmeanINVmean  0.7657383956339272 rINVmeanCONSmean  0.26487257578026824

# %%
plt.suptitle("Yearly National Accounts PlannerPropMax1")
plt.plot(results[:,0],color='darkorange',linewidth=1,label="added value")
plt.plot(results[:,1],color='darkorange',linestyle='dotted',linewidth=1,label="added value + 2std")
plt.plot(results[:,2],color='darkorange',linestyle='dashed',linewidth=1,label="added value - 2std")
plt.plot(results[:,3],color='green',linewidth=1,label="consumptions")
plt.plot(results[:,4],color='green',linestyle='dotted',linewidth=1,label="consumptions + 2std")
plt.plot(results[:,5],color='green',linestyle='dashed',linewidth=1,label="consumptions - 2std")
plt.plot(results[:,6],color='red',linewidth=1,label="investments")
plt.plot(results[:,7],color='red',linestyle='dotted',linewidth=1,label="investments + 2std")
plt.plot(results[:,8],color='red',linestyle='dashed',linewidth=1,label="investments - 2std")
plt.plot(0)
plt.xlabel("Years")
plt.legend(bbox_to_anchor=(1, 1), loc='upper left', ncol=1)
plt.savefig("_YearlyNationalAccountsMax.jpg", dpi=180, bbox_inches='tight')
