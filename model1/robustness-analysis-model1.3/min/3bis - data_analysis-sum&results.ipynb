# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fileBase="./yearlyData/PlannerPropMin"
num_of_repetitions = 100

# %%
yearlyDataAV=np.zeros((20,100))
yearlyDataCo=np.zeros((20,100))
yearlyDataIn=np.zeros((20,100))

# %%
for y in range(num_of_repetitions):
    yearlyData=np.load(fileBase+str(y)+".npy")
    yearlyDataAV[:,y]=yearlyData[:,0]
    yearlyDataCo[:,y]=yearlyData[:,1]
    yearlyDataIn[:,y]=yearlyData[:,2]

# %%
yearlyDataAV
# Out:
# array([[739870.02777779, 752658.97500001, 758698.11111113, ...,
#         766178.26805557, 752868.99166668, 745508.52361112],
#        [697043.42222223, 725977.1138889 , 704653.34861112, ...,
#         699922.40833334, 716358.41805557, 698553.29583334],
#        [688427.9263889 , 670562.85277779, 700385.07361112, ...,
#         658201.08750001, 652886.62500001, 673583.01527779],
#        ...,
#        [319672.07916667, 309849.26527778, 321335.32638889, ...,
#         329853.85277778, 320662.86111112, 330928.44583334],
#        [318464.74166667, 299345.05555556, 306814.82916667, ...,
#         311280.38055556, 310450.02777778, 309689.31111111],
#        [300309.22777778, 298284.23194445, 309715.24444445, ...,
#         304796.85      , 300907.16944445, 302669.31388889]],
#       shape=(20, 100))

# %%
yearlyDataCo
# Out:
# array([[603224.77499519, 599014.12367069, 606974.14599465, ...,
#         616145.46826452, 589327.74857691, 594336.75437337],
#        [560546.59282492, 573560.70194204, 558271.84988619, ...,
#         561002.86996791, 578254.10529104, 544877.60275869],
#        [534785.65852327, 541025.60336196, 548810.68540726, ...,
#         521407.59872553, 499811.7876752 , 522577.46320473],
#        ...,
#        [207573.51874175, 206607.14551995, 223074.73978849, ...,
#         235482.04064847, 224050.78320184, 237988.82218328],
#        [218692.22900239, 211760.4729864 , 215743.1385299 , ...,
#         205231.52429878, 197194.654199  , 207844.08333867],
#        [213834.7530938 , 201279.44517521, 213188.18153052, ...,
#         214835.67766671, 217747.37766726, 209175.12903614]],
#       shape=(20, 100))

# %%
yearlyDataIn
# Out:
# array([[162307.52837215, 156701.69997709, 156750.67721448, ...,
#         159436.74466766, 153840.5928372 , 162693.60644284],
#        [151712.20362692, 156482.44344961, 155403.03151553, ...,
#         153760.35243469, 156919.26406748, 158368.81259484],
#        [148791.73144067, 153038.2023421 , 156908.63920557, ...,
#         153365.98278094, 154672.71513961, 154950.03997772],
#        ...,
#        [109690.54110255, 103913.0879406 , 109277.00905885, ...,
#         106811.51198443, 104839.70826693, 108185.52606842],
#        [101126.2922955 ,  99846.23912827,  94719.71673524, ...,
#         101994.39840082, 103630.63587387,  95225.00082674],
#        [104176.53602043,  93149.12770836,  95414.29162132, ...,
#          99898.29915678, 103081.10983498,  98407.94484912]],
#       shape=(20, 100))

# %%
results=np.zeros((20,9))

# %%
for i in range(20):
    results[i,0]=yearlyDataAV[i,:].mean()
    results[i,1]=yearlyDataAV[i,:].mean()+2*yearlyDataAV[i,:].std()
    results[i,2]=yearlyDataAV[i,:].mean()-2*yearlyDataAV[i,:].std()
    results[i,3]=yearlyDataCo[i,:].mean()
    results[i,4]=yearlyDataCo[i,:].mean()+2*yearlyDataCo[i,:].std()
    results[i,5]=yearlyDataCo[i,:].mean()-2*yearlyDataCo[i,:].std()
    results[i,6]=yearlyDataIn[i,:].mean()
    results[i,7]=yearlyDataIn[i,:].mean()+2*yearlyDataIn[i,:].std()
    results[i,8]=yearlyDataIn[i,:].mean()-2*yearlyDataIn[i,:].std()

# %%
#results

# %%
AVmean = []
AVstd  = []
CONSmean = []
CONSstd  = []
INVmean = []
INVstd  = []
for i in range(20):
    AVmean.append(yearlyDataAV[i,:].mean())
    AVstd.append(yearlyDataAV[i,:].std())

    CONSmean.append(yearlyDataCo[i,:].mean())
    CONSstd.append(yearlyDataCo[i,:].std())

    INVmean.append(yearlyDataIn[i,:].mean())
    INVstd.append(yearlyDataIn[i,:].std())

# %%
# an example
for i in range(20):
    print(i, CONSstd[i])
# Out:
# 0 16673.508598114397
# 1 21163.732861147793
# 2 16025.646447110938
# 3 17320.460642616214
# 4 15296.119739808424
# 5 15201.11194171978
# 6 16256.935037946467
# 7 13981.253659490585
# 8 13533.02771274835
# 9 13322.513974912661
# 10 13009.975512263034
# 11 10561.677792983659
# 12 10921.625046320572
# 13 10607.407239255659
# 14 9836.495479759447
# 15 10150.42500565468
# 16 10755.056144071166
# 17 8684.01053161584
# 18 10680.644731350398
# 19 7746.92274032322

# %%
# to study business cycle duration
AVmeanDelta = []
AVmeanDeltaRate = []
for i in range(1,20):
    AVmeanDelta.append(AVmean[i] - AVmean[i-1])
    AVmeanDeltaRate.append((AVmean[i] - AVmean[i-1])/AVmean[i-1])

# %%
for i in range(19):
    print(i+1, AVmeanDeltaRate[i])
# Out:
# 1 -0.050845841425531724
# 2 -0.05475244516377107
# 3 -0.045142763350011814
# 4 -0.05281214948648637
# 5 -0.05066117532217966
# 6 -0.045155889273175924
# 7 -0.057894403983711866
# 8 -0.055319213686346985
# 9 -0.04573504168228386
# 10 -0.0458424326566256
# 11 -0.05345359574809934
# 12 -0.04579097963607779
# 13 -0.04453579659320379
# 14 -0.03985252947986892
# 15 -0.04718168562584194
# 16 -0.036854894502514626
# 17 -0.04824023213693249
# 18 -0.043914542154381626
# 19 -0.045638219322020834

# %%
rAVmeanCONSmean  = np.corrcoef(AVmean, CONSmean)[0, 1]
rAVmeanINVmean   = np.corrcoef(AVmean, INVmean)[0, 1]
rINVmeanCONSmean = np.corrcoef(INVmean, CONSmean)[0, 1]

# %%
print("rAVmeanCONSmean =",rAVmeanCONSmean, "rAVmeanINVmean ",rAVmeanINVmean,"rINVmeanCONSmean ",rINVmeanCONSmean)
# Out:
# rAVmeanCONSmean = 0.9986256064582567 rAVmeanINVmean  0.9342449798902046 rINVmeanCONSmean  0.9144847998939772

# %%
plt.suptitle("Yearly National Accounts PlannerPropMin1")
plt.plot(results[:,0],color='darkorange',linewidth=1,label="added value")
plt.plot(results[:,1],color='darkorange',linestyle='dotted',linewidth=1,label="added value + 2std")
plt.plot(results[:,2],color='darkorange',linestyle='dashed',linewidth=1,label="added value - 2std")
plt.plot(results[:,3],color='green',linewidth=1,label="consumptions")
plt.plot(results[:,4],color='green',linestyle='dotted',linewidth=1,label="consumptions + 2std")
plt.plot(results[:,5],color='green',linestyle='dashed',linewidth=1,label="consumptions - 2std")
plt.plot(results[:,6],color='red',linewidth=1,label="investments")
plt.plot(results[:,7],color='red',linestyle='dotted',linewidth=1,label="investments + 2std")
plt.plot(results[:,8],color='red',linestyle='dashed',linewidth=1,label="investments - 2std")
plt.plot(0)
plt.xlabel("Years")
plt.legend(bbox_to_anchor=(1, 1), loc='upper left', ncol=1)
plt.savefig("_YearlyNationalAccountsMin.jpg", dpi=180, bbox_inches='tight')
